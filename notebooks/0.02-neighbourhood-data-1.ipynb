# %%
# %load_ext autoreload
# %autoreload 2

# %%
from data import load_external_data
from config import NEIGHBOURHOODS_PATH

# %%
hoods = load_external_data(NEIGHBOURHOODS_PATH)

# %%
hoods.head()
# Out:
#    ID  ...                                           geometry
# 0   1  ...  POLYGON ((-79.58765 43.72808, -79.58736 43.728...
# 1   2  ...  POLYGON ((-79.5804 43.73973, -79.57988 43.7386...
# 2   3  ...  POLYGON ((-79.56213 43.73006, -79.56222 43.730...
# 3   4  ...  POLYGON ((-79.55976 43.72488, -79.55892 43.723...
# 4   5  ...  POLYGON ((-79.55343 43.71153, -79.5535 43.7117...
#
# [5 rows x 3 columns]

# %% [markdown]
# ### Outdated neighbourhood shapefile
# - neighbourhood shapefile: 140 neighbourhoods
# - collisions data: 158 neighbourhoods

# %%
hoods.shape
# Out:
# (140, 3)

# %%
hoods.plot()
# Out:
# <Axes: >
