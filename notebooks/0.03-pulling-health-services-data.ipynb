# %% [markdown]
# # Pulling Health Services Data

# %%
# %load_ext autoreload
# %autoreload 2

# %%
import requests
import json
import geopandas as gpd
from config import HEALTH_SERVICES_PATH

# %%
url = (
    "https://ws.lioservices.lrc.gov.on.ca/arcgis2/rest/services/"
    "LIO_OPEN_DATA/LIO_Open09/MapServer/26/query"
)

# %%
params = {
    'outFields': '*',
    'where': '1=1',
    'f': 'geojson'
}

# %%
response = requests.get(url, params=params).json()

# %%
response
# Out:
# {'type': 'FeatureCollection',
#  'features': [{'type': 'Feature',
#    'id': 2267361,
#    'geometry': {'type': 'Point',
#     'coordinates': [-79.37995558388347, 43.66425498716289]},
#    'properties': {'OGF_ID': 321014690,
#     'MOH_SERVICE_PROVIDER_IDENT': '7040917',
#     'SERVICE_TYPE': 'Pharmacy',
#     'SERVICE_TYPE_DETAIL': 'Retail Pharmacy',
#     'ENGLISH_NAME': 'Medsexpert Pharmacy',
#     'FRENCH_NAME': None,
#     'ENGLISH_NAME_ALT': None,
#     'FRENCH_NAME_ALT': None,
#     'ADDRESS_LINE_1': '461 Church Street',
#     'ADDRESS_LINE_2': None,
#     'ADDRESS_DESCRIPTOR': None,
#     'COMMUNITY': 'Toronto',
#     'POSTAL_CODE': 'M4Y2C5',
#     'GEOMETRY_UPDATE_DATETIME': 1744234487000,
#     'EFFECTIVE_DATETIME': 1744209962000,
#     'SYSTEM_DATETIME': 1744221299000,
#     'OBJECTID': 2267361}},
#   {'type': 'Feature',
#    'id': 2267377,
#    'geometry': {'type': 'Point',
#     'coordinates': [-79.37427148129977, 43.655494085887874]},
#    'properties': {'OGF_ID': 321007348,
#     'MOH_SERVICE_PROVIDER_IDENT': '2975',
#     'SERVICE_TYPE': 'Mental Health and Addiction Organization',
#     'SERVICE_TYPE_DETAIL': 'Mental Health Services',
#     'ENGLISH_NAME': 'Homes First Society',
#     'FRENCH_NAME': None,
#     'ENGLISH_NAME_ALT': None,
#     'FRENCH_NAME_ALT': None,
#     'ADDRESS_LINE_1': '90 Shuter Street',
#     'ADDRESS_LINE_2': '2nd Floor',
#     'ADDRESS_DESCRIPTOR': 'Administrative Office',
#     'COMMUNITY': 'Toronto',
#     'POSTAL_CODE': 'M5B2K6',
#     'GEOMETRY_UPDATE_DATETIME': 1744234390000,
#     'EFFECTIVE_DATETIME': 1744209151000,
#     'SYSTEM_DATETIME': 1744221299000,
#     'OBJECTID': 2267377}},
#   {'type': 'Feature',
#    'id': 2267393,
#    'geometry': {'type': 'Point',
#     'coordinates': [-79.33946097071183, 43.661393388536275]},
#    'properties': {'OGF_ID': 321015379,
#     'MOH_SERVICE_PROVIDER_IDENT': '7973712',
#     'SERVICE_TYPE': 'Pharmacy',
#     'SERVICE_TYPE_DETAIL': 'Retail Pharmacy',
#     'ENGLISH_NAME': 'Woodgreen Discount Pharmacy',
#     'FRENCH_NAME': None,
#     'ENGLISH_NAME_ALT': None,
#     'FRENCH_NAME_ALT': None,
#     'ADDRESS_LINE_1': '1000 Queen Street East',
#     'ADDRESS_LINE_2': None,
#     'ADDRESS_DESCRIPTOR': None,
#     'COMMUNITY': 'Toronto',
#     'POSTAL_CODE': 'M4M1K1',
#     'GEOMETRY_UPDATE_DATETIME': 1744234594000,
#     'EFFECTIVE_DATETIME': 1744210039000,
#     'SYSTEM_DATETIME': 1744221299000,
#     'OBJECTID': 2267393}},
#   {'type': 'Feature',
#    'id': 2267409,
#    'geometry': {'type': 'Point',
#     'coordinates': [-81.19939090131443, 43.013415986436605]},
#    'properties': {'OGF_ID': 321014328,
#     'MOH_SERVICE_PROVIDER_IDENT': '6544073',
#     'SERVICE_TYPE': 'Pharmacy',
#     'SERVICE_TYPE_DETAIL': 'Retail Pharmacy',
#     'ENGLISH_NAME': 'Fanshawe College Pharmacy',
#     'FRENCH_NAME': None,
#     'ENGLISH_NAME_ALT': None,
#     'FRENCH_NAME_ALT': None,
#     'ADDRESS_LINE_1': '1001 Fanshawe College Boulevard',
#     'ADDRESS_LINE_2': 'Unit J1000',
#     'ADDRESS_DESCRIPTOR': None,
#     'COMMUNITY': 'London',
#     'POSTAL_CODE': 'N5Y5R6',
#     'GEOMETRY_UPDATE_DATETIME': 1744234312000,
#     'EFFECTIVE_DATETIME': 1744209922000,
#     'SYSTEM_DATETIME': 1744221299000,
#     'OBJECTID': 2267409}},
#   {'type': 'Feature',
#    'id': 2267425,
#    'geometry': {'type': 'Point',
#     'coordinates': [-92.42782873979856, 50.116772846460314]},
#    'properties': {'OGF_ID': 321009035,
#     'MOH_SERVICE_PROVIDER_IDENT': '4484',
#     'SERVICE_TYPE': 'Community Support Service',
#     'SERVICE_TYPE_DETAIL': None,
#     'ENGLISH_NAME': 'Lac Seul First Nation',
#     'FRENCH_NAME': None,
#     'ENGLISH_NAME_ALT': None,
#     'FRENCH_NAME_ALT': None,
#     'ADDRESS_LINE_1': 'P.O. Box 100',
#     'ADDRESS_LINE_2': None,
#     'ADDRESS_DESCRIPTOR': None,
#     'COMMUNITY': 'Lac Seul 28',
#     'POSTAL_CODE': 'P0V1X0',
#     'GEOMETRY_UPDATE_DATETIME': 1744234492000,
#     'EFFECTIVE_DATETIME': 1744209335000,
#     'SYSTEM_DATETIME': 1744221299000,
#     'OBJECTID': 2267425}},
#   {'type': 'Feature',
#    'id': 2267441,
#    'geometry': {'type': 'Point',
#     'coordinates': [-79.38505668583214, 43.66790678756752]},
#    'properties': {'OGF_ID': 321011995,
#     'MOH_SERVICE_PROVIDER_IDENT': '2189517',
#     'SERVICE_TYPE': 'Pharmacy',
#     'SERVICE_TYPE_DETAIL': 'Retail Pharmacy',
#     'ENGLISH_NAME': 'Pace Pharmacy',
#     'FRENCH_NAME': None,
#     'ENGLISH_NAME_ALT': None,
#     'FRENCH_NAME_ALT': None,
#     'ADDRESS_LINE_1': '14 Isabella Street',
#     'ADDRESS_LINE_2': None,
#     'ADDRESS_DESCRIPTOR': None,
#     'COMMUNITY': 'Toronto',
#     'POSTAL_CODE': 'M4Y1N1',
#     'GEOMETRY_UPDATE_DATETIME': 1744234447000,
#     'EFFECTIVE_DATETIME': 1744209661000,
#     'SYSTEM_DATETIME': 1744221299000,
#     'OBJECTID': 2267441}},
#   {'type': 'Feature',
#    'id': 2267457,
#    'geometry': {'type': 'Point',
#     'coordinates': [-79.09912444785923, 43.12351570426253]},
#    'properties': {'OGF_ID': 321007520,
#     'MOH_SERVICE_PROVIDER_IDENT': '30714',
#     'SERVICE_TYPE': 'Mental Health and Addiction Organization',
#     'SERVICE_TYPE_DETAIL': 'Mental Health Services',
#     'ENGLISH_NAME': 'Consumer/Survivor Initiative Of Niagara',
#     'FRENCH_NAME': None,
#     'ENGLISH_NAME_ALT': None,
#     'FRENCH_NAME_ALT': None,
#     'ADDRESS_LINE_1': '3428 Portage Road',
#     'ADDRESS_LINE_2': None,
#     'ADDRESS_DESCRIPTOR': 'Practice Location',
#     'COMMUNITY': 'Niagara Falls',
#     'POSTAL_CODE': 'L2J2K4',
#     'GEOMETRY_UPDATE_DATETIME': 1744234257000,
#     'EFFECTIVE_DATETIME': 1744209170000,
#     'SYSTEM_DATETIME': 1744221299000,
#     'OBJECTID': 2267457}},
#   {'type': 'Feature',
#    'id': 2267473,
#    'geometry': {'type': 'Point',
#     'coordinates': [-75.54874899008772, 45.435952663614685]},
#    'properties': {'OGF_ID': 321010853,
#     'MOH_SERVICE_PROVIDER_IDENT': 'N0475',
#     'SERVICE_TYPE': 'Licensed Retirement Home',
#     'SERVICE_TYPE_DETAIL': None,
#     'ENGLISH_NAME': 'Blackburn Senior Retirement Home',
#     'FRENCH_NAME': None,
#     'ENGLISH_NAME_ALT': None,
#     'FRENCH_NAME_ALT': None,
#     'ADDRESS_LINE_1': '2412 Cleroux Crescent',
#     'ADDRESS_LINE_2': None,
#     'ADDRESS_DESCRIPTOR': None,
#     'COMMUNITY': 'Ottawa',
#     'POSTAL_CODE': 'K1W1A3',
#     'GEOMETRY_UPDATE_DATETIME': 1744234592000,
#     'EFFECTIVE_DATETIME': 1744209531000,
#     'SYSTEM_DATETIME': 1744221299000,
#     'OBJECTID': 2267473}},
#   {'type': 'Feature',
#    'id': 2267489,
#    'geometry': {'type': 'Point',
#     'coordinates': [-79.76219871397784, 43.75711708556565]},
#    'properties': {'OGF_ID': 321010237,
#     'MOH_SERVICE_PROVIDER_IDENT': '9966412',
#     'SERVICE_TYPE': 'Integrated Community Health Services Centre',
#     'SERVICE_TYPE_DETAIL': 'Nuclear Medicine - In Vivo - General, Nuclear Medicine - In Vivo - Spect',
#     'ENGLISH_NAME': 'Myhealth Centre',
#     'FRENCH_NAME': None,
#     'ENGLISH_NAME_ALT': 'Myhealth Caledon Inc.',
#     'FRENCH_NAME_ALT': None,
#     'ADDRESS_LINE_1': '2 Dewside Drive',
#     'ADDRESS_LINE_2': 'Unit 206',
#     'ADDRESS_DESCRIPTOR': None,
#     'COMMUNITY': 'Brampton',
#     'POSTAL_CODE': 'L6R3Y5',
#     'GEOMETRY_UPDATE_DATETIME': 1744234571000,
#     'EFFECTIVE_DATETIME': 1744209466000,
#     'SYSTEM_DATETIME': 1744221299000,
#     'OBJECTID': 2267489}},
#   {'type': 'Feature',
#    'id': 2267505,
#    'geometry': {'type': 'Point',
#     'coordinates': [-79.38605858549987, 43.660497586220224]},
#    'properties': {'OGF_ID': 321008658,
#     'MOH_SERVICE_PROVIDER_IDENT': '4179104',
#     'SERVICE_TYPE': 'Integrated Community Health Services Centre',
#     'SERVICE_TYPE_DETAIL': 'Sleep Studies',
#     'ENGLISH_NAME': 'Sleep And Alertness Clinic',
#     'FRENCH_NAME': None,
#     'ENGLISH_NAME_ALT': 'Straight Sleep Inc.',
#     'FRENCH_NAME_ALT': None,
#     'ADDRESS_LINE_1': '790 Bay Street',
#     'ADDRESS_LINE_2': 'Suite 800',
#     'ADDRESS_DESCRIPTOR': None,
#     'COMMUNITY': 'Toronto',
#     'POSTAL_CODE': 'M5G1N8',
#     'GEOMETRY_UPDATE_DATETIME': 1744234614000,
#     'EFFECTIVE_DATETIME': 1744209294000,
#     'SYSTEM_DATETIME': 1744221299000,
#     'OBJECTID': 2267505}},
#   {'type': 'Feature',
#    'id': 2267521,
#    'geometry': {'type': 'Point',
#     'coordinates': [-78.34783430860692, 44.30072534569156]},
#    'properties': {'OGF_ID': 321009817,
#     'MOH_SERVICE_PROVIDER_IDENT': '771',
#     'SERVICE_TYPE': 'Community Support Service',
#     'SERVICE_TYPE_DETAIL': None,
#     'ENGLISH_NAME': 'Peterborough Regional Health Centre',
#     'FRENCH_NAME': None,
#     'ENGLISH_NAME_ALT': None,
#     'FRENCH_NAME_ALT': None,
#     'ADDRESS_LINE_1': '1Hospital Drive',
#     'ADDRESS_LINE_2': None,
#     'ADDRESS_DESCRIPTOR': None,
#     'COMMUNITY': 'Peterborough',
#     'POSTAL_CODE': 'K9J7C6',
#     'GEOMETRY_UPDATE_DATETIME': 1744234520000,
#     'EFFECTIVE_DATETIME': 1744209420000,
#     'SYSTEM_DATETIME': 1744221299000,
#     'OBJECTID': 2267521}},
#   {'type': 'Feature',
#    'id': 2267537,
#    'geometry': {'type': 'Point',
#     'coordinates': [-80.9495195552336, 43.37202126153235]},
#    'properties': {'OGF_ID': 321012803,
#     'MOH_SERVICE_PROVIDER_IDENT': '4098951',
#     'SERVICE_TYPE': 'Pharmacy',
#     'SERVICE_TYPE_DETAIL': 'Retail Pharmacy',
#     'ENGLISH_NAME': 'Wal-Mart Pharmacy',
#     'FRENCH_NAME': None,
#     'ENGLISH_NAME_ALT': None,
#     'FRENCH_NAME_ALT': None,
#     'ADDRESS_LINE_1': '920 Ontario Street',
#     'ADDRESS_LINE_2': None,
#     'ADDRESS_DESCRIPTOR': None,
#     'COMMUNITY': 'Stratford',
#     'POSTAL_CODE': 'N5A3K1',
#     'GEOMETRY_UPDATE_DATETIME': 1744234486000,
#     'EFFECTIVE_DATETIME': 1744209753000,
#     'SYSTEM_DATETIME': 1744221299000,
#     'OBJECTID': 2267537}},
#   {'type': 'Feature',
#    'id': 2267553,
#    'geometry': {'type': 'Point',
#     'coordinates': [-79.52340783300271, 43.70239748718286]},
#    'properties': {'OGF_ID': 321015214,
#     'MOH_SERVICE_PROVIDER_IDENT': '7730510',
#     'SERVICE_TYPE': 'Pharmacy',
#     'SERVICE_TYPE_DETAIL': 'Retail Pharmacy',
#     'ENGLISH_NAME': 'Central Weston Pharmacy',
#     'FRENCH_NAME': None,
#     'ENGLISH_NAME_ALT': None,
#     'FRENCH_NAME_ALT': None,
#     'ADDRESS_LINE_1': '2105 Weston Road',
#     'ADDRESS_LINE_2': None,
#     'ADDRESS_DESCRIPTOR': None,
#     'COMMUNITY': 'Toronto',
#     'POSTAL_CODE': 'M9N1X7',
#     'GEOMETRY_UPDATE_DATETIME': 1744234455000,
#     'EFFECTIVE_DATETIME': 1744210021000,
#     'SYSTEM_DATETIME': 1744221299000,
#     'OBJECTID': 2267553}},
#   {'type': 'Feature',
#    'id': 2267569,
#    'geometry': {'type': 'Point',
#     'coordinates': [-80.29009692503519, 43.122190849040294]},
#    'properties': {'OGF_ID': 321012814,
#     'MOH_SERVICE_PROVIDER_IDENT': '4111758',
#     'SERVICE_TYPE': 'Pharmacy',
#     'SERVICE_TYPE_DETAIL': 'Retail Pharmacy',
#     'ENGLISH_NAME': 'Pharmasave Shellard Lane Phrcy',
#     'FRENCH_NAME': None,
#     'ENGLISH_NAME_ALT': None,
#     'FRENCH_NAME_ALT': None,
#     'ADDRESS_LINE_1': '7-230 Shellard Lane',
#     'ADDRESS_LINE_2': None,
#     'ADDRESS_DESCRIPTOR': None,
#     'COMMUNITY': 'Brantford',
#     'POSTAL_CODE': 'N3T5S5',
#     'GEOMETRY_UPDATE_DATETIME': 1744234644000,
#     'EFFECTIVE_DATETIME': 1744209754000,
#     'SYSTEM_DATETIME': 1744221299000,
#     'OBJECTID': 2267569}},
#   {'type': 'Feature',
#    'id': 2267585,
#    'geometry': {'type': 'Point',
#     'coordinates': [-75.91284559758488, 45.281026621783965]},
#    'properties': {'OGF_ID': 321016899,
#     'MOH_SERVICE_PROVIDER_IDENT': '9571279',
#     'SERVICE_TYPE': 'Pharmacy',
#     'SERVICE_TYPE_DETAIL': 'Retail Pharmacy',
#     'ENGLISH_NAME': 'Unity Compounding Pharmacy',
#     'FRENCH_NAME': None,
#     'ENGLISH_NAME_ALT': None,
#     'FRENCH_NAME_ALT': None,
#     'ADDRESS_LINE_1': '5-5754 Hazeldean Road',
#     'ADDRESS_LINE_2': None,
#     'ADDRESS_DESCRIPTOR': None,
#     'COMMUNITY': 'Stittsville',
#     'POSTAL_CODE': 'K2S2R1',
#     'GEOMETRY_UPDATE_DATETIME': 1744234593000,
#     'EFFECTIVE_DATETIME': 1744210211000,
#     'SYSTEM_DATETIME': 1744221299000,
#     'OBJECTID': 2267585}},
#   {'type': 'Feature',
#    'id': 2267601,
#    'geometry': {'type': 'Point',
#     'coordinates': [-75.69900132596497, 45.270859329062255]},
#    'properties': {'OGF_ID': 321015327,
#     'MOH_SERVICE_PROVIDER_IDENT': '7890598',
#     'SERVICE_TYPE': 'Pharmacy',
#     'SERVICE_TYPE_DETAIL': 'Retail Pharmacy',
#     'ENGLISH_NAME': 'Loblaw Pharmacy #4253',
#     'FRENCH_NAME': None,
#     'ENGLISH_NAME_ALT': None,
#     'FRENCH_NAME_ALT': None,
#     'ADDRESS_LINE_1': '671 River Road',
#     'ADDRESS_LINE_2': None,
#     'ADDRESS_DESCRIPTOR': None,
#     'COMMUNITY': 'Gloucester',
#     'POSTAL_CODE': 'K1V2G2',
#     'GEOMETRY_UPDATE_DATETIME': 1744234541000,
#     'EFFECTIVE_DATETIME': 1744210034000,
#     'SYSTEM_DATETIME': 1744221299000,
#     'OBJECTID': 2267601}},
#   {'type': 'Feature',
#    'id': 2267617,
#    'geometry': {'type': 'Point',
#     'coordinates': [-81.23625650653217, 42.94277697218394]},
#    'properties': {'OGF_ID': 321013202,
#     'MOH_SERVICE_PROVIDER_IDENT': '4812117',
#     'SERVICE_TYPE': 'Pharmacy',
#     'SERVICE_TYPE_DETAIL': 'Retail Pharmacy',
#     'ENGLISH_NAME': 'Nixon Pharmacy',
#     'FRENCH_NAME': None,
#     'ENGLISH_NAME_ALT': None,
#     'FRENCH_NAME_ALT': None,
#     'ADDRESS_LINE_1': '102-510 Southdale Road East',
#     'ADDRESS_LINE_2': None,
#     'ADDRESS_DESCRIPTOR': None,
#     'COMMUNITY': 'London',
#     'POSTAL_CODE': 'N6E0B2',
#     'GEOMETRY_UPDATE_DATETIME': 1744234618000,
#     'EFFECTIVE_DATETIME': 1744209797000,
#     'SYSTEM_DATETIME': 1744221299000,
#     'OBJECTID': 2267617}},
#   {'type': 'Feature',
#    'id': 2267633,
#    'geometry': {'type': 'Point',
#     'coordinates': [-81.37572909591384, 44.48930693252983]},
#    'properties': {'OGF_ID': 321014003,
#     'MOH_SERVICE_PROVIDER_IDENT': '6083597',
#     'SERVICE_TYPE': 'Pharmacy',
#     'SERVICE_TYPE_DETAIL': 'Retail Pharmacy',
#     'ENGLISH_NAME': 'Rexall #1644',
#     'FRENCH_NAME': None,
#     'ENGLISH_NAME_ALT': None,
#     'FRENCH_NAME_ALT': None,
#     'ADDRESS_LINE_1': '174 Albert Street South',
#     'ADDRESS_LINE_2': None,
#     'ADDRESS_DESCRIPTOR': None,
#     'COMMUNITY': 'Southampton',
#     'POSTAL_CODE': 'N0H2L0',
#     'GEOMETRY_UPDATE_DATETIME': 1744234479000,
#     'EFFECTIVE_DATETIME': 1744209885000,
#     'SYSTEM_DATETIME': 1744221299000,
#     'OBJECTID': 2267633}},
#   {'type': 'Feature',
#    'id': 2267649,
#    'geometry': {'type': 'Point',
#     'coordinates': [-80.73329806409193, 43.115469326836255]},
#    'properties': {'OGF_ID': 321013655,
#     'MOH_SERVICE_PROVIDER_IDENT': '5550370',
#     'SERVICE_TYPE': 'Pharmacy',
#     'SERVICE_TYPE_DETAIL': 'Retail Pharmacy',
#     'ENGLISH_NAME': 'Wal-Mart Pharmacy',
#     'FRENCH_NAME': None,
#     'ENGLISH_NAME_ALT': None,
#     'FRENCH_NAME_ALT': None,
#     'ADDRESS_LINE_1': '499 Norwich Avenue',
#     'ADDRESS_LINE_2': None,
#     'ADDRESS_DESCRIPTOR': None,
#     'COMMUNITY': 'Woodstock',
#     'POSTAL_CODE': 'N4S9A2',
#     'GEOMETRY_UPDATE_DATETIME': 1744234634000,
#     'EFFECTIVE_DATETIME': 1744209847000,
#     'SYSTEM_DATETIME': 1744221299000,
#     'OBJECTID': 2267649}},
#   {'type': 'Feature',
#    'id': 2267665,
#    'geometry': {'type': 'Point',
#     'coordinates': [-79.86967280377743, 43.25566909236831]},
#    'properties': {'OGF_ID': 321006702,
#     'MOH_SERVICE_PROVIDER_IDENT': '18191',
#     'SERVICE_TYPE': 'Mental Health and Addiction Organization',
#     'SERVICE_TYPE_DETAIL': 'Mental Health Services',
#     'ENGLISH_NAME': "St. Joseph's Healthcare Hamilton",
#     'FRENCH_NAME': None,
#     'ENGLISH_NAME_ALT': None,
#     'FRENCH_NAME_ALT': None,
#     'ADDRESS_LINE_1': '38 James Street South',
#     'ADDRESS_LINE_2': 'Second Floor',
#     'ADDRESS_DESCRIPTOR': 'Practice Location',
#     'COMMUNITY': 'Hamilton',
#     'POSTAL_CODE': 'L8P4W6',
#     'GEOMETRY_UPDATE_DATETIME': 1744234403000,
#     'EFFECTIVE_DATETIME': 1744209079000,
#     'SYSTEM_DATETIME': 1744221299000,
#     'OBJECTID': 2267665}},
#   {'type': 'Feature',
#    'id': 2267681,
#    'geometry': {'type': 'Point',
#     'coordinates': [-79.37867498329864, 43.66225108687043]},
#    'properties': {'OGF_ID': 321009562,
#     'MOH_SERVICE_PROVIDER_IDENT': '6101043',
#     'SERVICE_TYPE': 'Community Health Centre',
#     'SERVICE_TYPE_DETAIL': 'Satellite',
#     'ENGLISH_NAME': 'Vibrant Health Care Alliance Carlton Site',
#     'FRENCH_NAME': None,
#     'ENGLISH_NAME_ALT': 'Formerly Anne Johnston Health Station',
#     'FRENCH_NAME_ALT': None,
#     'ADDRESS_LINE_1': '84 Carlton Street',
#     'ADDRESS_LINE_2': 'Main Floor',
#     'ADDRESS_DESCRIPTOR': None,
#     'COMMUNITY': 'Toronto',
#     'POSTAL_CODE': 'M5B2P4',
#     'GEOMETRY_UPDATE_DATETIME': 1744234220000,
#     'EFFECTIVE_DATETIME': 1744209391000,
#     'SYSTEM_DATETIME': 1744221299000,
#     'OBJECTID': 2267681}},
#   {'type': 'Feature',
#    'id': 2267697,
#    'geometry': {'type': 'Point',
#     'coordinates': [-79.37519148253327, 43.66618368772238]},
#    'properties': {'OGF_ID': 321009571,
#     'MOH_SERVICE_PROVIDER_IDENT': '618980',
#     'SERVICE_TYPE': 'HIV AIDS and Hep C Program',
#     'SERVICE_TYPE_DETAIL': 'HIV Clinical Services',
#     'ENGLISH_NAME': "St. Michael's Hospital, Family Health Team, Wellesley-St. James Town Health Centre",
#     'FRENCH_NAME': None,
#     'ENGLISH_NAME_ALT': 'Unity Health',
#     'FRENCH_NAME_ALT': None,
#     'ADDRESS_LINE_1': '95 Homewood Avenue',
#     'ADDRESS_LINE_2': None,
#     'ADDRESS_DESCRIPTOR': 'Practice Location',
#     'COMMUNITY': 'Toronto',
#     'POSTAL_CODE': 'M4Y1J4',
#     'GEOMETRY_UPDATE_DATETIME': 1744234528000,
#     'EFFECTIVE_DATETIME': 1744209392000,
#     'SYSTEM_DATETIME': 1744221299000,
#     'OBJECTID': 2267697}},
#   {'type': 'Feature',
#    'id': 2267713,
#    'geometry': {'type': 'Point',
#     'coordinates': [-79.28092196152144, 43.769336010181625]},
#    'properties': {'OGF_ID': 321014876,
#     'MOH_SERVICE_PROVIDER_IDENT': '7267272',
#     'SERVICE_TYPE': 'Pharmacy',
#     'SERVICE_TYPE_DETAIL': 'Retail Pharmacy',
#     'ENGLISH_NAME': 'Progress Centre Pharmacy',
#     'FRENCH_NAME': None,
#     'ENGLISH_NAME_ALT': None,
#     'FRENCH_NAME_ALT': None,
#     'ADDRESS_LINE_1': '1A-9 Progress Avenue',
#     'ADDRESS_LINE_2': None,
#     'ADDRESS_DESCRIPTOR': None,
#     'COMMUNITY': 'Scarborough',
#     'POSTAL_CODE': 'M1P5A4',
#     'GEOMETRY_UPDATE_DATETIME': 1744234676000,
#     'EFFECTIVE_DATETIME': 1744209983000,
#     'SYSTEM_DATETIME': 1744221299000,
#     'OBJECTID': 2267713}},
#   {'type': 'Feature',
#    'id': 2267729,
#    'geometry': {'type': 'Point',
#     'coordinates': [-79.58415426092421, 43.79849170115353]},
#    'properties': {'OGF_ID': 321011443,
#     'MOH_SERVICE_PROVIDER_IDENT': 'T0638',
#     'SERVICE_TYPE': 'Licensed Retirement Home',
#     'SERVICE_TYPE_DETAIL': None,
#     'ENGLISH_NAME': 'Agecare Pine Grove',
#     'FRENCH_NAME': None,
#     'ENGLISH_NAME_ALT': None,
#     'FRENCH_NAME_ALT': None,
#     'ADDRESS_LINE_1': '8403 Islington Avenue North',
#     'ADDRESS_LINE_2': None,
#     'ADDRESS_DESCRIPTOR': None,
#     'COMMUNITY': 'Woodbridge',
#     'POSTAL_CODE': 'L4L1X3',
#     'GEOMETRY_UPDATE_DATETIME': 1744234397000,
#     'EFFECTIVE_DATETIME': 1744209598000,
#     'SYSTEM_DATETIME': 1744221299000,
#     'OBJECTID': 2267729}},
#   {'type': 'Feature',
#    'id': 2267745,
#    'geometry': {'type': 'Point',
#     'coordinates': [-81.33312654182063, 42.99812127726525]},
#    'properties': {'OGF_ID': 321013456,
#     'MOH_SERVICE_PROVIDER_IDENT': '5218196',
#     'SERVICE_TYPE': 'Pharmacy',
#     'SERVICE_TYPE_DETAIL': 'Retail Pharmacy',
#     'ENGLISH_NAME': 'Grace Drug Store',
#     'FRENCH_NAME': None,
#     'ENGLISH_NAME_ALT': None,
#     'FRENCH_NAME_ALT': None,
#     'ADDRESS_LINE_1': '1070 Gainsborough Road',
#     'ADDRESS_LINE_2': None,
#     'ADDRESS_DESCRIPTOR': None,
#     'COMMUNITY': 'London',
#     'POSTAL_CODE': 'N6H5L5',
#     'GEOMETRY_UPDATE_DATETIME': 1744234249000,
#     'EFFECTIVE_DATETIME': 1744209825000,
#     'SYSTEM_DATETIME': 1744221299000,
#     'OBJECTID': 2267745}},
#   {'type': 'Feature',
#    'id': 2267761,
#    'geometry': {'type': 'Point',
#     'coordinates': [-75.66223305874294, 44.60349171500411]},
#    'properties': {'OGF_ID': 321010697,
#     'MOH_SERVICE_PROVIDER_IDENT': 'N0070',
#     'SERVICE_TYPE': 'Licensed Retirement Home',
#     'SERVICE_TYPE_DETAIL': None,
#     'ENGLISH_NAME': 'Chartwell Rosedale Retirement Residence',
#     'FRENCH_NAME': None,
#     'ENGLISH_NAME_ALT': None,
#     'FRENCH_NAME_ALT': None,
#     'ADDRESS_LINE_1': '1813 County Road 2  East',
#     'ADDRESS_LINE_2': 'Rr 1',
#     'ADDRESS_DESCRIPTOR': None,
#     'COMMUNITY': 'Brockville',
#     'POSTAL_CODE': 'K6V5T1',
#     'GEOMETRY_UPDATE_DATETIME': 1744234347000,
#     'EFFECTIVE_DATETIME': 1744209514000,
#     'SYSTEM_DATETIME': 1744221299000,
#     'OBJECTID': 2267761}},
#   {'type': 'Feature',
#    'id': 2267777,
#    'geometry': {'type': 'Point',
#     'coordinates': [-79.233048946927, 43.777338413800024]},
#    'properties': {'OGF_ID': 321007681,
#     'MOH_SERVICE_PROVIDER_IDENT': '3130',
#     'SERVICE_TYPE': 'Mental Health and Addiction Organization',
#     'SERVICE_TYPE_DETAIL': 'Mental Health Services',
#     'ENGLISH_NAME': 'Canadian Mental Health Association (Cmha) Toronto Branch',
#     'FRENCH_NAME': None,
#     'ENGLISH_NAME_ALT': None,
#     'FRENCH_NAME_ALT': None,
#     'ADDRESS_LINE_1': '1200 Markham Road',
#     'ADDRESS_LINE_2': 'Suite: 500',
#     'ADDRESS_DESCRIPTOR': 'Practice Location',
#     'COMMUNITY': 'Scarborough',
#     'POSTAL_CODE': 'M1H3C3',
#     'GEOMETRY_UPDATE_DATETIME': 1744234624000,
#     'EFFECTIVE_DATETIME': 1744209187000,
#     'SYSTEM_DATETIME': 1744221299000,
#     'OBJECTID': 2267777}},
#   {'type': 'Feature',
#    'id': 2267793,
#    'geometry': {'type': 'Point',
#     'coordinates': [-79.44753421006226, 43.71661989320933]},
#    'properties': {'OGF_ID': 321008721,
#     'MOH_SERVICE_PROVIDER_IDENT': '4221435',
#     'SERVICE_TYPE': 'Community Health Centre',
#     'SERVICE_TYPE_DETAIL': 'Satellite',
#     'ENGLISH_NAME': 'Unison Health And Community Services Pathways To Education',
#     'FRENCH_NAME': None,
#     'ENGLISH_NAME_ALT': None,
#     'FRENCH_NAME_ALT': None,
#     'ADDRESS_LINE_1': '700 Lawrence Avenue West, Ste 440B',
#     'ADDRESS_LINE_2': 'Lawrence Square Mall',
#     'ADDRESS_DESCRIPTOR': None,
#     'COMMUNITY': 'Toronto',
#     'POSTAL_CODE': 'M6A3B4',
#     'GEOMETRY_UPDATE_DATETIME': 1744234200000,
#     'EFFECTIVE_DATETIME': 1744209301000,
#     'SYSTEM_DATETIME': 1744221299000,
#     'OBJECTID': 2267793}},
#   {'type': 'Feature',
#    'id': 2267809,
#    'geometry': {'type': 'Point',
#     'coordinates': [-79.55039245073577, 43.80502820387622]},
#    'properties': {'OGF_ID': 321010149,
#     'MOH_SERVICE_PROVIDER_IDENT': '9361147',
#     'SERVICE_TYPE': 'Integrated Community Health Services Centre',
#     'SERVICE_TYPE_DETAIL': 'Bone Mineral Dxa, Fluoroscopy, Mammography, Radiography, General Ultrasound, Vascular Ultrasound, Nuclear Medicine - In Vivo - General, Nuclear Medicine - In Vivo - Spect, Pulmonary Function A - Pure Screening, Pulmonary Function B - Lung Volumes & Diffusion',
#     'ENGLISH_NAME': 'Vaughan Imaging Consultants',
#     'FRENCH_NAME': None,
#     'ENGLISH_NAME_ALT': 'Dixie X-Ray Associates Limited',
#     'FRENCH_NAME_ALT': None,
#     'ADDRESS_LINE_1': '8333 Weston Road',
#     'ADDRESS_LINE_2': 'Suite B04',
#     'ADDRESS_DESCRIPTOR': None,
#     'COMMUNITY': 'Woodbridge',
#     'POSTAL_CODE': 'L4L8E2',
#     'GEOMETRY_UPDATE_DATETIME': 1744234534000,
#     'EFFECTIVE_DATETIME': 1744209456000,
#     'SYSTEM_DATETIME': 1744221299000,
#     'OBJECTID': 2267809}},
#   {'type': 'Feature',
#    'id': 2267825,
#    'geometry': {'type': 'Point',
#     'coordinates': [-79.54142299397417, 43.18952799583992]},
#    'properties': {'OGF_ID': 321014227,
#     'MOH_SERVICE_PROVIDER_IDENT': '6388839',
#     'SERVICE_TYPE': 'Pharmacy',
#     'SERVICE_TYPE_DETAIL': 'Long Term Care Facility',
#     'ENGLISH_NAME': 'Deer Park Villa',
#     'FRENCH_NAME': None,
#     'ENGLISH_NAME_ALT': None,
#     'FRENCH_NAME_ALT': None,
#     'ADDRESS_LINE_1': '150 Central Avenue',
#     'ADDRESS_LINE_2': None,
#     'ADDRESS_DESCRIPTOR': None,
#     'COMMUNITY': 'Grimsby',
#     'POSTAL_CODE': 'L3M4Z3',
#     'GEOMETRY_UPDATE_DATETIME': 1744234688000,
#     'EFFECTIVE_DATETIME': 1744209911000,
#     'SYSTEM_DATETIME': 1744221299000,
#     'OBJECTID': 2267825}},
#   {'type': 'Feature',
#    'id': 2267841,
#    'geometry': {'type': 'Point',
#     'coordinates': [-79.27087445825795, 43.76873671054211]},
#    'properties': {'OGF_ID': 321012492,
#     'MOH_SERVICE_PROVIDER_IDENT': '3401679',
#     'SERVICE_TYPE': 'Pharmacy',
#     'SERVICE_TYPE_DETAIL': 'Retail Pharmacy',
#     'ENGLISH_NAME': 'Metropolitan Pharmacy',
#     'FRENCH_NAME': None,
#     'ENGLISH_NAME_ALT': None,
#     'FRENCH_NAME_ALT': None,
#     'ADDRESS_LINE_1': '2025 Midland Avenue',
#     'ADDRESS_LINE_2': 'Suite 101',
#     'ADDRESS_DESCRIPTOR': None,
#     'COMMUNITY': 'Scarborough',
#     'POSTAL_CODE': 'M1P3E2',
#     'GEOMETRY_UPDATE_DATETIME': 1744234396000,
#     'EFFECTIVE_DATETIME': 1744209717000,
#     'SYSTEM_DATETIME': 1744221299000,
#     'OBJECTID': 2267841}},
#   {'type': 'Feature',
#    'id': 2267857,
#    'geometry': {'type': 'Point',
#     'coordinates': [-79.69416314940602, 44.38376529727595]},
#    'properties': {'OGF_ID': 321007668,
#     'MOH_SERVICE_PROVIDER_IDENT': '31279',
#     'SERVICE_TYPE': 'Mental Health and Addiction Organization',
#     'SERVICE_TYPE_DETAIL': 'Mental Health Services',
#     'ENGLISH_NAME': 'Canadian Mental Health Association (Cmha) Simcoe County Branch',
#     'FRENCH_NAME': None,
#     'ENGLISH_NAME_ALT': None,
#     'FRENCH_NAME_ALT': None,
#     'ADDRESS_LINE_1': '80 Bradford Street',
#     'ADDRESS_LINE_2': 'Suite: 555',
#     'ADDRESS_DESCRIPTOR': 'Practice Location',
#     'COMMUNITY': 'Barrie',
#     'POSTAL_CODE': 'L4N6S7',
#     'GEOMETRY_UPDATE_DATETIME': 1744234506000,
#     'EFFECTIVE_DATETIME': 1744209186000,
#     'SYSTEM_DATETIME': 1744221299000,
#     'OBJECTID': 2267857}},
#   {'type': 'Feature',
#    'id': 2267873,
#    'geometry': {'type': 'Point',
#     'coordinates': [-79.63276896741073, 43.69734528118895]},
#    'properties': {'OGF_ID': 321015915,
#     'MOH_SERVICE_PROVIDER_IDENT': '8601872',
#     'SERVICE_TYPE': 'Pharmacy',
#     'SERVICE_TYPE_DETAIL': 'Retail Pharmacy',
#     'ENGLISH_NAME': 'Mckesson Specialty Phcy (On)',
#     'FRENCH_NAME': None,
#     'ENGLISH_NAME_ALT': None,
#     'FRENCH_NAME_ALT': None,
#     'ADDRESS_LINE_1': 'B-6655 Airport Road',
#     'ADDRESS_LINE_2': None,
#     'ADDRESS_DESCRIPTOR': None,
#     'COMMUNITY': 'Mississauga',
#     'POSTAL_CODE': 'L4V1V8',
#     'GEOMETRY_UPDATE_DATETIME': 1744234333000,
#     'EFFECTIVE_DATETIME': 1744210099000,
#     'SYSTEM_DATETIME': 1744221299000,
#     'OBJECTID': 2267873}},
#   {'type': 'Feature',
#    'id': 2267889,
#    'geometry': {'type': 'Point',
#     'coordinates': [-75.75303365277082, 45.37621774482332]},
#    'properties': {'OGF_ID': 321017831,
#     'MOH_SERVICE_PROVIDER_IDENT': '1660',
#     'SERVICE_TYPE': 'Long-Term Care Home',
#     'SERVICE_TYPE_DETAIL': 'NH non-profit',
#     'ENGLISH_NAME': 'Hillel Lodge',
#     'FRENCH_NAME': None,
#     'ENGLISH_NAME_ALT': None,
#     'FRENCH_NAME_ALT': None,
#     'ADDRESS_LINE_1': '10 Nadolny Sachs Private',
#     'ADDRESS_LINE_2': None,
#     'ADDRESS_DESCRIPTOR': None,
#     'COMMUNITY': 'Ottawa',
#     'POSTAL_CODE': 'K2A4G7',
#     'GEOMETRY_UPDATE_DATETIME': 1744234649000,
#     'EFFECTIVE_DATETIME': 1744214631000,
#     'SYSTEM_DATETIME': 1744221299000,
#     'OBJECTID': 2267889}},
#   {'type': 'Feature',
#    'id': 2267905,
#    'geometry': {'type': 'Point',
#     'coordinates': [-80.64297907507508, 51.274170604302945]},
#    'properties': {'OGF_ID': 321007320,
#     'MOH_SERVICE_PROVIDER_IDENT': '2896',
#     'SERVICE_TYPE': 'Mental Health and Addiction Organization',
#     'SERVICE_TYPE_DETAIL': 'Addiction Services And Mental Health Services',
#     'ENGLISH_NAME': 'Weeneebayko Area Health Authority',
#     'FRENCH_NAME': None,
#     'ENGLISH_NAME_ALT': None,
#     'FRENCH_NAME_ALT': None,
#     'ADDRESS_LINE_1': '2 Bay Road',
#     'ADDRESS_LINE_2': None,
#     'ADDRESS_DESCRIPTOR': 'Administration And Practice Location',
#     'COMMUNITY': 'Moosonee',
#     'POSTAL_CODE': 'P0L1Y0',
#     'GEOMETRY_UPDATE_DATETIME': 1744234176000,
#     'EFFECTIVE_DATETIME': 1744209148000,
#     'SYSTEM_DATETIME': 1744221299000,
#     'OBJECTID': 2267905}},
#   {'type': 'Feature',
#    'id': 2267921,
#    'geometry': {'type': 'Point',
#     'coordinates': [-79.8076680899409, 43.32228620704034]},
#    'properties': {'OGF_ID': 321014319,
#     'MOH_SERVICE_PROVIDER_IDENT': '6534039',
#     'SERVICE_TYPE': 'Pharmacy',
#     'SERVICE_TYPE_DETAIL': 'Retail Pharmacy',
#     'ENGLISH_NAME': 'Maple IDA Pharmacy',
#     'FRENCH_NAME': None,
#     'ENGLISH_NAME_ALT': None,
#     'FRENCH_NAME_ALT': None,
#     'ADDRESS_LINE_1': '573 Maple Avenue',
#     'ADDRESS_LINE_2': None,
#     'ADDRESS_DESCRIPTOR': None,
#     'COMMUNITY': 'Burlington',
#     'POSTAL_CODE': 'L7S2E8',
#     'GEOMETRY_UPDATE_DATETIME': 1744234511000,
#     'EFFECTIVE_DATETIME': 1744209921000,
#     'SYSTEM_DATETIME': 1744221299000,
#     'OBJECTID': 2267921}},
#   {'type': 'Feature',
#    'id': 2267937,
#    'geometry': {'type': 'Point',
#     'coordinates': [-75.51180758146192, 45.47899407250755]},
#    'properties': {'OGF_ID': 321012483,
#     'MOH_SERVICE_PROVIDER_IDENT': '3384670',
#     'SERVICE_TYPE': 'Pharmacy',
#     'SERVICE_TYPE_DETAIL': 'Retail Pharmacy',
#     'ENGLISH_NAME': 'Pharmacie Centrum Pharmacy Inc',
#     'FRENCH_NAME': None,
#     'ENGLISH_NAME_ALT': None,
#     'FRENCH_NAME_ALT': None,
#     'ADDRESS_LINE_1': '210 Centrum Boulevard Suite 107',
#     'ADDRESS_LINE_2': None,
#     'ADDRESS_DESCRIPTOR': None,
#     'COMMUNITY': 'Orleans',
#     'POSTAL_CODE': 'K1E3V7',
#     'GEOMETRY_UPDATE_DATETIME': 1744234664000,
#     'EFFECTIVE_DATETIME': 1744209716000,
#     'SYSTEM_DATETIME': 1744221299000,
#     'OBJECTID': 2267937}},
#   {'type': 'Feature',
#    'id': 2267953,
#    'geometry': {'type': 'Point',
#     'coordinates': [-79.36123487754199, 43.66005918729368]},
#    'properties': {'OGF_ID': 321007039,
#     'MOH_SERVICE_PROVIDER_IDENT': '2307',
#     'SERVICE_TYPE': 'Mental Health and Addiction Organization',
#     'SERVICE_TYPE_DETAIL': 'Mental Health Services',
#     'ENGLISH_NAME': 'Unity Health Toronto',
#     'FRENCH_NAME': None,
#     'ENGLISH_NAME_ALT': None,
#     'FRENCH_NAME_ALT': None,
#     'ADDRESS_LINE_1': '73 Regent Park Boulevard',
#     'ADDRESS_LINE_2': '3rd Floor',
#     'ADDRESS_DESCRIPTOR': 'Practice Location',
#     'COMMUNITY': 'Toronto',
#     'POSTAL_CODE': 'M5A2B7',
#     'GEOMETRY_UPDATE_DATETIME': 1744234403000,
#     'EFFECTIVE_DATETIME': 1744209116000,
#     'SYSTEM_DATETIME': 1744221299000,
#     'OBJECTID': 2267953}},
#   {'type': 'Feature',
#    'id': 2267969,
#    'geometry': {'type': 'Point',
#     'coordinates': [-79.45016952452077, 43.86985601987992]},
#    'properties': {'OGF_ID': 321009695,
#     'MOH_SERVICE_PROVIDER_IDENT': '701',
#     'SERVICE_TYPE': 'Community Support Service',
#     'SERVICE_TYPE_DETAIL': None,
#     'ENGLISH_NAME': 'Mackenzie Health',
#     'FRENCH_NAME': None,
#     'ENGLISH_NAME_ALT': None,
#     'FRENCH_NAME_ALT': None,
#     'ADDRESS_LINE_1': '10 Trench Street',
#     'ADDRESS_LINE_2': None,
#     'ADDRESS_DESCRIPTOR': None,
#     'COMMUNITY': 'Richmond Hill',
#     'POSTAL_CODE': 'L4C4Z3',
#     'GEOMETRY_UPDATE_DATETIME': 1744234172000,
#     'EFFECTIVE_DATETIME': 1744209406000,
#     'SYSTEM_DATETIME': 1744221299000,
#     'OBJECTID': 2267969}},
#   {'type': 'Feature',
#    'id': 2267985,
#    'geometry': {'type': 'Point',
#     'coordinates': [-75.75406224410835, 45.26988402658037]},
#    'properties': {'OGF_ID': 321017101,
#     'MOH_SERVICE_PROVIDER_IDENT': '9702672',
#     'SERVICE_TYPE': 'Pharmacy',
#     'SERVICE_TYPE_DETAIL': 'Retail Pharmacy',
#     'ENGLISH_NAME': 'Tartan Pharmacy',
#     'FRENCH_NAME': None,
#     'ENGLISH_NAME_ALT': None,
#     'FRENCH_NAME_ALT': None,
#     'ADDRESS_LINE_1': '4-1 Tartan Drive',
#     'ADDRESS_LINE_2': None,
#     'ADDRESS_DESCRIPTOR': None,
#     'COMMUNITY': 'Nepean',
#     'POSTAL_CODE': 'K2J2W7',
#     'GEOMETRY_UPDATE_DATETIME': 1744234325000,
#     'EFFECTIVE_DATETIME': 1744210234000,
#     'SYSTEM_DATETIME': 1744221299000,
#     'OBJECTID': 2267985}},
#   {'type': 'Feature',
#    'id': 2268001,
#    'geometry': {'type': 'Point',
#     'coordinates': [-79.4449532094963, 43.71953139383965]},
#    'properties': {'OGF_ID': 321008716,
#     'MOH_SERVICE_PROVIDER_IDENT': '422143',
#     'SERVICE_TYPE': 'HIV AIDS and Hep C Program',
#     'SERVICE_TYPE_DETAIL': 'At Site, HR Program, HIV POC Testing',
#     'ENGLISH_NAME': 'Unison Health And Community Services',
#     'FRENCH_NAME': None,
#     'ENGLISH_NAME_ALT': None,
#     'FRENCH_NAME_ALT': None,
#     'ADDRESS_LINE_1': '12 Flemington Road',
#     'ADDRESS_LINE_2': None,
#     'ADDRESS_DESCRIPTOR': 'Practice Location',
#     'COMMUNITY': 'Toronto',
#     'POSTAL_CODE': 'M6A2N4',
#     'GEOMETRY_UPDATE_DATETIME': 1744234658000,
#     'EFFECTIVE_DATETIME': 1744209300000,
#     'SYSTEM_DATETIME': 1744221299000,
#     'OBJECTID': 2268001}},
#   {'type': 'Feature',
#    'id': 2268017,
#    'geometry': {'type': 'Point',
#     'coordinates': [-79.63082307953879, 43.840128706230814]},
#    'properties': {'OGF_ID': 321018056,
#     'MOH_SERVICE_PROVIDER_IDENT': '4650',
#     'SERVICE_TYPE': 'Long-Term Care Home',
#     'SERVICE_TYPE_DETAIL': 'NH non-profit',
#     'ENGLISH_NAME': 'Villa Colombo Seniors Centre (Vaughan)',
#     'FRENCH_NAME': None,
#     'ENGLISH_NAME_ALT': None,
#     'FRENCH_NAME_ALT': None,
#     'ADDRESS_LINE_1': '10443 Highway 27, Kleinburg',
#     'ADDRESS_LINE_2': None,
#     'ADDRESS_DESCRIPTOR': None,
#     'COMMUNITY': 'Vaughan',
#     'POSTAL_CODE': 'L0J1C0',
#     'GEOMETRY_UPDATE_DATETIME': 1744234581000,
#     'EFFECTIVE_DATETIME': 1744214629000,
#     'SYSTEM_DATETIME': 1744221299000,
#     'OBJECTID': 2268017}},
#   {'type': 'Feature',
#    'id': 2268033,
#    'geometry': {'type': 'Point',
#     'coordinates': [-79.2031277377414, 43.78165231593952]},
#    'properties': {'OGF_ID': 321011471,
#     'MOH_SERVICE_PROVIDER_IDENT': '1048459',
#     'SERVICE_TYPE': 'Pharmacy',
#     'SERVICE_TYPE_DETAIL': 'Long Term Care Facility',
#     'ENGLISH_NAME': 'Seven Oaks Home For The Aged',
#     'FRENCH_NAME': None,
#     'ENGLISH_NAME_ALT': None,
#     'FRENCH_NAME_ALT': None,
#     'ADDRESS_LINE_1': '9 Neilson Road',
#     'ADDRESS_LINE_2': None,
#     'ADDRESS_DESCRIPTOR': None,
#     'COMMUNITY': 'Scarborough',
#     'POSTAL_CODE': 'M1E5E1',
#     'GEOMETRY_UPDATE_DATETIME': 1744234599000,
#     'EFFECTIVE_DATETIME': 1744209602000,
#     'SYSTEM_DATETIME': 1744221299000,
#     'OBJECTID': 2268033}},
#   {'type': 'Feature',
#    'id': 2268049,
#    'geometry': {'type': 'Point',
#     'coordinates': [-79.87114272751477, 43.520254038955045]},
#    'properties': {'OGF_ID': 321016667,
#     'MOH_SERVICE_PROVIDER_IDENT': '9368917',
#     'SERVICE_TYPE': 'Pharmacy',
#     'SERVICE_TYPE_DETAIL': 'Retail Pharmacy',
#     'ENGLISH_NAME': 'Nipissing Phcy & Med Clinic',
#     'FRENCH_NAME': None,
#     'ENGLISH_NAME_ALT': None,
#     'FRENCH_NAME_ALT': None,
#     'ADDRESS_LINE_1': '5-150 Nipissing Road',
#     'ADDRESS_LINE_2': None,
#     'ADDRESS_DESCRIPTOR': None,
#     'COMMUNITY': 'Milton',
#     'POSTAL_CODE': 'L9T5B3',
#     'GEOMETRY_UPDATE_DATETIME': 1744234288000,
#     'EFFECTIVE_DATETIME': 1744210184000,
#     'SYSTEM_DATETIME': 1744221299000,
#     'OBJECTID': 2268049}},
#   {'type': 'Feature',
#    'id': 2268065,
#    'geometry': {'type': 'Point',
#     'coordinates': [-76.507228505811, 44.238907515699545]},
#    'properties': {'OGF_ID': 321014082,
#     'MOH_SERVICE_PROVIDER_IDENT': '6179011',
#     'SERVICE_TYPE': 'Pharmacy',
#     'SERVICE_TYPE_DETAIL': 'Retail Pharmacy',
#     'ENGLISH_NAME': 'Medical Arts Pharmacy',
#     'FRENCH_NAME': None,
#     'ENGLISH_NAME_ALT': None,
#     'FRENCH_NAME_ALT': None,
#     'ADDRESS_LINE_1': '800 Princess Street',
#     'ADDRESS_LINE_2': None,
#     'ADDRESS_DESCRIPTOR': None,
#     'COMMUNITY': 'Kingston',
#     'POSTAL_CODE': 'K7L1E4',
#     'GEOMETRY_UPDATE_DATETIME': 1744234500000,
#     'EFFECTIVE_DATETIME': 1744209894000,
#     'SYSTEM_DATETIME': 1744221299000,
#     'OBJECTID': 2268065}},
#   {'type': 'Feature',
#    'id': 2268081,
#    'geometry': {'type': 'Point',
#     'coordinates': [-79.42463021224985, 43.82371161301529]},
#    'properties': {'OGF_ID': 321012751,
#     'MOH_SERVICE_PROVIDER_IDENT': '398670',
#     'SERVICE_TYPE': 'Pharmacy',
#     'SERVICE_TYPE_DETAIL': 'Retail Pharmacy',
#     'ENGLISH_NAME': 'Shoppers Drug Mart #657',
#     'FRENCH_NAME': None,
#     'ENGLISH_NAME_ALT': None,
#     'FRENCH_NAME_ALT': None,
#     'ADDRESS_LINE_1': '10 Royal Orchard Boulevard',
#     'ADDRESS_LINE_2': None,
#     'ADDRESS_DESCRIPTOR': None,
#     'COMMUNITY': 'Thornhill',
#     'POSTAL_CODE': 'L3T3C3',
#     'GEOMETRY_UPDATE_DATETIME': 1744234457000,
#     'EFFECTIVE_DATETIME': 1744209747000,
#     'SYSTEM_DATETIME': 1744221299000,
#     'OBJECTID': 2268081}},
#   {'type': 'Feature',
#    'id': 2268097,
#    'geometry': {'type': 'Point',
#     'coordinates': [-75.7421900408291, 45.277587328400415]},
#    'properties': {'OGF_ID': 321010806,
#     'MOH_SERVICE_PROVIDER_IDENT': 'N0394',
#     'SERVICE_TYPE': 'Licensed Retirement Home',
#     'SERVICE_TYPE_DETAIL': None,
#     'ENGLISH_NAME': 'Barrhaven Manor',
#     'FRENCH_NAME': None,
#     'ENGLISH_NAME_ALT': None,
#     'FRENCH_NAME_ALT': None,
#     'ADDRESS_LINE_1': '110 Berrigan Drive',
#     'ADDRESS_LINE_2': None,
#     'ADDRESS_DESCRIPTOR': None,
#     'COMMUNITY': 'Ottawa',
#     'POSTAL_CODE': 'K2J5A6',
#     'GEOMETRY_UPDATE_DATETIME': 1744234240000,
#     'EFFECTIVE_DATETIME': 1744209526000,
#     'SYSTEM_DATETIME': 1744221299000,
#     'OBJECTID': 2268097}},
#   {'type': 'Feature',
#    'id': 2268113,
#    'geometry': {'type': 'Point',
#     'coordinates': [-79.47554591746572, 43.69929948887006]},
#    'properties': {'OGF_ID': 321009875,
#     'MOH_SERVICE_PROVIDER_IDENT': '8100003',
#     'SERVICE_TYPE': 'Integrated Community Health Services Centre',
#     'SERVICE_TYPE_DETAIL': 'Fluoroscopy, Radiography, General Ultrasound',
#     'ENGLISH_NAME': 'Northwest Imaging Associates',
#     'FRENCH_NAME': None,
#     'ENGLISH_NAME_ALT': '2352898 Ontario Inc.',
#     'FRENCH_NAME_ALT': None,
#     'ADDRESS_LINE_1': '2221 Keele Street',
#     'ADDRESS_LINE_2': 'Suite 106',
#     'ADDRESS_DESCRIPTOR': None,
#     'COMMUNITY': 'North York',
#     'POSTAL_CODE': 'M6M3Z5',
#     'GEOMETRY_UPDATE_DATETIME': 1744234405000,
#     'EFFECTIVE_DATETIME': 1744209426000,
#     'SYSTEM_DATETIME': 1744221299000,
#     'OBJECTID': 2268113}},
#   {'type': 'Feature',
#    'id': 2268129,
#    'geometry': {'type': 'Point',
#     'coordinates': [-79.5076464210025, 43.62345107406832]},
#    'properties': {'OGF_ID': 321014699,
#     'MOH_SERVICE_PROVIDER_IDENT': '7048358',
#     'SERVICE_TYPE': 'Pharmacy',
#     'SERVICE_TYPE_DETAIL': 'Retail Pharmacy',
#     'ENGLISH_NAME': 'Costco Pharmacy #524',
#     'FRENCH_NAME': None,
#     'ENGLISH_NAME_ALT': None,
#     'FRENCH_NAME_ALT': None,
#     'ADDRESS_LINE_1': '50 Queen Elizabeth Boulevard',
#     'ADDRESS_LINE_2': None,
#     'ADDRESS_DESCRIPTOR': None,
#     'COMMUNITY': 'Etobicoke',
#     'POSTAL_CODE': 'M8Z1M1',
#     'GEOMETRY_UPDATE_DATETIME': 1744234572000,
#     'EFFECTIVE_DATETIME': 1744209963000,
#     'SYSTEM_DATETIME': 1744221299000,
#     'OBJECTID': 2268129}},
#   {'type': 'Feature',
#    'id': 2268145,
#    'geometry': {'type': 'Point',
#     'coordinates': [-79.7884330863995, 43.35155381310772]},
#    'properties': {'OGF_ID': 321012603,
#     'MOH_SERVICE_PROVIDER_IDENT': '3631957',
#     'SERVICE_TYPE': 'Pharmacy',
#     'SERVICE_TYPE_DETAIL': 'Retail Pharmacy',
#     'ENGLISH_NAME': 'Chez Pharmacy',
#     'FRENCH_NAME': None,
#     'ENGLISH_NAME_ALT': None,
#     'FRENCH_NAME_ALT': None,
#     'ADDRESS_LINE_1': '3230 Fairview Street',
#     'ADDRESS_LINE_2': '#2006',
#     'ADDRESS_DESCRIPTOR': None,
#     'COMMUNITY': 'Burlington',
#     'POSTAL_CODE': 'L7N3H5',
#     'GEOMETRY_UPDATE_DATETIME': 1744234619000,
#     'EFFECTIVE_DATETIME': 1744209730000,
#     'SYSTEM_DATETIME': 1744221299000,
#     'OBJECTID': 2268145}},
#   {'type': 'Feature',
#    'id': 2268161,
#    'geometry': {'type': 'Point',
#     'coordinates': [-82.61512945514836, 42.05057104636631]},
#    'properties': {'OGF_ID': 321008178,
#     'MOH_SERVICE_PROVIDER_IDENT': '3812',
#     'SERVICE_TYPE': 'Licensed Lab and Specimen Collection Centre',
#     'SERVICE_TYPE_DETAIL': 'Licensed Specimen Collection Centre Location',
#     'ENGLISH_NAME': 'Medical Laboratories Of Windsor Limited',
#     'FRENCH_NAME': None,
#     'ENGLISH_NAME_ALT': None,
#     'FRENCH_NAME_ALT': None,
#     'ADDRESS_LINE_1': '197 Talbot Street West',
#     'ADDRESS_LINE_2': None,
#     'ADDRESS_DESCRIPTOR': 'Practice Address',
#     'COMMUNITY': 'Leamington',
#     'POSTAL_CODE': 'N8H1N8',
#     'GEOMETRY_UPDATE_DATETIME': 1744234687000,
#     'EFFECTIVE_DATETIME': 1744209242000,
#     'SYSTEM_DATETIME': 1744221299000,
#     'OBJECTID': 2268161}},
#   {'type': 'Feature',
#    'id': 2268177,
#    'geometry': {'type': 'Point',
#     'coordinates': [-79.59449315915548, 43.741675090738404]},
#    'properties': {'OGF_ID': 321012929,
#     'MOH_SERVICE_PROVIDER_IDENT': '4313576',
#     'SERVICE_TYPE': 'Pharmacy',
#     'SERVICE_TYPE_DETAIL': 'Retail Pharmacy',
#     'ENGLISH_NAME': 'Albion Martingrove Pharmacy',
#     'FRENCH_NAME': None,
#     'ENGLISH_NAME_ALT': None,
#     'FRENCH_NAME_ALT': None,
#     'ADDRESS_LINE_1': '1625 Albion Road',
#     'ADDRESS_LINE_2': None,
#     'ADDRESS_DESCRIPTOR': None,
#     'COMMUNITY': 'Etobicoke',
#     'POSTAL_CODE': 'M9V5H8',
#     'GEOMETRY_UPDATE_DATETIME': 1744234444000,
#     'EFFECTIVE_DATETIME': 1744209767000,
#     'SYSTEM_DATETIME': 1744221299000,
#     'OBJECTID': 2268177}},
#   {'type': 'Feature',
#    'id': 2268193,
#    'geometry': {'type': 'Point',
#     'coordinates': [-75.76877135740718, 45.36941674299701]},
#    'properties': {'OGF_ID': 321007755,
#     'MOH_SERVICE_PROVIDER_IDENT': '3180971',
#     'SERVICE_TYPE': 'Integrated Community Health Services Centre',
#     'SERVICE_TYPE_DETAIL': 'Ophthalmic Ultrasound',
#     'ENGLISH_NAME': 'Icare Surgical Centre',
#     'FRENCH_NAME': None,
#     'ENGLISH_NAME_ALT': 'Bhatti Medicine Professional Corporation',
#     'FRENCH_NAME_ALT': None,
#     'ADDRESS_LINE_1': '2148 Carling Avenue',
#     'ADDRESS_LINE_2': 'Suite 205',
#     'ADDRESS_DESCRIPTOR': None,
#     'COMMUNITY': 'Ottawa',
#     'POSTAL_CODE': 'K2A1H1',
#     'GEOMETRY_UPDATE_DATETIME': 1744234226000,
#     'EFFECTIVE_DATETIME': 1744209196000,
#     'SYSTEM_DATETIME': 1744221299000,
#     'OBJECTID': 2268193}},
#   {'type': 'Feature',
#    'id': 2268209,
#    'geometry': {'type': 'Point',
#     'coordinates': [-91.92542598342531, 50.10601598436745]},
#    'properties': {'OGF_ID': 321017534,
#     'MOH_SERVICE_PROVIDER_IDENT': '9640',
#     'SERVICE_TYPE': 'Hospital',
#     'SERVICE_TYPE_DETAIL': 'Corporation',
#     'ENGLISH_NAME': 'Sioux Lookout Meno Ya Win Health Centre - Lookout District',
#     'FRENCH_NAME': None,
#     'ENGLISH_NAME_ALT': 'Sioux Lookout Meno Ya Win Health Centre',
#     'FRENCH_NAME_ALT': None,
#     'ADDRESS_LINE_1': '1 Meno Ya Win Way',
#     'ADDRESS_LINE_2': None,
#     'ADDRESS_DESCRIPTOR': None,
#     'COMMUNITY': 'Sioux Lookout',
#     'POSTAL_CODE': 'P8T1B4',
#     'GEOMETRY_UPDATE_DATETIME': 1744234550000,
#     'EFFECTIVE_DATETIME': 1744210282000,
#     'SYSTEM_DATETIME': 1744221299000,
#     'OBJECTID': 2268209}},
#   {'type': 'Feature',
#    'id': 2268225,
#    'geometry': {'type': 'Point',
#     'coordinates': [-76.67734870743138, 44.78943760446653]},
#    'properties': {'OGF_ID': 321009481,
#     'MOH_SERVICE_PROVIDER_IDENT': '5846',
#     'SERVICE_TYPE': 'Mental Health and Addiction Organization',
#     'SERVICE_TYPE_DETAIL': 'Mental Health Services',
#     'ENGLISH_NAME': 'Maltby Centre, The',
#     'FRENCH_NAME': None,
#     'ENGLISH_NAME_ALT': None,
#     'FRENCH_NAME_ALT': None,
#     'ADDRESS_LINE_1': '1004 Art Duffy Road',
#     'ADDRESS_LINE_2': 'The Child Centre; Rr 1',
#     'ADDRESS_DESCRIPTOR': 'Practice Location',
#     'COMMUNITY': 'Sharbot Lake',
#     'POSTAL_CODE': 'K0H2P0',
#     'GEOMETRY_UPDATE_DATETIME': 1744234701000,
#     'EFFECTIVE_DATETIME': 1744209383000,
#     'SYSTEM_DATETIME': 1744221299000,
#     'OBJECTID': 2268225}},
#   {'type': 'Feature',
#    'id': 2268241,
#    'geometry': {'type': 'Point',
#     'coordinates': [-79.34788898372828, 43.77852540868418]},
#    'properties': {'OGF_ID': 321006842,
#     'MOH_SERVICE_PROVIDER_IDENT': '20201',
#     'SERVICE_TYPE': 'Community Health Centre',
#     'SERVICE_TYPE_DETAIL': 'Satellite',
#     'ENGLISH_NAME': 'The Centre Francophone Du Grand Toronto Medical Clinic',
#     'FRENCH_NAME': 'The Centre Francophone Du Grand Toronto Medical Clinic',
#     'ENGLISH_NAME_ALT': None,
#     'FRENCH_NAME_ALT': None,
#     'ADDRESS_LINE_1': '5 Fairview Mall Road, Suite 280',
#     'ADDRESS_LINE_2': None,
#     'ADDRESS_DESCRIPTOR': None,
#     'COMMUNITY': 'North York',
#     'POSTAL_CODE': 'M2J2Z1',
#     'GEOMETRY_UPDATE_DATETIME': 1744234614000,
#     'EFFECTIVE_DATETIME': 1744209095000,
#     'SYSTEM_DATETIME': 1744221299000,
#     'OBJECTID': 2268241}},
#   {'type': 'Feature',
#    'id': 2268257,
#    'geometry': {'type': 'Point',
#     'coordinates': [-79.56611008361755, 44.114241356904635]},
#    'properties': {'OGF_ID': 321016975,
#     'MOH_SERVICE_PROVIDER_IDENT': '9618513',
#     'SERVICE_TYPE': 'Pharmacy',
#     'SERVICE_TYPE_DETAIL': 'Retail Pharmacy',
#     'ENGLISH_NAME': 'Milan Pharmacy',
#     'FRENCH_NAME': None,
#     'ENGLISH_NAME_ALT': None,
#     'FRENCH_NAME_ALT': None,
#     'ADDRESS_LINE_1': '37 Holland Street West',
#     'ADDRESS_LINE_2': None,
#     'ADDRESS_DESCRIPTOR': None,
#     'COMMUNITY': 'Bradford',
#     'POSTAL_CODE': 'L3Z2B9',
#     'GEOMETRY_UPDATE_DATETIME': 1744234284000,
#     'EFFECTIVE_DATETIME': 1744210219000,
#     'SYSTEM_DATETIME': 1744221299000,
#     'OBJECTID': 2268257}},
#   {'type': 'Feature',
#    'id': 2268273,
#    'geometry': {'type': 'Point',
#     'coordinates': [-80.95805970360927, 42.7641740538486]},
#    'properties': {'OGF_ID': 321015184,
#     'MOH_SERVICE_PROVIDER_IDENT': '7675018',
#     'SERVICE_TYPE': 'Pharmacy',
#     'SERVICE_TYPE_DETAIL': 'Long Term Care Facility',
#     'ENGLISH_NAME': 'Country Terrace',
#     'FRENCH_NAME': None,
#     'ENGLISH_NAME_ALT': None,
#     'FRENCH_NAME_ALT': None,
#     'ADDRESS_LINE_1': 'Rural Route 3',
#     'ADDRESS_LINE_2': None,
#     'ADDRESS_DESCRIPTOR': None,
#     'COMMUNITY': 'Komoka',
#     'POSTAL_CODE': 'N0L1R0',
#     'GEOMETRY_UPDATE_DATETIME': 1744234362000,
#     'EFFECTIVE_DATETIME': 1744210018000,
#     'SYSTEM_DATETIME': 1744221299000,
#     'OBJECTID': 2268273}},
#   {'type': 'Feature',
#    'id': 2268289,
#    'geometry': {'type': 'Point',
#     'coordinates': [-80.14412305895615, 42.89166001489364]},
#    'properties': {'OGF_ID': 321007134,
#     'MOH_SERVICE_PROVIDER_IDENT': '247',
#     'SERVICE_TYPE': 'Mental Health and Addiction Organization',
#     'SERVICE_TYPE_DETAIL': 'Mental Health Services',
#     'ENGLISH_NAME': 'Haldimand-Norfolk Reach',
#     'FRENCH_NAME': None,
#     'ENGLISH_NAME_ALT': None,
#     'FRENCH_NAME_ALT': None,
#     'ADDRESS_LINE_1': '101A Nanticoke Creek Parkway',
#     'ADDRESS_LINE_2': None,
#     'ADDRESS_DESCRIPTOR': 'Administration And Practice Location',
#     'COMMUNITY': 'Townsend',
#     'POSTAL_CODE': 'N0A1S0',
#     'GEOMETRY_UPDATE_DATETIME': 1744234437000,
#     'EFFECTIVE_DATETIME': 1744209127000,
#     'SYSTEM_DATETIME': 1744221299000,
#     'OBJECTID': 2268289}},
#   {'type': 'Feature',
#    'id': 2268305,
#    'geometry': {'type': 'Point',
#     'coordinates': [-81.22555500457369, 42.958335575449496]},
#    'properties': {'OGF_ID': 321017456,
#     'MOH_SERVICE_PROVIDER_IDENT': '9360',
#     'SERVICE_TYPE': 'Hospital',
#     'SERVICE_TYPE_DETAIL': 'Corporation',
#     'ENGLISH_NAME': 'London Health Sciences Centre - Victoria',
#     'FRENCH_NAME': None,
#     'ENGLISH_NAME_ALT': 'London Health Sciences Centre',
#     'FRENCH_NAME_ALT': None,
#     'ADDRESS_LINE_1': '800 Commissioners Road East',
#     'ADDRESS_LINE_2': None,
#     'ADDRESS_DESCRIPTOR': None,
#     'COMMUNITY': 'London',
#     'POSTAL_CODE': 'N6A5W9',
#     'GEOMETRY_UPDATE_DATETIME': 1744234586000,
#     'EFFECTIVE_DATETIME': 1744210273000,
#     'SYSTEM_DATETIME': 1744221299000,
#     'OBJECTID': 2268305}},
#   {'type': 'Feature',
#    'id': 2268321,
#    'geometry': {'type': 'Point',
#     'coordinates': [-80.99563556952064, 43.36947385885172]},
#    'properties': {'OGF_ID': 321010079,
#     'MOH_SERVICE_PROVIDER_IDENT': '9000000060',
#     'SERVICE_TYPE': 'Midwifery Clinic',
#     'SERVICE_TYPE_DETAIL': 'Main',
#     'ENGLISH_NAME': 'Stratford Midwives',
#     'FRENCH_NAME': None,
#     'ENGLISH_NAME_ALT': None,
#     'FRENCH_NAME_ALT': None,
#     'ADDRESS_LINE_1': '386 Cambria Street',
#     'ADDRESS_LINE_2': None,
#     'ADDRESS_DESCRIPTOR': 'Practice Location',
#     'COMMUNITY': 'Stratford',
#     'POSTAL_CODE': 'N5A1J4',
#     'GEOMETRY_UPDATE_DATETIME': 1744234541000,
#     'EFFECTIVE_DATETIME': 1744209449000,
#     'SYSTEM_DATETIME': 1744221299000,
#     'OBJECTID': 2268321}},
#   {'type': 'Feature',
#    'id': 2268337,
#    'geometry': {'type': 'Point',
#     'coordinates': [-80.21621692779156, 44.50288149244803]},
#    'properties': {'OGF_ID': 321007505,
#     'MOH_SERVICE_PROVIDER_IDENT': '3067',
#     'SERVICE_TYPE': 'Licensed Lab and Specimen Collection Centre',
#     'SERVICE_TYPE_DETAIL': 'Licensed Specimen Collection Centre Location',
#     'ENGLISH_NAME': 'Alpha Laboratories',
#     'FRENCH_NAME': None,
#     'ENGLISH_NAME_ALT': None,
#     'FRENCH_NAME_ALT': None,
#     'ADDRESS_LINE_1': '28 Huron Street Suite 102',
#     'ADDRESS_LINE_2': None,
# ...
#    'properties': {'OGF_ID': 321013339,
#     'MOH_SERVICE_PROVIDER_IDENT': '5036837',
#     'SERVICE_TYPE': 'Pharmacy',
#     'SERVICE_TYPE_DETAIL': 'Long Term Care Facility',
#     'ENGLISH_NAME': 'Extendicare/Brampton',
#     'FRENCH_NAME': None,
#     'ENGLISH_NAME_ALT': None,
#     'FRENCH_NAME_ALT': None,
#     'ADDRESS_LINE_1': '7891 Mclaughlin Road',
#     'ADDRESS_LINE_2': None,
#     'ADDRESS_DESCRIPTOR': None,
#     'COMMUNITY': 'Brampton',
#     'POSTAL_CODE': 'L6V3N2',
#     'GEOMETRY_UPDATE_DATETIME': 1744234475000,
#     'EFFECTIVE_DATETIME': 1744209812000,
#     'SYSTEM_DATETIME': 1744221299000,
#     'OBJECTID': 2272801}},
#   {'type': 'Feature',
#    'id': 2272817,
#    'geometry': {'type': 'Point',
#     'coordinates': [-79.72498689343605, 43.65976697028731]},
#    'properties': {'OGF_ID': 321007908,
#     'MOH_SERVICE_PROVIDER_IDENT': '3431',
#     'SERVICE_TYPE': 'Mental Health and Addiction Organization',
#     'SERVICE_TYPE_DETAIL': 'Mental Health Services',
#     'ENGLISH_NAME': 'Reconnect Community Health Services',
#     'FRENCH_NAME': None,
#     'ENGLISH_NAME_ALT': None,
#     'FRENCH_NAME_ALT': None,
#     'ADDRESS_LINE_1': '7700 Hurontario Street',
#     'ADDRESS_LINE_2': 'Suite: 601',
#     'ADDRESS_DESCRIPTOR': 'Practice Location',
#     'COMMUNITY': 'Brampton',
#     'POSTAL_CODE': 'L6Y4M3',
#     'GEOMETRY_UPDATE_DATETIME': 1744234588000,
#     'EFFECTIVE_DATETIME': 1744209213000,
#     'SYSTEM_DATETIME': 1744221299000,
#     'OBJECTID': 2272817}},
#   {'type': 'Feature',
#    'id': 2272833,
#    'geometry': {'type': 'Point',
#     'coordinates': [-75.68729753311985, 45.40138755189371]},
#    'properties': {'OGF_ID': 321014359,
#     'MOH_SERVICE_PROVIDER_IDENT': '6583636',
#     'SERVICE_TYPE': 'Pharmacy',
#     'SERVICE_TYPE_DETAIL': 'Retail Pharmacy',
#     'ENGLISH_NAME': 'Whole Health Pharmacy Glebe',
#     'FRENCH_NAME': None,
#     'ENGLISH_NAME_ALT': None,
#     'FRENCH_NAME_ALT': None,
#     'ADDRESS_LINE_1': '857A Bank Street',
#     'ADDRESS_LINE_2': None,
#     'ADDRESS_DESCRIPTOR': None,
#     'COMMUNITY': 'Ottawa',
#     'POSTAL_CODE': 'K1S3W2',
#     'GEOMETRY_UPDATE_DATETIME': 1744234557000,
#     'EFFECTIVE_DATETIME': 1744209926000,
#     'SYSTEM_DATETIME': 1744221299000,
#     'OBJECTID': 2272833}},
#   {'type': 'Feature',
#    'id': 2272849,
#    'geometry': {'type': 'Point',
#     'coordinates': [-75.68888103623168, 45.431856957029304]},
#    'properties': {'OGF_ID': 321007317,
#     'MOH_SERVICE_PROVIDER_IDENT': '2889',
#     'SERVICE_TYPE': 'Mental Health and Addiction Organization',
#     'SERVICE_TYPE_DETAIL': 'Mental Health Services',
#     'ENGLISH_NAME': 'Shepherds Of Good Hope',
#     'FRENCH_NAME': None,
#     'ENGLISH_NAME_ALT': None,
#     'FRENCH_NAME_ALT': None,
#     'ADDRESS_LINE_1': '233 Murray Street',
#     'ADDRESS_LINE_2': None,
#     'ADDRESS_DESCRIPTOR': 'Administration And Practice Location',
#     'COMMUNITY': 'Ottawa',
#     'POSTAL_CODE': 'K1N5M9',
#     'GEOMETRY_UPDATE_DATETIME': 1744234704000,
#     'EFFECTIVE_DATETIME': 1744209147000,
#     'SYSTEM_DATETIME': 1744221299000,
#     'OBJECTID': 2272849}},
#   {'type': 'Feature',
#    'id': 2272865,
#    'geometry': {'type': 'Point',
#     'coordinates': [-79.824027731721, 43.73542197886343]},
#    'properties': {'OGF_ID': 321016477,
#     'MOH_SERVICE_PROVIDER_IDENT': '9206110',
#     'SERVICE_TYPE': 'Pharmacy',
#     'SERVICE_TYPE_DETAIL': 'Retail Pharmacy',
#     'ENGLISH_NAME': 'Mayfield Pharmacare',
#     'FRENCH_NAME': None,
#     'ENGLISH_NAME_ALT': None,
#     'FRENCH_NAME_ALT': None,
#     'ADDRESS_LINE_1': '3068 Mayfield Road',
#     'ADDRESS_LINE_2': 'Units 8&9',
#     'ADDRESS_DESCRIPTOR': None,
#     'COMMUNITY': 'Brampton',
#     'POSTAL_CODE': 'L6Z0E3',
#     'GEOMETRY_UPDATE_DATETIME': 1744234630000,
#     'EFFECTIVE_DATETIME': 1744210163000,
#     'SYSTEM_DATETIME': 1744221299000,
#     'OBJECTID': 2272865}},
#   {'type': 'Feature',
#    'id': 2272881,
#    'geometry': {'type': 'Point',
#     'coordinates': [-79.62613485553796, 43.58718396217913]},
#    'properties': {'OGF_ID': 321015387,
#     'MOH_SERVICE_PROVIDER_IDENT': '7983319',
#     'SERVICE_TYPE': 'Pharmacy',
#     'SERVICE_TYPE_DETAIL': 'Retail Pharmacy',
#     'ENGLISH_NAME': 'Fairview Medical Pharmacy',
#     'FRENCH_NAME': None,
#     'ENGLISH_NAME_ALT': None,
#     'FRENCH_NAME_ALT': None,
#     'ADDRESS_LINE_1': '12-3355 Hurontario Street',
#     'ADDRESS_LINE_2': None,
#     'ADDRESS_DESCRIPTOR': None,
#     'COMMUNITY': 'Mississauga',
#     'POSTAL_CODE': 'L5A4E7',
#     'GEOMETRY_UPDATE_DATETIME': 1744234268000,
#     'EFFECTIVE_DATETIME': 1744210040000,
#     'SYSTEM_DATETIME': 1744221299000,
#     'OBJECTID': 2272881}},
#   {'type': 'Feature',
#    'id': 2272897,
#    'geometry': {'type': 'Point',
#     'coordinates': [-81.23595281043816, 42.98744998008784]},
#    'properties': {'OGF_ID': 321016867,
#     'MOH_SERVICE_PROVIDER_IDENT': '9547911',
#     'SERVICE_TYPE': 'Pharmacy',
#     'SERVICE_TYPE_DETAIL': 'Retail Pharmacy',
#     'ENGLISH_NAME': 'Pharmasave Dundas Street',
#     'FRENCH_NAME': None,
#     'ENGLISH_NAME_ALT': None,
#     'FRENCH_NAME_ALT': None,
#     'ADDRESS_LINE_1': '1-493-495 Dundas Street',
#     'ADDRESS_LINE_2': None,
#     'ADDRESS_DESCRIPTOR': None,
#     'COMMUNITY': 'London',
#     'POSTAL_CODE': 'N6B1W4',
#     'GEOMETRY_UPDATE_DATETIME': 1744234355000,
#     'EFFECTIVE_DATETIME': 1744210207000,
#     'SYSTEM_DATETIME': 1744221299000,
#     'OBJECTID': 2272897}},
#   {'type': 'Feature',
#    'id': 2272913,
#    'geometry': {'type': 'Point',
#     'coordinates': [-79.40219158941336, 43.646487183011686]},
#    'properties': {'OGF_ID': 321006208,
#     'MOH_SERVICE_PROVIDER_IDENT': '101034',
#     'SERVICE_TYPE': 'HIV AIDS and Hep C Program',
#     'SERVICE_TYPE_DETAIL': 'CBAESP, HCV Service',
#     'ENGLISH_NAME': 'Canadian AIDS Treatment Information Exchange',
#     'FRENCH_NAME': None,
#     'ENGLISH_NAME_ALT': None,
#     'FRENCH_NAME_ALT': None,
#     'ADDRESS_LINE_1': '555 Richmond Street West',
#     'ADDRESS_LINE_2': 'Suite 505, P.O. Box 1104',
#     'ADDRESS_DESCRIPTOR': 'Practice Location',
#     'COMMUNITY': 'Toronto',
#     'POSTAL_CODE': 'M5V3B1',
#     'GEOMETRY_UPDATE_DATETIME': 1744234443000,
#     'EFFECTIVE_DATETIME': 1744209015000,
#     'SYSTEM_DATETIME': 1744221299000,
#     'OBJECTID': 2272913}},
#   {'type': 'Feature',
#    'id': 2272929,
#    'geometry': {'type': 'Point',
#     'coordinates': [-79.43782791002327, 43.75116679971216]},
#    'properties': {'OGF_ID': 321015728,
#     'MOH_SERVICE_PROVIDER_IDENT': '83901',
#     'SERVICE_TYPE': 'Pharmacy',
#     'SERVICE_TYPE_DETAIL': 'Retail Pharmacy',
#     'ENGLISH_NAME': 'Sunshine Drugs Bathurst',
#     'FRENCH_NAME': None,
#     'ENGLISH_NAME_ALT': None,
#     'FRENCH_NAME_ALT': None,
#     'ADDRESS_LINE_1': '108-4256 Bathurst Street',
#     'ADDRESS_LINE_2': None,
#     'ADDRESS_DESCRIPTOR': None,
#     'COMMUNITY': 'North York',
#     'POSTAL_CODE': 'M3H5Y8',
#     'GEOMETRY_UPDATE_DATETIME': 1744234641000,
#     'EFFECTIVE_DATETIME': 1744210078000,
#     'SYSTEM_DATETIME': 1744221299000,
#     'OBJECTID': 2272929}},
#   {'type': 'Feature',
#    'id': 2272945,
#    'geometry': {'type': 'Point',
#     'coordinates': [-79.383091884996, 43.66552788724098]},
#    'properties': {'OGF_ID': 321016521,
#     'MOH_SERVICE_PROVIDER_IDENT': '9246032',
#     'SERVICE_TYPE': 'Pharmacy',
#     'SERVICE_TYPE_DETAIL': 'Retail Pharmacy',
#     'ENGLISH_NAME': 'Srx Pharmacy',
#     'FRENCH_NAME': None,
#     'ENGLISH_NAME_ALT': None,
#     'FRENCH_NAME_ALT': None,
#     'ADDRESS_LINE_1': '34 Wellesley Street East',
#     'ADDRESS_LINE_2': None,
#     'ADDRESS_DESCRIPTOR': None,
#     'COMMUNITY': 'Toronto',
#     'POSTAL_CODE': 'M4Y1G7',
#     'GEOMETRY_UPDATE_DATETIME': 1744234405000,
#     'EFFECTIVE_DATETIME': 1744210168000,
#     'SYSTEM_DATETIME': 1744221299000,
#     'OBJECTID': 2272945}},
#   {'type': 'Feature',
#    'id': 2272961,
#    'geometry': {'type': 'Point',
#     'coordinates': [-82.71996060904969, 42.2936024845567]},
#    'properties': {'OGF_ID': 321011013,
#     'MOH_SERVICE_PROVIDER_IDENT': 'S0157',
#     'SERVICE_TYPE': 'Licensed Retirement Home',
#     'SERVICE_TYPE_DETAIL': None,
#     'ENGLISH_NAME': 'Seasons Belle River',
#     'FRENCH_NAME': None,
#     'ENGLISH_NAME_ALT': None,
#     'FRENCH_NAME_ALT': None,
#     'ADDRESS_LINE_1': '1700 County Road #22',
#     'ADDRESS_LINE_2': None,
#     'ADDRESS_DESCRIPTOR': None,
#     'COMMUNITY': 'Belle River',
#     'POSTAL_CODE': 'N0R1A0',
#     'GEOMETRY_UPDATE_DATETIME': 1744234200000,
#     'EFFECTIVE_DATETIME': 1744209550000,
#     'SYSTEM_DATETIME': 1744221299000,
#     'OBJECTID': 2272961}},
#   {'type': 'Feature',
#    'id': 2272977,
#    'geometry': {'type': 'Point',
#     'coordinates': [-79.85053659703405, 43.24786669187867]},
#    'properties': {'OGF_ID': 321013745,
#     'MOH_SERVICE_PROVIDER_IDENT': '5694858',
#     'SERVICE_TYPE': 'Pharmacy',
#     'SERVICE_TYPE_DETAIL': 'Long Term Care Facility',
#     'ENGLISH_NAME': 'Hamilton Continuing Care',
#     'FRENCH_NAME': None,
#     'ENGLISH_NAME_ALT': None,
#     'FRENCH_NAME_ALT': None,
#     'ADDRESS_LINE_1': '125 Wentworth Street South',
#     'ADDRESS_LINE_2': None,
#     'ADDRESS_DESCRIPTOR': None,
#     'COMMUNITY': 'Hamilton',
#     'POSTAL_CODE': 'L8N2Z1',
#     'GEOMETRY_UPDATE_DATETIME': 1744234541000,
#     'EFFECTIVE_DATETIME': 1744209857000,
#     'SYSTEM_DATETIME': 1744221299000,
#     'OBJECTID': 2272977}},
#   {'type': 'Feature',
#    'id': 2272993,
#    'geometry': {'type': 'Point',
#     'coordinates': [-79.78945157644723, 43.23373149221625]},
#    'properties': {'OGF_ID': 321012792,
#     'MOH_SERVICE_PROVIDER_IDENT': '4074192',
#     'SERVICE_TYPE': 'Pharmacy',
#     'SERVICE_TYPE_DETAIL': 'Retail Pharmacy',
#     'ENGLISH_NAME': 'The Hamilton Pharmacy',
#     'FRENCH_NAME': None,
#     'ENGLISH_NAME_ALT': None,
#     'FRENCH_NAME_ALT': None,
#     'ADDRESS_LINE_1': '335 Queenston Road',
#     'ADDRESS_LINE_2': None,
#     'ADDRESS_DESCRIPTOR': None,
#     'COMMUNITY': 'Hamilton',
#     'POSTAL_CODE': 'L8K1H7',
#     'GEOMETRY_UPDATE_DATETIME': 1744234700000,
#     'EFFECTIVE_DATETIME': 1744209751000,
#     'SYSTEM_DATETIME': 1744221299000,
#     'OBJECTID': 2272993}},
#   {'type': 'Feature',
#    'id': 2273009,
#    'geometry': {'type': 'Point',
#     'coordinates': [-80.51566012599716, 43.45629609717748]},
#    'properties': {'OGF_ID': 321015971,
#     'MOH_SERVICE_PROVIDER_IDENT': '8677513',
#     'SERVICE_TYPE': 'Pharmacy',
#     'SERVICE_TYPE_DETAIL': 'Retail Pharmacy',
#     'ENGLISH_NAME': 'Spark Pharmacy',
#     'FRENCH_NAME': None,
#     'ENGLISH_NAME_ALT': None,
#     'FRENCH_NAME_ALT': None,
#     'ADDRESS_LINE_1': '535 Park Street',
#     'ADDRESS_LINE_2': None,
#     'ADDRESS_DESCRIPTOR': None,
#     'COMMUNITY': 'Kitchener',
#     'POSTAL_CODE': 'N2G1N8',
#     'GEOMETRY_UPDATE_DATETIME': 1744234403000,
#     'EFFECTIVE_DATETIME': 1744210106000,
#     'SYSTEM_DATETIME': 1744221299000,
#     'OBJECTID': 2273009}},
#   {'type': 'Feature',
#    'id': 2273025,
#    'geometry': {'type': 'Point',
#     'coordinates': [-81.18343525337902, 46.57570858420468]},
#    'properties': {'OGF_ID': 321017942,
#     'MOH_SERVICE_PROVIDER_IDENT': '4725',
#     'SERVICE_TYPE': 'Long-Term Care Home',
#     'SERVICE_TYPE_DETAIL': 'NH non-profit',
#     'ENGLISH_NAME': "St. Gabriel's Villa of Sudbury",
#     'FRENCH_NAME': None,
#     'ENGLISH_NAME_ALT': None,
#     'FRENCH_NAME_ALT': None,
#     'ADDRESS_LINE_1': '4690 Municipal Road 15',
#     'ADDRESS_LINE_2': None,
#     'ADDRESS_DESCRIPTOR': None,
#     'COMMUNITY': 'Chelmsford',
#     'POSTAL_CODE': 'P0M1L0',
#     'GEOMETRY_UPDATE_DATETIME': 1744234239000,
#     'EFFECTIVE_DATETIME': 1744216944000,
#     'SYSTEM_DATETIME': 1744221299000,
#     'OBJECTID': 2273025}},
#   {'type': 'Feature',
#    'id': 2273041,
#    'geometry': {'type': 'Point',
#     'coordinates': [-83.0219864022949, 42.29724247018098]},
#    'properties': {'OGF_ID': 321009549,
#     'MOH_SERVICE_PROVIDER_IDENT': '604290',
#     'SERVICE_TYPE': 'Integrated Community Health Services Centre',
#     'SERVICE_TYPE_DETAIL': 'Radiography, General Ultrasound',
#     'ENGLISH_NAME': 'Clear Medical Imaging',
#     'FRENCH_NAME': None,
#     'ENGLISH_NAME_ALT': '2324317 Ontario Ltd.',
#     'FRENCH_NAME_ALT': None,
#     'ADDRESS_LINE_1': '250 Tecumseh Road East',
#     'ADDRESS_LINE_2': 'Building 100, Unit 120',
#     'ADDRESS_DESCRIPTOR': None,
#     'COMMUNITY': 'Windsor',
#     'POSTAL_CODE': 'N8X2R3',
#     'GEOMETRY_UPDATE_DATETIME': 1744234330000,
#     'EFFECTIVE_DATETIME': 1744209390000,
#     'SYSTEM_DATETIME': 1744221299000,
#     'OBJECTID': 2273041}},
#   {'type': 'Feature',
#    'id': 2273057,
#    'geometry': {'type': 'Point',
#     'coordinates': [-79.45446184295467, 44.05984995273585]},
#    'properties': {'OGF_ID': 321007106,
#     'MOH_SERVICE_PROVIDER_IDENT': '240507',
#     'SERVICE_TYPE': 'HIV AIDS and Hep C Program',
#     'SERVICE_TYPE_DETAIL': 'At Site, HIV POC Testing',
#     'ENGLISH_NAME': 'York Region Public Health Services, Sexual Health Clinic',
#     'FRENCH_NAME': None,
#     'ENGLISH_NAME_ALT': None,
#     'FRENCH_NAME_ALT': None,
#     'ADDRESS_LINE_1': '22 Prospect Street',
#     'ADDRESS_LINE_2': None,
#     'ADDRESS_DESCRIPTOR': 'Practice Location',
#     'COMMUNITY': 'Newmarket',
#     'POSTAL_CODE': 'L3Y3S9',
#     'GEOMETRY_UPDATE_DATETIME': 1744234639000,
#     'EFFECTIVE_DATETIME': 1744209124000,
#     'SYSTEM_DATETIME': 1744221299000,
#     'OBJECTID': 2273057}},
#   {'type': 'Feature',
#    'id': 2273073,
#    'geometry': {'type': 'Point',
#     'coordinates': [-79.59846854903863, 43.61332116805954]},
#    'properties': {'OGF_ID': 321011554,
#     'MOH_SERVICE_PROVIDER_IDENT': '1209793',
#     'SERVICE_TYPE': 'Pharmacy',
#     'SERVICE_TYPE_DETAIL': 'Retail Pharmacy',
#     'ENGLISH_NAME': 'Apple-Hills Medical Pharmacy',
#     'FRENCH_NAME': None,
#     'ENGLISH_NAME_ALT': None,
#     'FRENCH_NAME_ALT': None,
#     'ADDRESS_LINE_1': '1221 Bloor Street East',
#     'ADDRESS_LINE_2': None,
#     'ADDRESS_DESCRIPTOR': None,
#     'COMMUNITY': 'Mississauga',
#     'POSTAL_CODE': 'L4Y2N8',
#     'GEOMETRY_UPDATE_DATETIME': 1744234204000,
#     'EFFECTIVE_DATETIME': 1744209612000,
#     'SYSTEM_DATETIME': 1744221299000,
#     'OBJECTID': 2273073}},
#   {'type': 'Feature',
#    'id': 2273089,
#    'geometry': {'type': 'Point',
#     'coordinates': [-79.30593097599301, 43.84256792183537]},
#    'properties': {'OGF_ID': 321014253,
#     'MOH_SERVICE_PROVIDER_IDENT': '6436751',
#     'SERVICE_TYPE': 'Pharmacy',
#     'SERVICE_TYPE_DETAIL': 'Retail Pharmacy',
#     'ENGLISH_NAME': 'Janedal Pharmacy',
#     'FRENCH_NAME': None,
#     'ENGLISH_NAME_ALT': None,
#     'FRENCH_NAME_ALT': None,
#     'ADDRESS_LINE_1': '7A-7750 Kennedy Road',
#     'ADDRESS_LINE_2': None,
#     'ADDRESS_DESCRIPTOR': None,
#     'COMMUNITY': 'Markham',
#     'POSTAL_CODE': 'L3R0A7',
#     'GEOMETRY_UPDATE_DATETIME': 1744234532000,
#     'EFFECTIVE_DATETIME': 1744209914000,
#     'SYSTEM_DATETIME': 1744221299000,
#     'OBJECTID': 2273089}},
#   {'type': 'Feature',
#    'id': 2273105,
#    'geometry': {'type': 'Point',
#     'coordinates': [-81.36219794823211, 42.968273170591424]},
#    'properties': {'OGF_ID': 321010980,
#     'MOH_SERVICE_PROVIDER_IDENT': 'S01218',
#     'SERVICE_TYPE': 'Licensed Retirement Home',
#     'SERVICE_TYPE_DETAIL': None,
#     'ENGLISH_NAME': 'Riverstone Retirement Residence',
#     'FRENCH_NAME': None,
#     'ENGLISH_NAME_ALT': None,
#     'FRENCH_NAME_ALT': None,
#     'ADDRESS_LINE_1': '1951 Shore Road',
#     'ADDRESS_LINE_2': None,
#     'ADDRESS_DESCRIPTOR': None,
#     'COMMUNITY': 'London',
#     'POSTAL_CODE': 'N6K0K4',
#     'GEOMETRY_UPDATE_DATETIME': 1744234682000,
#     'EFFECTIVE_DATETIME': 1744209546000,
#     'SYSTEM_DATETIME': 1744221299000,
#     'OBJECTID': 2273105}},
#   {'type': 'Feature',
#    'id': 2273121,
#    'geometry': {'type': 'Point',
#     'coordinates': [-79.80565247687393, 43.179500781847466]},
#    'properties': {'OGF_ID': 321013344,
#     'MOH_SERVICE_PROVIDER_IDENT': '5049556',
#     'SERVICE_TYPE': 'Pharmacy',
#     'SERVICE_TYPE_DETAIL': 'Retail Pharmacy',
#     'ENGLISH_NAME': 'Fletcher Pharmacy',
#     'FRENCH_NAME': None,
#     'ENGLISH_NAME_ALT': None,
#     'FRENCH_NAME_ALT': None,
#     'ADDRESS_LINE_1': '2-1962 Rymal Road East',
#     'ADDRESS_LINE_2': None,
#     'ADDRESS_DESCRIPTOR': None,
#     'COMMUNITY': 'Hamilton',
#     'POSTAL_CODE': 'L0R1P0',
#     'GEOMETRY_UPDATE_DATETIME': 1744234420000,
#     'EFFECTIVE_DATETIME': 1744209813000,
#     'SYSTEM_DATETIME': 1744221299000,
#     'OBJECTID': 2273121}},
#   ...],
#  'exceededTransferLimit': True,
#  'properties': {'exceededTransferLimit': True}}

# %%
response['features']
# Out:
# [{'type': 'Feature',
#   'id': 2267361,
#   'geometry': {'type': 'Point',
#    'coordinates': [-79.37995558388347, 43.66425498716289]},
#   'properties': {'OGF_ID': 321014690,
#    'MOH_SERVICE_PROVIDER_IDENT': '7040917',
#    'SERVICE_TYPE': 'Pharmacy',
#    'SERVICE_TYPE_DETAIL': 'Retail Pharmacy',
#    'ENGLISH_NAME': 'Medsexpert Pharmacy',
#    'FRENCH_NAME': None,
#    'ENGLISH_NAME_ALT': None,
#    'FRENCH_NAME_ALT': None,
#    'ADDRESS_LINE_1': '461 Church Street',
#    'ADDRESS_LINE_2': None,
#    'ADDRESS_DESCRIPTOR': None,
#    'COMMUNITY': 'Toronto',
#    'POSTAL_CODE': 'M4Y2C5',
#    'GEOMETRY_UPDATE_DATETIME': 1744234487000,
#    'EFFECTIVE_DATETIME': 1744209962000,
#    'SYSTEM_DATETIME': 1744221299000,
#    'OBJECTID': 2267361}},
#  {'type': 'Feature',
#   'id': 2267377,
#   'geometry': {'type': 'Point',
#    'coordinates': [-79.37427148129977, 43.655494085887874]},
#   'properties': {'OGF_ID': 321007348,
#    'MOH_SERVICE_PROVIDER_IDENT': '2975',
#    'SERVICE_TYPE': 'Mental Health and Addiction Organization',
#    'SERVICE_TYPE_DETAIL': 'Mental Health Services',
#    'ENGLISH_NAME': 'Homes First Society',
#    'FRENCH_NAME': None,
#    'ENGLISH_NAME_ALT': None,
#    'FRENCH_NAME_ALT': None,
#    'ADDRESS_LINE_1': '90 Shuter Street',
#    'ADDRESS_LINE_2': '2nd Floor',
#    'ADDRESS_DESCRIPTOR': 'Administrative Office',
#    'COMMUNITY': 'Toronto',
#    'POSTAL_CODE': 'M5B2K6',
#    'GEOMETRY_UPDATE_DATETIME': 1744234390000,
#    'EFFECTIVE_DATETIME': 1744209151000,
#    'SYSTEM_DATETIME': 1744221299000,
#    'OBJECTID': 2267377}},
#  {'type': 'Feature',
#   'id': 2267393,
#   'geometry': {'type': 'Point',
#    'coordinates': [-79.33946097071183, 43.661393388536275]},
#   'properties': {'OGF_ID': 321015379,
#    'MOH_SERVICE_PROVIDER_IDENT': '7973712',
#    'SERVICE_TYPE': 'Pharmacy',
#    'SERVICE_TYPE_DETAIL': 'Retail Pharmacy',
#    'ENGLISH_NAME': 'Woodgreen Discount Pharmacy',
#    'FRENCH_NAME': None,
#    'ENGLISH_NAME_ALT': None,
#    'FRENCH_NAME_ALT': None,
#    'ADDRESS_LINE_1': '1000 Queen Street East',
#    'ADDRESS_LINE_2': None,
#    'ADDRESS_DESCRIPTOR': None,
#    'COMMUNITY': 'Toronto',
#    'POSTAL_CODE': 'M4M1K1',
#    'GEOMETRY_UPDATE_DATETIME': 1744234594000,
#    'EFFECTIVE_DATETIME': 1744210039000,
#    'SYSTEM_DATETIME': 1744221299000,
#    'OBJECTID': 2267393}},
#  {'type': 'Feature',
#   'id': 2267409,
#   'geometry': {'type': 'Point',
#    'coordinates': [-81.19939090131443, 43.013415986436605]},
#   'properties': {'OGF_ID': 321014328,
#    'MOH_SERVICE_PROVIDER_IDENT': '6544073',
#    'SERVICE_TYPE': 'Pharmacy',
#    'SERVICE_TYPE_DETAIL': 'Retail Pharmacy',
#    'ENGLISH_NAME': 'Fanshawe College Pharmacy',
#    'FRENCH_NAME': None,
#    'ENGLISH_NAME_ALT': None,
#    'FRENCH_NAME_ALT': None,
#    'ADDRESS_LINE_1': '1001 Fanshawe College Boulevard',
#    'ADDRESS_LINE_2': 'Unit J1000',
#    'ADDRESS_DESCRIPTOR': None,
#    'COMMUNITY': 'London',
#    'POSTAL_CODE': 'N5Y5R6',
#    'GEOMETRY_UPDATE_DATETIME': 1744234312000,
#    'EFFECTIVE_DATETIME': 1744209922000,
#    'SYSTEM_DATETIME': 1744221299000,
#    'OBJECTID': 2267409}},
#  {'type': 'Feature',
#   'id': 2267425,
#   'geometry': {'type': 'Point',
#    'coordinates': [-92.42782873979856, 50.116772846460314]},
#   'properties': {'OGF_ID': 321009035,
#    'MOH_SERVICE_PROVIDER_IDENT': '4484',
#    'SERVICE_TYPE': 'Community Support Service',
#    'SERVICE_TYPE_DETAIL': None,
#    'ENGLISH_NAME': 'Lac Seul First Nation',
#    'FRENCH_NAME': None,
#    'ENGLISH_NAME_ALT': None,
#    'FRENCH_NAME_ALT': None,
#    'ADDRESS_LINE_1': 'P.O. Box 100',
#    'ADDRESS_LINE_2': None,
#    'ADDRESS_DESCRIPTOR': None,
#    'COMMUNITY': 'Lac Seul 28',
#    'POSTAL_CODE': 'P0V1X0',
#    'GEOMETRY_UPDATE_DATETIME': 1744234492000,
#    'EFFECTIVE_DATETIME': 1744209335000,
#    'SYSTEM_DATETIME': 1744221299000,
#    'OBJECTID': 2267425}},
#  {'type': 'Feature',
#   'id': 2267441,
#   'geometry': {'type': 'Point',
#    'coordinates': [-79.38505668583214, 43.66790678756752]},
#   'properties': {'OGF_ID': 321011995,
#    'MOH_SERVICE_PROVIDER_IDENT': '2189517',
#    'SERVICE_TYPE': 'Pharmacy',
#    'SERVICE_TYPE_DETAIL': 'Retail Pharmacy',
#    'ENGLISH_NAME': 'Pace Pharmacy',
#    'FRENCH_NAME': None,
#    'ENGLISH_NAME_ALT': None,
#    'FRENCH_NAME_ALT': None,
#    'ADDRESS_LINE_1': '14 Isabella Street',
#    'ADDRESS_LINE_2': None,
#    'ADDRESS_DESCRIPTOR': None,
#    'COMMUNITY': 'Toronto',
#    'POSTAL_CODE': 'M4Y1N1',
#    'GEOMETRY_UPDATE_DATETIME': 1744234447000,
#    'EFFECTIVE_DATETIME': 1744209661000,
#    'SYSTEM_DATETIME': 1744221299000,
#    'OBJECTID': 2267441}},
#  {'type': 'Feature',
#   'id': 2267457,
#   'geometry': {'type': 'Point',
#    'coordinates': [-79.09912444785923, 43.12351570426253]},
#   'properties': {'OGF_ID': 321007520,
#    'MOH_SERVICE_PROVIDER_IDENT': '30714',
#    'SERVICE_TYPE': 'Mental Health and Addiction Organization',
#    'SERVICE_TYPE_DETAIL': 'Mental Health Services',
#    'ENGLISH_NAME': 'Consumer/Survivor Initiative Of Niagara',
#    'FRENCH_NAME': None,
#    'ENGLISH_NAME_ALT': None,
#    'FRENCH_NAME_ALT': None,
#    'ADDRESS_LINE_1': '3428 Portage Road',
#    'ADDRESS_LINE_2': None,
#    'ADDRESS_DESCRIPTOR': 'Practice Location',
#    'COMMUNITY': 'Niagara Falls',
#    'POSTAL_CODE': 'L2J2K4',
#    'GEOMETRY_UPDATE_DATETIME': 1744234257000,
#    'EFFECTIVE_DATETIME': 1744209170000,
#    'SYSTEM_DATETIME': 1744221299000,
#    'OBJECTID': 2267457}},
#  {'type': 'Feature',
#   'id': 2267473,
#   'geometry': {'type': 'Point',
#    'coordinates': [-75.54874899008772, 45.435952663614685]},
#   'properties': {'OGF_ID': 321010853,
#    'MOH_SERVICE_PROVIDER_IDENT': 'N0475',
#    'SERVICE_TYPE': 'Licensed Retirement Home',
#    'SERVICE_TYPE_DETAIL': None,
#    'ENGLISH_NAME': 'Blackburn Senior Retirement Home',
#    'FRENCH_NAME': None,
#    'ENGLISH_NAME_ALT': None,
#    'FRENCH_NAME_ALT': None,
#    'ADDRESS_LINE_1': '2412 Cleroux Crescent',
#    'ADDRESS_LINE_2': None,
#    'ADDRESS_DESCRIPTOR': None,
#    'COMMUNITY': 'Ottawa',
#    'POSTAL_CODE': 'K1W1A3',
#    'GEOMETRY_UPDATE_DATETIME': 1744234592000,
#    'EFFECTIVE_DATETIME': 1744209531000,
#    'SYSTEM_DATETIME': 1744221299000,
#    'OBJECTID': 2267473}},
#  {'type': 'Feature',
#   'id': 2267489,
#   'geometry': {'type': 'Point',
#    'coordinates': [-79.76219871397784, 43.75711708556565]},
#   'properties': {'OGF_ID': 321010237,
#    'MOH_SERVICE_PROVIDER_IDENT': '9966412',
#    'SERVICE_TYPE': 'Integrated Community Health Services Centre',
#    'SERVICE_TYPE_DETAIL': 'Nuclear Medicine - In Vivo - General, Nuclear Medicine - In Vivo - Spect',
#    'ENGLISH_NAME': 'Myhealth Centre',
#    'FRENCH_NAME': None,
#    'ENGLISH_NAME_ALT': 'Myhealth Caledon Inc.',
#    'FRENCH_NAME_ALT': None,
#    'ADDRESS_LINE_1': '2 Dewside Drive',
#    'ADDRESS_LINE_2': 'Unit 206',
#    'ADDRESS_DESCRIPTOR': None,
#    'COMMUNITY': 'Brampton',
#    'POSTAL_CODE': 'L6R3Y5',
#    'GEOMETRY_UPDATE_DATETIME': 1744234571000,
#    'EFFECTIVE_DATETIME': 1744209466000,
#    'SYSTEM_DATETIME': 1744221299000,
#    'OBJECTID': 2267489}},
#  {'type': 'Feature',
#   'id': 2267505,
#   'geometry': {'type': 'Point',
#    'coordinates': [-79.38605858549987, 43.660497586220224]},
#   'properties': {'OGF_ID': 321008658,
#    'MOH_SERVICE_PROVIDER_IDENT': '4179104',
#    'SERVICE_TYPE': 'Integrated Community Health Services Centre',
#    'SERVICE_TYPE_DETAIL': 'Sleep Studies',
#    'ENGLISH_NAME': 'Sleep And Alertness Clinic',
#    'FRENCH_NAME': None,
#    'ENGLISH_NAME_ALT': 'Straight Sleep Inc.',
#    'FRENCH_NAME_ALT': None,
#    'ADDRESS_LINE_1': '790 Bay Street',
#    'ADDRESS_LINE_2': 'Suite 800',
#    'ADDRESS_DESCRIPTOR': None,
#    'COMMUNITY': 'Toronto',
#    'POSTAL_CODE': 'M5G1N8',
#    'GEOMETRY_UPDATE_DATETIME': 1744234614000,
#    'EFFECTIVE_DATETIME': 1744209294000,
#    'SYSTEM_DATETIME': 1744221299000,
#    'OBJECTID': 2267505}},
#  {'type': 'Feature',
#   'id': 2267521,
#   'geometry': {'type': 'Point',
#    'coordinates': [-78.34783430860692, 44.30072534569156]},
#   'properties': {'OGF_ID': 321009817,
#    'MOH_SERVICE_PROVIDER_IDENT': '771',
#    'SERVICE_TYPE': 'Community Support Service',
#    'SERVICE_TYPE_DETAIL': None,
#    'ENGLISH_NAME': 'Peterborough Regional Health Centre',
#    'FRENCH_NAME': None,
#    'ENGLISH_NAME_ALT': None,
#    'FRENCH_NAME_ALT': None,
#    'ADDRESS_LINE_1': '1Hospital Drive',
#    'ADDRESS_LINE_2': None,
#    'ADDRESS_DESCRIPTOR': None,
#    'COMMUNITY': 'Peterborough',
#    'POSTAL_CODE': 'K9J7C6',
#    'GEOMETRY_UPDATE_DATETIME': 1744234520000,
#    'EFFECTIVE_DATETIME': 1744209420000,
#    'SYSTEM_DATETIME': 1744221299000,
#    'OBJECTID': 2267521}},
#  {'type': 'Feature',
#   'id': 2267537,
#   'geometry': {'type': 'Point',
#    'coordinates': [-80.9495195552336, 43.37202126153235]},
#   'properties': {'OGF_ID': 321012803,
#    'MOH_SERVICE_PROVIDER_IDENT': '4098951',
#    'SERVICE_TYPE': 'Pharmacy',
#    'SERVICE_TYPE_DETAIL': 'Retail Pharmacy',
#    'ENGLISH_NAME': 'Wal-Mart Pharmacy',
#    'FRENCH_NAME': None,
#    'ENGLISH_NAME_ALT': None,
#    'FRENCH_NAME_ALT': None,
#    'ADDRESS_LINE_1': '920 Ontario Street',
#    'ADDRESS_LINE_2': None,
#    'ADDRESS_DESCRIPTOR': None,
#    'COMMUNITY': 'Stratford',
#    'POSTAL_CODE': 'N5A3K1',
#    'GEOMETRY_UPDATE_DATETIME': 1744234486000,
#    'EFFECTIVE_DATETIME': 1744209753000,
#    'SYSTEM_DATETIME': 1744221299000,
#    'OBJECTID': 2267537}},
#  {'type': 'Feature',
#   'id': 2267553,
#   'geometry': {'type': 'Point',
#    'coordinates': [-79.52340783300271, 43.70239748718286]},
#   'properties': {'OGF_ID': 321015214,
#    'MOH_SERVICE_PROVIDER_IDENT': '7730510',
#    'SERVICE_TYPE': 'Pharmacy',
#    'SERVICE_TYPE_DETAIL': 'Retail Pharmacy',
#    'ENGLISH_NAME': 'Central Weston Pharmacy',
#    'FRENCH_NAME': None,
#    'ENGLISH_NAME_ALT': None,
#    'FRENCH_NAME_ALT': None,
#    'ADDRESS_LINE_1': '2105 Weston Road',
#    'ADDRESS_LINE_2': None,
#    'ADDRESS_DESCRIPTOR': None,
#    'COMMUNITY': 'Toronto',
#    'POSTAL_CODE': 'M9N1X7',
#    'GEOMETRY_UPDATE_DATETIME': 1744234455000,
#    'EFFECTIVE_DATETIME': 1744210021000,
#    'SYSTEM_DATETIME': 1744221299000,
#    'OBJECTID': 2267553}},
#  {'type': 'Feature',
#   'id': 2267569,
#   'geometry': {'type': 'Point',
#    'coordinates': [-80.29009692503519, 43.122190849040294]},
#   'properties': {'OGF_ID': 321012814,
#    'MOH_SERVICE_PROVIDER_IDENT': '4111758',
#    'SERVICE_TYPE': 'Pharmacy',
#    'SERVICE_TYPE_DETAIL': 'Retail Pharmacy',
#    'ENGLISH_NAME': 'Pharmasave Shellard Lane Phrcy',
#    'FRENCH_NAME': None,
#    'ENGLISH_NAME_ALT': None,
#    'FRENCH_NAME_ALT': None,
#    'ADDRESS_LINE_1': '7-230 Shellard Lane',
#    'ADDRESS_LINE_2': None,
#    'ADDRESS_DESCRIPTOR': None,
#    'COMMUNITY': 'Brantford',
#    'POSTAL_CODE': 'N3T5S5',
#    'GEOMETRY_UPDATE_DATETIME': 1744234644000,
#    'EFFECTIVE_DATETIME': 1744209754000,
#    'SYSTEM_DATETIME': 1744221299000,
#    'OBJECTID': 2267569}},
#  {'type': 'Feature',
#   'id': 2267585,
#   'geometry': {'type': 'Point',
#    'coordinates': [-75.91284559758488, 45.281026621783965]},
#   'properties': {'OGF_ID': 321016899,
#    'MOH_SERVICE_PROVIDER_IDENT': '9571279',
#    'SERVICE_TYPE': 'Pharmacy',
#    'SERVICE_TYPE_DETAIL': 'Retail Pharmacy',
#    'ENGLISH_NAME': 'Unity Compounding Pharmacy',
#    'FRENCH_NAME': None,
#    'ENGLISH_NAME_ALT': None,
#    'FRENCH_NAME_ALT': None,
#    'ADDRESS_LINE_1': '5-5754 Hazeldean Road',
#    'ADDRESS_LINE_2': None,
#    'ADDRESS_DESCRIPTOR': None,
#    'COMMUNITY': 'Stittsville',
#    'POSTAL_CODE': 'K2S2R1',
#    'GEOMETRY_UPDATE_DATETIME': 1744234593000,
#    'EFFECTIVE_DATETIME': 1744210211000,
#    'SYSTEM_DATETIME': 1744221299000,
#    'OBJECTID': 2267585}},
#  {'type': 'Feature',
#   'id': 2267601,
#   'geometry': {'type': 'Point',
#    'coordinates': [-75.69900132596497, 45.270859329062255]},
#   'properties': {'OGF_ID': 321015327,
#    'MOH_SERVICE_PROVIDER_IDENT': '7890598',
#    'SERVICE_TYPE': 'Pharmacy',
#    'SERVICE_TYPE_DETAIL': 'Retail Pharmacy',
#    'ENGLISH_NAME': 'Loblaw Pharmacy #4253',
#    'FRENCH_NAME': None,
#    'ENGLISH_NAME_ALT': None,
#    'FRENCH_NAME_ALT': None,
#    'ADDRESS_LINE_1': '671 River Road',
#    'ADDRESS_LINE_2': None,
#    'ADDRESS_DESCRIPTOR': None,
#    'COMMUNITY': 'Gloucester',
#    'POSTAL_CODE': 'K1V2G2',
#    'GEOMETRY_UPDATE_DATETIME': 1744234541000,
#    'EFFECTIVE_DATETIME': 1744210034000,
#    'SYSTEM_DATETIME': 1744221299000,
#    'OBJECTID': 2267601}},
#  {'type': 'Feature',
#   'id': 2267617,
#   'geometry': {'type': 'Point',
#    'coordinates': [-81.23625650653217, 42.94277697218394]},
#   'properties': {'OGF_ID': 321013202,
#    'MOH_SERVICE_PROVIDER_IDENT': '4812117',
#    'SERVICE_TYPE': 'Pharmacy',
#    'SERVICE_TYPE_DETAIL': 'Retail Pharmacy',
#    'ENGLISH_NAME': 'Nixon Pharmacy',
#    'FRENCH_NAME': None,
#    'ENGLISH_NAME_ALT': None,
#    'FRENCH_NAME_ALT': None,
#    'ADDRESS_LINE_1': '102-510 Southdale Road East',
#    'ADDRESS_LINE_2': None,
#    'ADDRESS_DESCRIPTOR': None,
#    'COMMUNITY': 'London',
#    'POSTAL_CODE': 'N6E0B2',
#    'GEOMETRY_UPDATE_DATETIME': 1744234618000,
#    'EFFECTIVE_DATETIME': 1744209797000,
#    'SYSTEM_DATETIME': 1744221299000,
#    'OBJECTID': 2267617}},
#  {'type': 'Feature',
#   'id': 2267633,
#   'geometry': {'type': 'Point',
#    'coordinates': [-81.37572909591384, 44.48930693252983]},
#   'properties': {'OGF_ID': 321014003,
#    'MOH_SERVICE_PROVIDER_IDENT': '6083597',
#    'SERVICE_TYPE': 'Pharmacy',
#    'SERVICE_TYPE_DETAIL': 'Retail Pharmacy',
#    'ENGLISH_NAME': 'Rexall #1644',
#    'FRENCH_NAME': None,
#    'ENGLISH_NAME_ALT': None,
#    'FRENCH_NAME_ALT': None,
#    'ADDRESS_LINE_1': '174 Albert Street South',
#    'ADDRESS_LINE_2': None,
#    'ADDRESS_DESCRIPTOR': None,
#    'COMMUNITY': 'Southampton',
#    'POSTAL_CODE': 'N0H2L0',
#    'GEOMETRY_UPDATE_DATETIME': 1744234479000,
#    'EFFECTIVE_DATETIME': 1744209885000,
#    'SYSTEM_DATETIME': 1744221299000,
#    'OBJECTID': 2267633}},
#  {'type': 'Feature',
#   'id': 2267649,
#   'geometry': {'type': 'Point',
#    'coordinates': [-80.73329806409193, 43.115469326836255]},
#   'properties': {'OGF_ID': 321013655,
#    'MOH_SERVICE_PROVIDER_IDENT': '5550370',
#    'SERVICE_TYPE': 'Pharmacy',
#    'SERVICE_TYPE_DETAIL': 'Retail Pharmacy',
#    'ENGLISH_NAME': 'Wal-Mart Pharmacy',
#    'FRENCH_NAME': None,
#    'ENGLISH_NAME_ALT': None,
#    'FRENCH_NAME_ALT': None,
#    'ADDRESS_LINE_1': '499 Norwich Avenue',
#    'ADDRESS_LINE_2': None,
#    'ADDRESS_DESCRIPTOR': None,
#    'COMMUNITY': 'Woodstock',
#    'POSTAL_CODE': 'N4S9A2',
#    'GEOMETRY_UPDATE_DATETIME': 1744234634000,
#    'EFFECTIVE_DATETIME': 1744209847000,
#    'SYSTEM_DATETIME': 1744221299000,
#    'OBJECTID': 2267649}},
#  {'type': 'Feature',
#   'id': 2267665,
#   'geometry': {'type': 'Point',
#    'coordinates': [-79.86967280377743, 43.25566909236831]},
#   'properties': {'OGF_ID': 321006702,
#    'MOH_SERVICE_PROVIDER_IDENT': '18191',
#    'SERVICE_TYPE': 'Mental Health and Addiction Organization',
#    'SERVICE_TYPE_DETAIL': 'Mental Health Services',
#    'ENGLISH_NAME': "St. Joseph's Healthcare Hamilton",
#    'FRENCH_NAME': None,
#    'ENGLISH_NAME_ALT': None,
#    'FRENCH_NAME_ALT': None,
#    'ADDRESS_LINE_1': '38 James Street South',
#    'ADDRESS_LINE_2': 'Second Floor',
#    'ADDRESS_DESCRIPTOR': 'Practice Location',
#    'COMMUNITY': 'Hamilton',
#    'POSTAL_CODE': 'L8P4W6',
#    'GEOMETRY_UPDATE_DATETIME': 1744234403000,
#    'EFFECTIVE_DATETIME': 1744209079000,
#    'SYSTEM_DATETIME': 1744221299000,
#    'OBJECTID': 2267665}},
#  {'type': 'Feature',
#   'id': 2267681,
#   'geometry': {'type': 'Point',
#    'coordinates': [-79.37867498329864, 43.66225108687043]},
#   'properties': {'OGF_ID': 321009562,
#    'MOH_SERVICE_PROVIDER_IDENT': '6101043',
#    'SERVICE_TYPE': 'Community Health Centre',
#    'SERVICE_TYPE_DETAIL': 'Satellite',
#    'ENGLISH_NAME': 'Vibrant Health Care Alliance Carlton Site',
#    'FRENCH_NAME': None,
#    'ENGLISH_NAME_ALT': 'Formerly Anne Johnston Health Station',
#    'FRENCH_NAME_ALT': None,
#    'ADDRESS_LINE_1': '84 Carlton Street',
#    'ADDRESS_LINE_2': 'Main Floor',
#    'ADDRESS_DESCRIPTOR': None,
#    'COMMUNITY': 'Toronto',
#    'POSTAL_CODE': 'M5B2P4',
#    'GEOMETRY_UPDATE_DATETIME': 1744234220000,
#    'EFFECTIVE_DATETIME': 1744209391000,
#    'SYSTEM_DATETIME': 1744221299000,
#    'OBJECTID': 2267681}},
#  {'type': 'Feature',
#   'id': 2267697,
#   'geometry': {'type': 'Point',
#    'coordinates': [-79.37519148253327, 43.66618368772238]},
#   'properties': {'OGF_ID': 321009571,
#    'MOH_SERVICE_PROVIDER_IDENT': '618980',
#    'SERVICE_TYPE': 'HIV AIDS and Hep C Program',
#    'SERVICE_TYPE_DETAIL': 'HIV Clinical Services',
#    'ENGLISH_NAME': "St. Michael's Hospital, Family Health Team, Wellesley-St. James Town Health Centre",
#    'FRENCH_NAME': None,
#    'ENGLISH_NAME_ALT': 'Unity Health',
#    'FRENCH_NAME_ALT': None,
#    'ADDRESS_LINE_1': '95 Homewood Avenue',
#    'ADDRESS_LINE_2': None,
#    'ADDRESS_DESCRIPTOR': 'Practice Location',
#    'COMMUNITY': 'Toronto',
#    'POSTAL_CODE': 'M4Y1J4',
#    'GEOMETRY_UPDATE_DATETIME': 1744234528000,
#    'EFFECTIVE_DATETIME': 1744209392000,
#    'SYSTEM_DATETIME': 1744221299000,
#    'OBJECTID': 2267697}},
#  {'type': 'Feature',
#   'id': 2267713,
#   'geometry': {'type': 'Point',
#    'coordinates': [-79.28092196152144, 43.769336010181625]},
#   'properties': {'OGF_ID': 321014876,
#    'MOH_SERVICE_PROVIDER_IDENT': '7267272',
#    'SERVICE_TYPE': 'Pharmacy',
#    'SERVICE_TYPE_DETAIL': 'Retail Pharmacy',
#    'ENGLISH_NAME': 'Progress Centre Pharmacy',
#    'FRENCH_NAME': None,
#    'ENGLISH_NAME_ALT': None,
#    'FRENCH_NAME_ALT': None,
#    'ADDRESS_LINE_1': '1A-9 Progress Avenue',
#    'ADDRESS_LINE_2': None,
#    'ADDRESS_DESCRIPTOR': None,
#    'COMMUNITY': 'Scarborough',
#    'POSTAL_CODE': 'M1P5A4',
#    'GEOMETRY_UPDATE_DATETIME': 1744234676000,
#    'EFFECTIVE_DATETIME': 1744209983000,
#    'SYSTEM_DATETIME': 1744221299000,
#    'OBJECTID': 2267713}},
#  {'type': 'Feature',
#   'id': 2267729,
#   'geometry': {'type': 'Point',
#    'coordinates': [-79.58415426092421, 43.79849170115353]},
#   'properties': {'OGF_ID': 321011443,
#    'MOH_SERVICE_PROVIDER_IDENT': 'T0638',
#    'SERVICE_TYPE': 'Licensed Retirement Home',
#    'SERVICE_TYPE_DETAIL': None,
#    'ENGLISH_NAME': 'Agecare Pine Grove',
#    'FRENCH_NAME': None,
#    'ENGLISH_NAME_ALT': None,
#    'FRENCH_NAME_ALT': None,
#    'ADDRESS_LINE_1': '8403 Islington Avenue North',
#    'ADDRESS_LINE_2': None,
#    'ADDRESS_DESCRIPTOR': None,
#    'COMMUNITY': 'Woodbridge',
#    'POSTAL_CODE': 'L4L1X3',
#    'GEOMETRY_UPDATE_DATETIME': 1744234397000,
#    'EFFECTIVE_DATETIME': 1744209598000,
#    'SYSTEM_DATETIME': 1744221299000,
#    'OBJECTID': 2267729}},
#  {'type': 'Feature',
#   'id': 2267745,
#   'geometry': {'type': 'Point',
#    'coordinates': [-81.33312654182063, 42.99812127726525]},
#   'properties': {'OGF_ID': 321013456,
#    'MOH_SERVICE_PROVIDER_IDENT': '5218196',
#    'SERVICE_TYPE': 'Pharmacy',
#    'SERVICE_TYPE_DETAIL': 'Retail Pharmacy',
#    'ENGLISH_NAME': 'Grace Drug Store',
#    'FRENCH_NAME': None,
#    'ENGLISH_NAME_ALT': None,
#    'FRENCH_NAME_ALT': None,
#    'ADDRESS_LINE_1': '1070 Gainsborough Road',
#    'ADDRESS_LINE_2': None,
#    'ADDRESS_DESCRIPTOR': None,
#    'COMMUNITY': 'London',
#    'POSTAL_CODE': 'N6H5L5',
#    'GEOMETRY_UPDATE_DATETIME': 1744234249000,
#    'EFFECTIVE_DATETIME': 1744209825000,
#    'SYSTEM_DATETIME': 1744221299000,
#    'OBJECTID': 2267745}},
#  {'type': 'Feature',
#   'id': 2267761,
#   'geometry': {'type': 'Point',
#    'coordinates': [-75.66223305874294, 44.60349171500411]},
#   'properties': {'OGF_ID': 321010697,
#    'MOH_SERVICE_PROVIDER_IDENT': 'N0070',
#    'SERVICE_TYPE': 'Licensed Retirement Home',
#    'SERVICE_TYPE_DETAIL': None,
#    'ENGLISH_NAME': 'Chartwell Rosedale Retirement Residence',
#    'FRENCH_NAME': None,
#    'ENGLISH_NAME_ALT': None,
#    'FRENCH_NAME_ALT': None,
#    'ADDRESS_LINE_1': '1813 County Road 2  East',
#    'ADDRESS_LINE_2': 'Rr 1',
#    'ADDRESS_DESCRIPTOR': None,
#    'COMMUNITY': 'Brockville',
#    'POSTAL_CODE': 'K6V5T1',
#    'GEOMETRY_UPDATE_DATETIME': 1744234347000,
#    'EFFECTIVE_DATETIME': 1744209514000,
#    'SYSTEM_DATETIME': 1744221299000,
#    'OBJECTID': 2267761}},
#  {'type': 'Feature',
#   'id': 2267777,
#   'geometry': {'type': 'Point',
#    'coordinates': [-79.233048946927, 43.777338413800024]},
#   'properties': {'OGF_ID': 321007681,
#    'MOH_SERVICE_PROVIDER_IDENT': '3130',
#    'SERVICE_TYPE': 'Mental Health and Addiction Organization',
#    'SERVICE_TYPE_DETAIL': 'Mental Health Services',
#    'ENGLISH_NAME': 'Canadian Mental Health Association (Cmha) Toronto Branch',
#    'FRENCH_NAME': None,
#    'ENGLISH_NAME_ALT': None,
#    'FRENCH_NAME_ALT': None,
#    'ADDRESS_LINE_1': '1200 Markham Road',
#    'ADDRESS_LINE_2': 'Suite: 500',
#    'ADDRESS_DESCRIPTOR': 'Practice Location',
#    'COMMUNITY': 'Scarborough',
#    'POSTAL_CODE': 'M1H3C3',
#    'GEOMETRY_UPDATE_DATETIME': 1744234624000,
#    'EFFECTIVE_DATETIME': 1744209187000,
#    'SYSTEM_DATETIME': 1744221299000,
#    'OBJECTID': 2267777}},
#  {'type': 'Feature',
#   'id': 2267793,
#   'geometry': {'type': 'Point',
#    'coordinates': [-79.44753421006226, 43.71661989320933]},
#   'properties': {'OGF_ID': 321008721,
#    'MOH_SERVICE_PROVIDER_IDENT': '4221435',
#    'SERVICE_TYPE': 'Community Health Centre',
#    'SERVICE_TYPE_DETAIL': 'Satellite',
#    'ENGLISH_NAME': 'Unison Health And Community Services Pathways To Education',
#    'FRENCH_NAME': None,
#    'ENGLISH_NAME_ALT': None,
#    'FRENCH_NAME_ALT': None,
#    'ADDRESS_LINE_1': '700 Lawrence Avenue West, Ste 440B',
#    'ADDRESS_LINE_2': 'Lawrence Square Mall',
#    'ADDRESS_DESCRIPTOR': None,
#    'COMMUNITY': 'Toronto',
#    'POSTAL_CODE': 'M6A3B4',
#    'GEOMETRY_UPDATE_DATETIME': 1744234200000,
#    'EFFECTIVE_DATETIME': 1744209301000,
#    'SYSTEM_DATETIME': 1744221299000,
#    'OBJECTID': 2267793}},
#  {'type': 'Feature',
#   'id': 2267809,
#   'geometry': {'type': 'Point',
#    'coordinates': [-79.55039245073577, 43.80502820387622]},
#   'properties': {'OGF_ID': 321010149,
#    'MOH_SERVICE_PROVIDER_IDENT': '9361147',
#    'SERVICE_TYPE': 'Integrated Community Health Services Centre',
#    'SERVICE_TYPE_DETAIL': 'Bone Mineral Dxa, Fluoroscopy, Mammography, Radiography, General Ultrasound, Vascular Ultrasound, Nuclear Medicine - In Vivo - General, Nuclear Medicine - In Vivo - Spect, Pulmonary Function A - Pure Screening, Pulmonary Function B - Lung Volumes & Diffusion',
#    'ENGLISH_NAME': 'Vaughan Imaging Consultants',
#    'FRENCH_NAME': None,
#    'ENGLISH_NAME_ALT': 'Dixie X-Ray Associates Limited',
#    'FRENCH_NAME_ALT': None,
#    'ADDRESS_LINE_1': '8333 Weston Road',
#    'ADDRESS_LINE_2': 'Suite B04',
#    'ADDRESS_DESCRIPTOR': None,
#    'COMMUNITY': 'Woodbridge',
#    'POSTAL_CODE': 'L4L8E2',
#    'GEOMETRY_UPDATE_DATETIME': 1744234534000,
#    'EFFECTIVE_DATETIME': 1744209456000,
#    'SYSTEM_DATETIME': 1744221299000,
#    'OBJECTID': 2267809}},
#  {'type': 'Feature',
#   'id': 2267825,
#   'geometry': {'type': 'Point',
#    'coordinates': [-79.54142299397417, 43.18952799583992]},
#   'properties': {'OGF_ID': 321014227,
#    'MOH_SERVICE_PROVIDER_IDENT': '6388839',
#    'SERVICE_TYPE': 'Pharmacy',
#    'SERVICE_TYPE_DETAIL': 'Long Term Care Facility',
#    'ENGLISH_NAME': 'Deer Park Villa',
#    'FRENCH_NAME': None,
#    'ENGLISH_NAME_ALT': None,
#    'FRENCH_NAME_ALT': None,
#    'ADDRESS_LINE_1': '150 Central Avenue',
#    'ADDRESS_LINE_2': None,
#    'ADDRESS_DESCRIPTOR': None,
#    'COMMUNITY': 'Grimsby',
#    'POSTAL_CODE': 'L3M4Z3',
#    'GEOMETRY_UPDATE_DATETIME': 1744234688000,
#    'EFFECTIVE_DATETIME': 1744209911000,
#    'SYSTEM_DATETIME': 1744221299000,
#    'OBJECTID': 2267825}},
#  {'type': 'Feature',
#   'id': 2267841,
#   'geometry': {'type': 'Point',
#    'coordinates': [-79.27087445825795, 43.76873671054211]},
#   'properties': {'OGF_ID': 321012492,
#    'MOH_SERVICE_PROVIDER_IDENT': '3401679',
#    'SERVICE_TYPE': 'Pharmacy',
#    'SERVICE_TYPE_DETAIL': 'Retail Pharmacy',
#    'ENGLISH_NAME': 'Metropolitan Pharmacy',
#    'FRENCH_NAME': None,
#    'ENGLISH_NAME_ALT': None,
#    'FRENCH_NAME_ALT': None,
#    'ADDRESS_LINE_1': '2025 Midland Avenue',
#    'ADDRESS_LINE_2': 'Suite 101',
#    'ADDRESS_DESCRIPTOR': None,
#    'COMMUNITY': 'Scarborough',
#    'POSTAL_CODE': 'M1P3E2',
#    'GEOMETRY_UPDATE_DATETIME': 1744234396000,
#    'EFFECTIVE_DATETIME': 1744209717000,
#    'SYSTEM_DATETIME': 1744221299000,
#    'OBJECTID': 2267841}},
#  {'type': 'Feature',
#   'id': 2267857,
#   'geometry': {'type': 'Point',
#    'coordinates': [-79.69416314940602, 44.38376529727595]},
#   'properties': {'OGF_ID': 321007668,
#    'MOH_SERVICE_PROVIDER_IDENT': '31279',
#    'SERVICE_TYPE': 'Mental Health and Addiction Organization',
#    'SERVICE_TYPE_DETAIL': 'Mental Health Services',
#    'ENGLISH_NAME': 'Canadian Mental Health Association (Cmha) Simcoe County Branch',
#    'FRENCH_NAME': None,
#    'ENGLISH_NAME_ALT': None,
#    'FRENCH_NAME_ALT': None,
#    'ADDRESS_LINE_1': '80 Bradford Street',
#    'ADDRESS_LINE_2': 'Suite: 555',
#    'ADDRESS_DESCRIPTOR': 'Practice Location',
#    'COMMUNITY': 'Barrie',
#    'POSTAL_CODE': 'L4N6S7',
#    'GEOMETRY_UPDATE_DATETIME': 1744234506000,
#    'EFFECTIVE_DATETIME': 1744209186000,
#    'SYSTEM_DATETIME': 1744221299000,
#    'OBJECTID': 2267857}},
#  {'type': 'Feature',
#   'id': 2267873,
#   'geometry': {'type': 'Point',
#    'coordinates': [-79.63276896741073, 43.69734528118895]},
#   'properties': {'OGF_ID': 321015915,
#    'MOH_SERVICE_PROVIDER_IDENT': '8601872',
#    'SERVICE_TYPE': 'Pharmacy',
#    'SERVICE_TYPE_DETAIL': 'Retail Pharmacy',
#    'ENGLISH_NAME': 'Mckesson Specialty Phcy (On)',
#    'FRENCH_NAME': None,
#    'ENGLISH_NAME_ALT': None,
#    'FRENCH_NAME_ALT': None,
#    'ADDRESS_LINE_1': 'B-6655 Airport Road',
#    'ADDRESS_LINE_2': None,
#    'ADDRESS_DESCRIPTOR': None,
#    'COMMUNITY': 'Mississauga',
#    'POSTAL_CODE': 'L4V1V8',
#    'GEOMETRY_UPDATE_DATETIME': 1744234333000,
#    'EFFECTIVE_DATETIME': 1744210099000,
#    'SYSTEM_DATETIME': 1744221299000,
#    'OBJECTID': 2267873}},
#  {'type': 'Feature',
#   'id': 2267889,
#   'geometry': {'type': 'Point',
#    'coordinates': [-75.75303365277082, 45.37621774482332]},
#   'properties': {'OGF_ID': 321017831,
#    'MOH_SERVICE_PROVIDER_IDENT': '1660',
#    'SERVICE_TYPE': 'Long-Term Care Home',
#    'SERVICE_TYPE_DETAIL': 'NH non-profit',
#    'ENGLISH_NAME': 'Hillel Lodge',
#    'FRENCH_NAME': None,
#    'ENGLISH_NAME_ALT': None,
#    'FRENCH_NAME_ALT': None,
#    'ADDRESS_LINE_1': '10 Nadolny Sachs Private',
#    'ADDRESS_LINE_2': None,
#    'ADDRESS_DESCRIPTOR': None,
#    'COMMUNITY': 'Ottawa',
#    'POSTAL_CODE': 'K2A4G7',
#    'GEOMETRY_UPDATE_DATETIME': 1744234649000,
#    'EFFECTIVE_DATETIME': 1744214631000,
#    'SYSTEM_DATETIME': 1744221299000,
#    'OBJECTID': 2267889}},
#  {'type': 'Feature',
#   'id': 2267905,
#   'geometry': {'type': 'Point',
#    'coordinates': [-80.64297907507508, 51.274170604302945]},
#   'properties': {'OGF_ID': 321007320,
#    'MOH_SERVICE_PROVIDER_IDENT': '2896',
#    'SERVICE_TYPE': 'Mental Health and Addiction Organization',
#    'SERVICE_TYPE_DETAIL': 'Addiction Services And Mental Health Services',
#    'ENGLISH_NAME': 'Weeneebayko Area Health Authority',
#    'FRENCH_NAME': None,
#    'ENGLISH_NAME_ALT': None,
#    'FRENCH_NAME_ALT': None,
#    'ADDRESS_LINE_1': '2 Bay Road',
#    'ADDRESS_LINE_2': None,
#    'ADDRESS_DESCRIPTOR': 'Administration And Practice Location',
#    'COMMUNITY': 'Moosonee',
#    'POSTAL_CODE': 'P0L1Y0',
#    'GEOMETRY_UPDATE_DATETIME': 1744234176000,
#    'EFFECTIVE_DATETIME': 1744209148000,
#    'SYSTEM_DATETIME': 1744221299000,
#    'OBJECTID': 2267905}},
#  {'type': 'Feature',
#   'id': 2267921,
#   'geometry': {'type': 'Point',
#    'coordinates': [-79.8076680899409, 43.32228620704034]},
#   'properties': {'OGF_ID': 321014319,
#    'MOH_SERVICE_PROVIDER_IDENT': '6534039',
#    'SERVICE_TYPE': 'Pharmacy',
#    'SERVICE_TYPE_DETAIL': 'Retail Pharmacy',
#    'ENGLISH_NAME': 'Maple IDA Pharmacy',
#    'FRENCH_NAME': None,
#    'ENGLISH_NAME_ALT': None,
#    'FRENCH_NAME_ALT': None,
#    'ADDRESS_LINE_1': '573 Maple Avenue',
#    'ADDRESS_LINE_2': None,
#    'ADDRESS_DESCRIPTOR': None,
#    'COMMUNITY': 'Burlington',
#    'POSTAL_CODE': 'L7S2E8',
#    'GEOMETRY_UPDATE_DATETIME': 1744234511000,
#    'EFFECTIVE_DATETIME': 1744209921000,
#    'SYSTEM_DATETIME': 1744221299000,
#    'OBJECTID': 2267921}},
#  {'type': 'Feature',
#   'id': 2267937,
#   'geometry': {'type': 'Point',
#    'coordinates': [-75.51180758146192, 45.47899407250755]},
#   'properties': {'OGF_ID': 321012483,
#    'MOH_SERVICE_PROVIDER_IDENT': '3384670',
#    'SERVICE_TYPE': 'Pharmacy',
#    'SERVICE_TYPE_DETAIL': 'Retail Pharmacy',
#    'ENGLISH_NAME': 'Pharmacie Centrum Pharmacy Inc',
#    'FRENCH_NAME': None,
#    'ENGLISH_NAME_ALT': None,
#    'FRENCH_NAME_ALT': None,
#    'ADDRESS_LINE_1': '210 Centrum Boulevard Suite 107',
#    'ADDRESS_LINE_2': None,
#    'ADDRESS_DESCRIPTOR': None,
#    'COMMUNITY': 'Orleans',
#    'POSTAL_CODE': 'K1E3V7',
#    'GEOMETRY_UPDATE_DATETIME': 1744234664000,
#    'EFFECTIVE_DATETIME': 1744209716000,
#    'SYSTEM_DATETIME': 1744221299000,
#    'OBJECTID': 2267937}},
#  {'type': 'Feature',
#   'id': 2267953,
#   'geometry': {'type': 'Point',
#    'coordinates': [-79.36123487754199, 43.66005918729368]},
#   'properties': {'OGF_ID': 321007039,
#    'MOH_SERVICE_PROVIDER_IDENT': '2307',
#    'SERVICE_TYPE': 'Mental Health and Addiction Organization',
#    'SERVICE_TYPE_DETAIL': 'Mental Health Services',
#    'ENGLISH_NAME': 'Unity Health Toronto',
#    'FRENCH_NAME': None,
#    'ENGLISH_NAME_ALT': None,
#    'FRENCH_NAME_ALT': None,
#    'ADDRESS_LINE_1': '73 Regent Park Boulevard',
#    'ADDRESS_LINE_2': '3rd Floor',
#    'ADDRESS_DESCRIPTOR': 'Practice Location',
#    'COMMUNITY': 'Toronto',
#    'POSTAL_CODE': 'M5A2B7',
#    'GEOMETRY_UPDATE_DATETIME': 1744234403000,
#    'EFFECTIVE_DATETIME': 1744209116000,
#    'SYSTEM_DATETIME': 1744221299000,
#    'OBJECTID': 2267953}},
#  {'type': 'Feature',
#   'id': 2267969,
#   'geometry': {'type': 'Point',
#    'coordinates': [-79.45016952452077, 43.86985601987992]},
#   'properties': {'OGF_ID': 321009695,
#    'MOH_SERVICE_PROVIDER_IDENT': '701',
#    'SERVICE_TYPE': 'Community Support Service',
#    'SERVICE_TYPE_DETAIL': None,
#    'ENGLISH_NAME': 'Mackenzie Health',
#    'FRENCH_NAME': None,
#    'ENGLISH_NAME_ALT': None,
#    'FRENCH_NAME_ALT': None,
#    'ADDRESS_LINE_1': '10 Trench Street',
#    'ADDRESS_LINE_2': None,
#    'ADDRESS_DESCRIPTOR': None,
#    'COMMUNITY': 'Richmond Hill',
#    'POSTAL_CODE': 'L4C4Z3',
#    'GEOMETRY_UPDATE_DATETIME': 1744234172000,
#    'EFFECTIVE_DATETIME': 1744209406000,
#    'SYSTEM_DATETIME': 1744221299000,
#    'OBJECTID': 2267969}},
#  {'type': 'Feature',
#   'id': 2267985,
#   'geometry': {'type': 'Point',
#    'coordinates': [-75.75406224410835, 45.26988402658037]},
#   'properties': {'OGF_ID': 321017101,
#    'MOH_SERVICE_PROVIDER_IDENT': '9702672',
#    'SERVICE_TYPE': 'Pharmacy',
#    'SERVICE_TYPE_DETAIL': 'Retail Pharmacy',
#    'ENGLISH_NAME': 'Tartan Pharmacy',
#    'FRENCH_NAME': None,
#    'ENGLISH_NAME_ALT': None,
#    'FRENCH_NAME_ALT': None,
#    'ADDRESS_LINE_1': '4-1 Tartan Drive',
#    'ADDRESS_LINE_2': None,
#    'ADDRESS_DESCRIPTOR': None,
#    'COMMUNITY': 'Nepean',
#    'POSTAL_CODE': 'K2J2W7',
#    'GEOMETRY_UPDATE_DATETIME': 1744234325000,
#    'EFFECTIVE_DATETIME': 1744210234000,
#    'SYSTEM_DATETIME': 1744221299000,
#    'OBJECTID': 2267985}},
#  {'type': 'Feature',
#   'id': 2268001,
#   'geometry': {'type': 'Point',
#    'coordinates': [-79.4449532094963, 43.71953139383965]},
#   'properties': {'OGF_ID': 321008716,
#    'MOH_SERVICE_PROVIDER_IDENT': '422143',
#    'SERVICE_TYPE': 'HIV AIDS and Hep C Program',
#    'SERVICE_TYPE_DETAIL': 'At Site, HR Program, HIV POC Testing',
#    'ENGLISH_NAME': 'Unison Health And Community Services',
#    'FRENCH_NAME': None,
#    'ENGLISH_NAME_ALT': None,
#    'FRENCH_NAME_ALT': None,
#    'ADDRESS_LINE_1': '12 Flemington Road',
#    'ADDRESS_LINE_2': None,
#    'ADDRESS_DESCRIPTOR': 'Practice Location',
#    'COMMUNITY': 'Toronto',
#    'POSTAL_CODE': 'M6A2N4',
#    'GEOMETRY_UPDATE_DATETIME': 1744234658000,
#    'EFFECTIVE_DATETIME': 1744209300000,
#    'SYSTEM_DATETIME': 1744221299000,
#    'OBJECTID': 2268001}},
#  {'type': 'Feature',
#   'id': 2268017,
#   'geometry': {'type': 'Point',
#    'coordinates': [-79.63082307953879, 43.840128706230814]},
#   'properties': {'OGF_ID': 321018056,
#    'MOH_SERVICE_PROVIDER_IDENT': '4650',
#    'SERVICE_TYPE': 'Long-Term Care Home',
#    'SERVICE_TYPE_DETAIL': 'NH non-profit',
#    'ENGLISH_NAME': 'Villa Colombo Seniors Centre (Vaughan)',
#    'FRENCH_NAME': None,
#    'ENGLISH_NAME_ALT': None,
#    'FRENCH_NAME_ALT': None,
#    'ADDRESS_LINE_1': '10443 Highway 27, Kleinburg',
#    'ADDRESS_LINE_2': None,
#    'ADDRESS_DESCRIPTOR': None,
#    'COMMUNITY': 'Vaughan',
#    'POSTAL_CODE': 'L0J1C0',
#    'GEOMETRY_UPDATE_DATETIME': 1744234581000,
#    'EFFECTIVE_DATETIME': 1744214629000,
#    'SYSTEM_DATETIME': 1744221299000,
#    'OBJECTID': 2268017}},
#  {'type': 'Feature',
#   'id': 2268033,
#   'geometry': {'type': 'Point',
#    'coordinates': [-79.2031277377414, 43.78165231593952]},
#   'properties': {'OGF_ID': 321011471,
#    'MOH_SERVICE_PROVIDER_IDENT': '1048459',
#    'SERVICE_TYPE': 'Pharmacy',
#    'SERVICE_TYPE_DETAIL': 'Long Term Care Facility',
#    'ENGLISH_NAME': 'Seven Oaks Home For The Aged',
#    'FRENCH_NAME': None,
#    'ENGLISH_NAME_ALT': None,
#    'FRENCH_NAME_ALT': None,
#    'ADDRESS_LINE_1': '9 Neilson Road',
#    'ADDRESS_LINE_2': None,
#    'ADDRESS_DESCRIPTOR': None,
#    'COMMUNITY': 'Scarborough',
#    'POSTAL_CODE': 'M1E5E1',
#    'GEOMETRY_UPDATE_DATETIME': 1744234599000,
#    'EFFECTIVE_DATETIME': 1744209602000,
#    'SYSTEM_DATETIME': 1744221299000,
#    'OBJECTID': 2268033}},
#  {'type': 'Feature',
#   'id': 2268049,
#   'geometry': {'type': 'Point',
#    'coordinates': [-79.87114272751477, 43.520254038955045]},
#   'properties': {'OGF_ID': 321016667,
#    'MOH_SERVICE_PROVIDER_IDENT': '9368917',
#    'SERVICE_TYPE': 'Pharmacy',
#    'SERVICE_TYPE_DETAIL': 'Retail Pharmacy',
#    'ENGLISH_NAME': 'Nipissing Phcy & Med Clinic',
#    'FRENCH_NAME': None,
#    'ENGLISH_NAME_ALT': None,
#    'FRENCH_NAME_ALT': None,
#    'ADDRESS_LINE_1': '5-150 Nipissing Road',
#    'ADDRESS_LINE_2': None,
#    'ADDRESS_DESCRIPTOR': None,
#    'COMMUNITY': 'Milton',
#    'POSTAL_CODE': 'L9T5B3',
#    'GEOMETRY_UPDATE_DATETIME': 1744234288000,
#    'EFFECTIVE_DATETIME': 1744210184000,
#    'SYSTEM_DATETIME': 1744221299000,
#    'OBJECTID': 2268049}},
#  {'type': 'Feature',
#   'id': 2268065,
#   'geometry': {'type': 'Point',
#    'coordinates': [-76.507228505811, 44.238907515699545]},
#   'properties': {'OGF_ID': 321014082,
#    'MOH_SERVICE_PROVIDER_IDENT': '6179011',
#    'SERVICE_TYPE': 'Pharmacy',
#    'SERVICE_TYPE_DETAIL': 'Retail Pharmacy',
#    'ENGLISH_NAME': 'Medical Arts Pharmacy',
#    'FRENCH_NAME': None,
#    'ENGLISH_NAME_ALT': None,
#    'FRENCH_NAME_ALT': None,
#    'ADDRESS_LINE_1': '800 Princess Street',
#    'ADDRESS_LINE_2': None,
#    'ADDRESS_DESCRIPTOR': None,
#    'COMMUNITY': 'Kingston',
#    'POSTAL_CODE': 'K7L1E4',
#    'GEOMETRY_UPDATE_DATETIME': 1744234500000,
#    'EFFECTIVE_DATETIME': 1744209894000,
#    'SYSTEM_DATETIME': 1744221299000,
#    'OBJECTID': 2268065}},
#  {'type': 'Feature',
#   'id': 2268081,
#   'geometry': {'type': 'Point',
#    'coordinates': [-79.42463021224985, 43.82371161301529]},
#   'properties': {'OGF_ID': 321012751,
#    'MOH_SERVICE_PROVIDER_IDENT': '398670',
#    'SERVICE_TYPE': 'Pharmacy',
#    'SERVICE_TYPE_DETAIL': 'Retail Pharmacy',
#    'ENGLISH_NAME': 'Shoppers Drug Mart #657',
#    'FRENCH_NAME': None,
#    'ENGLISH_NAME_ALT': None,
#    'FRENCH_NAME_ALT': None,
#    'ADDRESS_LINE_1': '10 Royal Orchard Boulevard',
#    'ADDRESS_LINE_2': None,
#    'ADDRESS_DESCRIPTOR': None,
#    'COMMUNITY': 'Thornhill',
#    'POSTAL_CODE': 'L3T3C3',
#    'GEOMETRY_UPDATE_DATETIME': 1744234457000,
#    'EFFECTIVE_DATETIME': 1744209747000,
#    'SYSTEM_DATETIME': 1744221299000,
#    'OBJECTID': 2268081}},
#  {'type': 'Feature',
#   'id': 2268097,
#   'geometry': {'type': 'Point',
#    'coordinates': [-75.7421900408291, 45.277587328400415]},
#   'properties': {'OGF_ID': 321010806,
#    'MOH_SERVICE_PROVIDER_IDENT': 'N0394',
#    'SERVICE_TYPE': 'Licensed Retirement Home',
#    'SERVICE_TYPE_DETAIL': None,
#    'ENGLISH_NAME': 'Barrhaven Manor',
#    'FRENCH_NAME': None,
#    'ENGLISH_NAME_ALT': None,
#    'FRENCH_NAME_ALT': None,
#    'ADDRESS_LINE_1': '110 Berrigan Drive',
#    'ADDRESS_LINE_2': None,
#    'ADDRESS_DESCRIPTOR': None,
#    'COMMUNITY': 'Ottawa',
#    'POSTAL_CODE': 'K2J5A6',
#    'GEOMETRY_UPDATE_DATETIME': 1744234240000,
#    'EFFECTIVE_DATETIME': 1744209526000,
#    'SYSTEM_DATETIME': 1744221299000,
#    'OBJECTID': 2268097}},
#  {'type': 'Feature',
#   'id': 2268113,
#   'geometry': {'type': 'Point',
#    'coordinates': [-79.47554591746572, 43.69929948887006]},
#   'properties': {'OGF_ID': 321009875,
#    'MOH_SERVICE_PROVIDER_IDENT': '8100003',
#    'SERVICE_TYPE': 'Integrated Community Health Services Centre',
#    'SERVICE_TYPE_DETAIL': 'Fluoroscopy, Radiography, General Ultrasound',
#    'ENGLISH_NAME': 'Northwest Imaging Associates',
#    'FRENCH_NAME': None,
#    'ENGLISH_NAME_ALT': '2352898 Ontario Inc.',
#    'FRENCH_NAME_ALT': None,
#    'ADDRESS_LINE_1': '2221 Keele Street',
#    'ADDRESS_LINE_2': 'Suite 106',
#    'ADDRESS_DESCRIPTOR': None,
#    'COMMUNITY': 'North York',
#    'POSTAL_CODE': 'M6M3Z5',
#    'GEOMETRY_UPDATE_DATETIME': 1744234405000,
#    'EFFECTIVE_DATETIME': 1744209426000,
#    'SYSTEM_DATETIME': 1744221299000,
#    'OBJECTID': 2268113}},
#  {'type': 'Feature',
#   'id': 2268129,
#   'geometry': {'type': 'Point',
#    'coordinates': [-79.5076464210025, 43.62345107406832]},
#   'properties': {'OGF_ID': 321014699,
#    'MOH_SERVICE_PROVIDER_IDENT': '7048358',
#    'SERVICE_TYPE': 'Pharmacy',
#    'SERVICE_TYPE_DETAIL': 'Retail Pharmacy',
#    'ENGLISH_NAME': 'Costco Pharmacy #524',
#    'FRENCH_NAME': None,
#    'ENGLISH_NAME_ALT': None,
#    'FRENCH_NAME_ALT': None,
#    'ADDRESS_LINE_1': '50 Queen Elizabeth Boulevard',
#    'ADDRESS_LINE_2': None,
#    'ADDRESS_DESCRIPTOR': None,
#    'COMMUNITY': 'Etobicoke',
#    'POSTAL_CODE': 'M8Z1M1',
#    'GEOMETRY_UPDATE_DATETIME': 1744234572000,
#    'EFFECTIVE_DATETIME': 1744209963000,
#    'SYSTEM_DATETIME': 1744221299000,
#    'OBJECTID': 2268129}},
#  {'type': 'Feature',
#   'id': 2268145,
#   'geometry': {'type': 'Point',
#    'coordinates': [-79.7884330863995, 43.35155381310772]},
#   'properties': {'OGF_ID': 321012603,
#    'MOH_SERVICE_PROVIDER_IDENT': '3631957',
#    'SERVICE_TYPE': 'Pharmacy',
#    'SERVICE_TYPE_DETAIL': 'Retail Pharmacy',
#    'ENGLISH_NAME': 'Chez Pharmacy',
#    'FRENCH_NAME': None,
#    'ENGLISH_NAME_ALT': None,
#    'FRENCH_NAME_ALT': None,
#    'ADDRESS_LINE_1': '3230 Fairview Street',
#    'ADDRESS_LINE_2': '#2006',
#    'ADDRESS_DESCRIPTOR': None,
#    'COMMUNITY': 'Burlington',
#    'POSTAL_CODE': 'L7N3H5',
#    'GEOMETRY_UPDATE_DATETIME': 1744234619000,
#    'EFFECTIVE_DATETIME': 1744209730000,
#    'SYSTEM_DATETIME': 1744221299000,
#    'OBJECTID': 2268145}},
#  {'type': 'Feature',
#   'id': 2268161,
#   'geometry': {'type': 'Point',
#    'coordinates': [-82.61512945514836, 42.05057104636631]},
#   'properties': {'OGF_ID': 321008178,
#    'MOH_SERVICE_PROVIDER_IDENT': '3812',
#    'SERVICE_TYPE': 'Licensed Lab and Specimen Collection Centre',
#    'SERVICE_TYPE_DETAIL': 'Licensed Specimen Collection Centre Location',
#    'ENGLISH_NAME': 'Medical Laboratories Of Windsor Limited',
#    'FRENCH_NAME': None,
#    'ENGLISH_NAME_ALT': None,
#    'FRENCH_NAME_ALT': None,
#    'ADDRESS_LINE_1': '197 Talbot Street West',
#    'ADDRESS_LINE_2': None,
#    'ADDRESS_DESCRIPTOR': 'Practice Address',
#    'COMMUNITY': 'Leamington',
#    'POSTAL_CODE': 'N8H1N8',
#    'GEOMETRY_UPDATE_DATETIME': 1744234687000,
#    'EFFECTIVE_DATETIME': 1744209242000,
#    'SYSTEM_DATETIME': 1744221299000,
#    'OBJECTID': 2268161}},
#  {'type': 'Feature',
#   'id': 2268177,
#   'geometry': {'type': 'Point',
#    'coordinates': [-79.59449315915548, 43.741675090738404]},
#   'properties': {'OGF_ID': 321012929,
#    'MOH_SERVICE_PROVIDER_IDENT': '4313576',
#    'SERVICE_TYPE': 'Pharmacy',
#    'SERVICE_TYPE_DETAIL': 'Retail Pharmacy',
#    'ENGLISH_NAME': 'Albion Martingrove Pharmacy',
#    'FRENCH_NAME': None,
#    'ENGLISH_NAME_ALT': None,
#    'FRENCH_NAME_ALT': None,
#    'ADDRESS_LINE_1': '1625 Albion Road',
#    'ADDRESS_LINE_2': None,
#    'ADDRESS_DESCRIPTOR': None,
#    'COMMUNITY': 'Etobicoke',
#    'POSTAL_CODE': 'M9V5H8',
#    'GEOMETRY_UPDATE_DATETIME': 1744234444000,
#    'EFFECTIVE_DATETIME': 1744209767000,
#    'SYSTEM_DATETIME': 1744221299000,
#    'OBJECTID': 2268177}},
#  {'type': 'Feature',
#   'id': 2268193,
#   'geometry': {'type': 'Point',
#    'coordinates': [-75.76877135740718, 45.36941674299701]},
#   'properties': {'OGF_ID': 321007755,
#    'MOH_SERVICE_PROVIDER_IDENT': '3180971',
#    'SERVICE_TYPE': 'Integrated Community Health Services Centre',
#    'SERVICE_TYPE_DETAIL': 'Ophthalmic Ultrasound',
#    'ENGLISH_NAME': 'Icare Surgical Centre',
#    'FRENCH_NAME': None,
#    'ENGLISH_NAME_ALT': 'Bhatti Medicine Professional Corporation',
#    'FRENCH_NAME_ALT': None,
#    'ADDRESS_LINE_1': '2148 Carling Avenue',
#    'ADDRESS_LINE_2': 'Suite 205',
#    'ADDRESS_DESCRIPTOR': None,
#    'COMMUNITY': 'Ottawa',
#    'POSTAL_CODE': 'K2A1H1',
#    'GEOMETRY_UPDATE_DATETIME': 1744234226000,
#    'EFFECTIVE_DATETIME': 1744209196000,
#    'SYSTEM_DATETIME': 1744221299000,
#    'OBJECTID': 2268193}},
#  {'type': 'Feature',
#   'id': 2268209,
#   'geometry': {'type': 'Point',
#    'coordinates': [-91.92542598342531, 50.10601598436745]},
#   'properties': {'OGF_ID': 321017534,
#    'MOH_SERVICE_PROVIDER_IDENT': '9640',
#    'SERVICE_TYPE': 'Hospital',
#    'SERVICE_TYPE_DETAIL': 'Corporation',
#    'ENGLISH_NAME': 'Sioux Lookout Meno Ya Win Health Centre - Lookout District',
#    'FRENCH_NAME': None,
#    'ENGLISH_NAME_ALT': 'Sioux Lookout Meno Ya Win Health Centre',
#    'FRENCH_NAME_ALT': None,
#    'ADDRESS_LINE_1': '1 Meno Ya Win Way',
#    'ADDRESS_LINE_2': None,
#    'ADDRESS_DESCRIPTOR': None,
#    'COMMUNITY': 'Sioux Lookout',
#    'POSTAL_CODE': 'P8T1B4',
#    'GEOMETRY_UPDATE_DATETIME': 1744234550000,
#    'EFFECTIVE_DATETIME': 1744210282000,
#    'SYSTEM_DATETIME': 1744221299000,
#    'OBJECTID': 2268209}},
#  {'type': 'Feature',
#   'id': 2268225,
#   'geometry': {'type': 'Point',
#    'coordinates': [-76.67734870743138, 44.78943760446653]},
#   'properties': {'OGF_ID': 321009481,
#    'MOH_SERVICE_PROVIDER_IDENT': '5846',
#    'SERVICE_TYPE': 'Mental Health and Addiction Organization',
#    'SERVICE_TYPE_DETAIL': 'Mental Health Services',
#    'ENGLISH_NAME': 'Maltby Centre, The',
#    'FRENCH_NAME': None,
#    'ENGLISH_NAME_ALT': None,
#    'FRENCH_NAME_ALT': None,
#    'ADDRESS_LINE_1': '1004 Art Duffy Road',
#    'ADDRESS_LINE_2': 'The Child Centre; Rr 1',
#    'ADDRESS_DESCRIPTOR': 'Practice Location',
#    'COMMUNITY': 'Sharbot Lake',
#    'POSTAL_CODE': 'K0H2P0',
#    'GEOMETRY_UPDATE_DATETIME': 1744234701000,
#    'EFFECTIVE_DATETIME': 1744209383000,
#    'SYSTEM_DATETIME': 1744221299000,
#    'OBJECTID': 2268225}},
#  {'type': 'Feature',
#   'id': 2268241,
#   'geometry': {'type': 'Point',
#    'coordinates': [-79.34788898372828, 43.77852540868418]},
#   'properties': {'OGF_ID': 321006842,
#    'MOH_SERVICE_PROVIDER_IDENT': '20201',
#    'SERVICE_TYPE': 'Community Health Centre',
#    'SERVICE_TYPE_DETAIL': 'Satellite',
#    'ENGLISH_NAME': 'The Centre Francophone Du Grand Toronto Medical Clinic',
#    'FRENCH_NAME': 'The Centre Francophone Du Grand Toronto Medical Clinic',
#    'ENGLISH_NAME_ALT': None,
#    'FRENCH_NAME_ALT': None,
#    'ADDRESS_LINE_1': '5 Fairview Mall Road, Suite 280',
#    'ADDRESS_LINE_2': None,
#    'ADDRESS_DESCRIPTOR': None,
#    'COMMUNITY': 'North York',
#    'POSTAL_CODE': 'M2J2Z1',
#    'GEOMETRY_UPDATE_DATETIME': 1744234614000,
#    'EFFECTIVE_DATETIME': 1744209095000,
#    'SYSTEM_DATETIME': 1744221299000,
#    'OBJECTID': 2268241}},
#  {'type': 'Feature',
#   'id': 2268257,
#   'geometry': {'type': 'Point',
#    'coordinates': [-79.56611008361755, 44.114241356904635]},
#   'properties': {'OGF_ID': 321016975,
#    'MOH_SERVICE_PROVIDER_IDENT': '9618513',
#    'SERVICE_TYPE': 'Pharmacy',
#    'SERVICE_TYPE_DETAIL': 'Retail Pharmacy',
#    'ENGLISH_NAME': 'Milan Pharmacy',
#    'FRENCH_NAME': None,
#    'ENGLISH_NAME_ALT': None,
#    'FRENCH_NAME_ALT': None,
#    'ADDRESS_LINE_1': '37 Holland Street West',
#    'ADDRESS_LINE_2': None,
#    'ADDRESS_DESCRIPTOR': None,
#    'COMMUNITY': 'Bradford',
#    'POSTAL_CODE': 'L3Z2B9',
#    'GEOMETRY_UPDATE_DATETIME': 1744234284000,
#    'EFFECTIVE_DATETIME': 1744210219000,
#    'SYSTEM_DATETIME': 1744221299000,
#    'OBJECTID': 2268257}},
#  {'type': 'Feature',
#   'id': 2268273,
#   'geometry': {'type': 'Point',
#    'coordinates': [-80.95805970360927, 42.7641740538486]},
#   'properties': {'OGF_ID': 321015184,
#    'MOH_SERVICE_PROVIDER_IDENT': '7675018',
#    'SERVICE_TYPE': 'Pharmacy',
#    'SERVICE_TYPE_DETAIL': 'Long Term Care Facility',
#    'ENGLISH_NAME': 'Country Terrace',
#    'FRENCH_NAME': None,
#    'ENGLISH_NAME_ALT': None,
#    'FRENCH_NAME_ALT': None,
#    'ADDRESS_LINE_1': 'Rural Route 3',
#    'ADDRESS_LINE_2': None,
#    'ADDRESS_DESCRIPTOR': None,
#    'COMMUNITY': 'Komoka',
#    'POSTAL_CODE': 'N0L1R0',
#    'GEOMETRY_UPDATE_DATETIME': 1744234362000,
#    'EFFECTIVE_DATETIME': 1744210018000,
#    'SYSTEM_DATETIME': 1744221299000,
#    'OBJECTID': 2268273}},
#  {'type': 'Feature',
#   'id': 2268289,
#   'geometry': {'type': 'Point',
#    'coordinates': [-80.14412305895615, 42.89166001489364]},
#   'properties': {'OGF_ID': 321007134,
#    'MOH_SERVICE_PROVIDER_IDENT': '247',
#    'SERVICE_TYPE': 'Mental Health and Addiction Organization',
#    'SERVICE_TYPE_DETAIL': 'Mental Health Services',
#    'ENGLISH_NAME': 'Haldimand-Norfolk Reach',
#    'FRENCH_NAME': None,
#    'ENGLISH_NAME_ALT': None,
#    'FRENCH_NAME_ALT': None,
#    'ADDRESS_LINE_1': '101A Nanticoke Creek Parkway',
#    'ADDRESS_LINE_2': None,
#    'ADDRESS_DESCRIPTOR': 'Administration And Practice Location',
#    'COMMUNITY': 'Townsend',
#    'POSTAL_CODE': 'N0A1S0',
#    'GEOMETRY_UPDATE_DATETIME': 1744234437000,
#    'EFFECTIVE_DATETIME': 1744209127000,
#    'SYSTEM_DATETIME': 1744221299000,
#    'OBJECTID': 2268289}},
#  {'type': 'Feature',
#   'id': 2268305,
#   'geometry': {'type': 'Point',
#    'coordinates': [-81.22555500457369, 42.958335575449496]},
#   'properties': {'OGF_ID': 321017456,
#    'MOH_SERVICE_PROVIDER_IDENT': '9360',
#    'SERVICE_TYPE': 'Hospital',
#    'SERVICE_TYPE_DETAIL': 'Corporation',
#    'ENGLISH_NAME': 'London Health Sciences Centre - Victoria',
#    'FRENCH_NAME': None,
#    'ENGLISH_NAME_ALT': 'London Health Sciences Centre',
#    'FRENCH_NAME_ALT': None,
#    'ADDRESS_LINE_1': '800 Commissioners Road East',
#    'ADDRESS_LINE_2': None,
#    'ADDRESS_DESCRIPTOR': None,
#    'COMMUNITY': 'London',
#    'POSTAL_CODE': 'N6A5W9',
#    'GEOMETRY_UPDATE_DATETIME': 1744234586000,
#    'EFFECTIVE_DATETIME': 1744210273000,
#    'SYSTEM_DATETIME': 1744221299000,
#    'OBJECTID': 2268305}},
#  {'type': 'Feature',
#   'id': 2268321,
#   'geometry': {'type': 'Point',
#    'coordinates': [-80.99563556952064, 43.36947385885172]},
#   'properties': {'OGF_ID': 321010079,
#    'MOH_SERVICE_PROVIDER_IDENT': '9000000060',
#    'SERVICE_TYPE': 'Midwifery Clinic',
#    'SERVICE_TYPE_DETAIL': 'Main',
#    'ENGLISH_NAME': 'Stratford Midwives',
#    'FRENCH_NAME': None,
#    'ENGLISH_NAME_ALT': None,
#    'FRENCH_NAME_ALT': None,
#    'ADDRESS_LINE_1': '386 Cambria Street',
#    'ADDRESS_LINE_2': None,
#    'ADDRESS_DESCRIPTOR': 'Practice Location',
#    'COMMUNITY': 'Stratford',
#    'POSTAL_CODE': 'N5A1J4',
#    'GEOMETRY_UPDATE_DATETIME': 1744234541000,
#    'EFFECTIVE_DATETIME': 1744209449000,
#    'SYSTEM_DATETIME': 1744221299000,
#    'OBJECTID': 2268321}},
#  {'type': 'Feature',
#   'id': 2268337,
#   'geometry': {'type': 'Point',
#    'coordinates': [-80.21621692779156, 44.50288149244803]},
#   'properties': {'OGF_ID': 321007505,
#    'MOH_SERVICE_PROVIDER_IDENT': '3067',
#    'SERVICE_TYPE': 'Licensed Lab and Specimen Collection Centre',
#    'SERVICE_TYPE_DETAIL': 'Licensed Specimen Collection Centre Location',
#    'ENGLISH_NAME': 'Alpha Laboratories',
#    'FRENCH_NAME': None,
#    'ENGLISH_NAME_ALT': None,
#    'FRENCH_NAME_ALT': None,
#    'ADDRESS_LINE_1': '28 Huron Street Suite 102',
#    'ADDRESS_LINE_2': None,
#    'ADDRESS_DESCRIPTOR': 'Practice Address',
#    'COMMUNITY': 'Collingwood',
#    'POSTAL_CODE': 'L9Y1C4',
#    'GEOMETRY_UPDATE_DATETIME': 1744234700000,
#    'EFFECTIVE_DATETIME': 1744209168000,
#    'SYSTEM_DATETIME': 1744221299000,
#    'OBJECTID': 2268337}},
#  {'type': 'Feature',
#   'id': 2268353,
#   'geometry': {'type': 'Point',
#    'coordinates': [-79.43672031986121, 43.86579541979964]},
#   'properties': {'OGF_ID': 321011293,
#    'MOH_SERVICE_PROVIDER_IDENT': 'T0204',
#    'SERVICE_TYPE': 'Licensed Retirement Home',
#    'SERVICE_TYPE_DETAIL': None,
#    'ENGLISH_NAME': 'Sunrise Senior Living Of Richmond Hill',
#    'FRENCH_NAME': None,
#    'ENGLISH_NAME_ALT': None,
#    'FRENCH_NAME_ALT': None,
#    'ADDRESS_LINE_1': '9800 Yonge Street',
#    'ADDRESS_LINE_2': None,
#    'ADDRESS_DESCRIPTOR': None,
#    'COMMUNITY': 'Richmond Hill',
#    'POSTAL_CODE': 'L4C0P5',
#    'GEOMETRY_UPDATE_DATETIME': 1744234611000,
#    'EFFECTIVE_DATETIME': 1744209581000,
#    'SYSTEM_DATETIME': 1744221299000,
#    'OBJECTID': 2268353}},
#  {'type': 'Feature',
#   'id': 2268369,
#   'geometry': {'type': 'Point',
#    'coordinates': [-79.86268789633426, 43.195600682052834]},
#   'properties': {'OGF_ID': 321015139,
#    'MOH_SERVICE_PROVIDER_IDENT': '7610837',
#    'SERVICE_TYPE': 'Pharmacy',
#    'SERVICE_TYPE_DETAIL': 'Retail Pharmacy',
#    'ENGLISH_NAME': 'Sherman IDA Pharmacy',
#    'FRENCH_NAME': None,
# ...
#    'FRENCH_NAME': None,
#    'ENGLISH_NAME_ALT': None,
#    'FRENCH_NAME_ALT': None,
#    'ADDRESS_LINE_1': '377 Church Street',
#    'ADDRESS_LINE_2': 'Suite 101',
#    'ADDRESS_DESCRIPTOR': '82',
#    'COMMUNITY': 'Markham',
#    'POSTAL_CODE': 'L6B1A1',
#    'GEOMETRY_UPDATE_DATETIME': 1744234289000,
#    'EFFECTIVE_DATETIME': 1744209433000,
#    'SYSTEM_DATETIME': 1744221299000,
#    'OBJECTID': 2272785}},
#  {'type': 'Feature',
#   'id': 2272801,
#   'geometry': {'type': 'Point',
#    'coordinates': [-79.73584139650136, 43.65538896901125]},
#   'properties': {'OGF_ID': 321013339,
#    'MOH_SERVICE_PROVIDER_IDENT': '5036837',
#    'SERVICE_TYPE': 'Pharmacy',
#    'SERVICE_TYPE_DETAIL': 'Long Term Care Facility',
#    'ENGLISH_NAME': 'Extendicare/Brampton',
#    'FRENCH_NAME': None,
#    'ENGLISH_NAME_ALT': None,
#    'FRENCH_NAME_ALT': None,
#    'ADDRESS_LINE_1': '7891 Mclaughlin Road',
#    'ADDRESS_LINE_2': None,
#    'ADDRESS_DESCRIPTOR': None,
#    'COMMUNITY': 'Brampton',
#    'POSTAL_CODE': 'L6V3N2',
#    'GEOMETRY_UPDATE_DATETIME': 1744234475000,
#    'EFFECTIVE_DATETIME': 1744209812000,
#    'SYSTEM_DATETIME': 1744221299000,
#    'OBJECTID': 2272801}},
#  {'type': 'Feature',
#   'id': 2272817,
#   'geometry': {'type': 'Point',
#    'coordinates': [-79.72498689343605, 43.65976697028731]},
#   'properties': {'OGF_ID': 321007908,
#    'MOH_SERVICE_PROVIDER_IDENT': '3431',
#    'SERVICE_TYPE': 'Mental Health and Addiction Organization',
#    'SERVICE_TYPE_DETAIL': 'Mental Health Services',
#    'ENGLISH_NAME': 'Reconnect Community Health Services',
#    'FRENCH_NAME': None,
#    'ENGLISH_NAME_ALT': None,
#    'FRENCH_NAME_ALT': None,
#    'ADDRESS_LINE_1': '7700 Hurontario Street',
#    'ADDRESS_LINE_2': 'Suite: 601',
#    'ADDRESS_DESCRIPTOR': 'Practice Location',
#    'COMMUNITY': 'Brampton',
#    'POSTAL_CODE': 'L6Y4M3',
#    'GEOMETRY_UPDATE_DATETIME': 1744234588000,
#    'EFFECTIVE_DATETIME': 1744209213000,
#    'SYSTEM_DATETIME': 1744221299000,
#    'OBJECTID': 2272817}},
#  {'type': 'Feature',
#   'id': 2272833,
#   'geometry': {'type': 'Point',
#    'coordinates': [-75.68729753311985, 45.40138755189371]},
#   'properties': {'OGF_ID': 321014359,
#    'MOH_SERVICE_PROVIDER_IDENT': '6583636',
#    'SERVICE_TYPE': 'Pharmacy',
#    'SERVICE_TYPE_DETAIL': 'Retail Pharmacy',
#    'ENGLISH_NAME': 'Whole Health Pharmacy Glebe',
#    'FRENCH_NAME': None,
#    'ENGLISH_NAME_ALT': None,
#    'FRENCH_NAME_ALT': None,
#    'ADDRESS_LINE_1': '857A Bank Street',
#    'ADDRESS_LINE_2': None,
#    'ADDRESS_DESCRIPTOR': None,
#    'COMMUNITY': 'Ottawa',
#    'POSTAL_CODE': 'K1S3W2',
#    'GEOMETRY_UPDATE_DATETIME': 1744234557000,
#    'EFFECTIVE_DATETIME': 1744209926000,
#    'SYSTEM_DATETIME': 1744221299000,
#    'OBJECTID': 2272833}},
#  {'type': 'Feature',
#   'id': 2272849,
#   'geometry': {'type': 'Point',
#    'coordinates': [-75.68888103623168, 45.431856957029304]},
#   'properties': {'OGF_ID': 321007317,
#    'MOH_SERVICE_PROVIDER_IDENT': '2889',
#    'SERVICE_TYPE': 'Mental Health and Addiction Organization',
#    'SERVICE_TYPE_DETAIL': 'Mental Health Services',
#    'ENGLISH_NAME': 'Shepherds Of Good Hope',
#    'FRENCH_NAME': None,
#    'ENGLISH_NAME_ALT': None,
#    'FRENCH_NAME_ALT': None,
#    'ADDRESS_LINE_1': '233 Murray Street',
#    'ADDRESS_LINE_2': None,
#    'ADDRESS_DESCRIPTOR': 'Administration And Practice Location',
#    'COMMUNITY': 'Ottawa',
#    'POSTAL_CODE': 'K1N5M9',
#    'GEOMETRY_UPDATE_DATETIME': 1744234704000,
#    'EFFECTIVE_DATETIME': 1744209147000,
#    'SYSTEM_DATETIME': 1744221299000,
#    'OBJECTID': 2272849}},
#  {'type': 'Feature',
#   'id': 2272865,
#   'geometry': {'type': 'Point',
#    'coordinates': [-79.824027731721, 43.73542197886343]},
#   'properties': {'OGF_ID': 321016477,
#    'MOH_SERVICE_PROVIDER_IDENT': '9206110',
#    'SERVICE_TYPE': 'Pharmacy',
#    'SERVICE_TYPE_DETAIL': 'Retail Pharmacy',
#    'ENGLISH_NAME': 'Mayfield Pharmacare',
#    'FRENCH_NAME': None,
#    'ENGLISH_NAME_ALT': None,
#    'FRENCH_NAME_ALT': None,
#    'ADDRESS_LINE_1': '3068 Mayfield Road',
#    'ADDRESS_LINE_2': 'Units 8&9',
#    'ADDRESS_DESCRIPTOR': None,
#    'COMMUNITY': 'Brampton',
#    'POSTAL_CODE': 'L6Z0E3',
#    'GEOMETRY_UPDATE_DATETIME': 1744234630000,
#    'EFFECTIVE_DATETIME': 1744210163000,
#    'SYSTEM_DATETIME': 1744221299000,
#    'OBJECTID': 2272865}},
#  {'type': 'Feature',
#   'id': 2272881,
#   'geometry': {'type': 'Point',
#    'coordinates': [-79.62613485553796, 43.58718396217913]},
#   'properties': {'OGF_ID': 321015387,
#    'MOH_SERVICE_PROVIDER_IDENT': '7983319',
#    'SERVICE_TYPE': 'Pharmacy',
#    'SERVICE_TYPE_DETAIL': 'Retail Pharmacy',
#    'ENGLISH_NAME': 'Fairview Medical Pharmacy',
#    'FRENCH_NAME': None,
#    'ENGLISH_NAME_ALT': None,
#    'FRENCH_NAME_ALT': None,
#    'ADDRESS_LINE_1': '12-3355 Hurontario Street',
#    'ADDRESS_LINE_2': None,
#    'ADDRESS_DESCRIPTOR': None,
#    'COMMUNITY': 'Mississauga',
#    'POSTAL_CODE': 'L5A4E7',
#    'GEOMETRY_UPDATE_DATETIME': 1744234268000,
#    'EFFECTIVE_DATETIME': 1744210040000,
#    'SYSTEM_DATETIME': 1744221299000,
#    'OBJECTID': 2272881}},
#  {'type': 'Feature',
#   'id': 2272897,
#   'geometry': {'type': 'Point',
#    'coordinates': [-81.23595281043816, 42.98744998008784]},
#   'properties': {'OGF_ID': 321016867,
#    'MOH_SERVICE_PROVIDER_IDENT': '9547911',
#    'SERVICE_TYPE': 'Pharmacy',
#    'SERVICE_TYPE_DETAIL': 'Retail Pharmacy',
#    'ENGLISH_NAME': 'Pharmasave Dundas Street',
#    'FRENCH_NAME': None,
#    'ENGLISH_NAME_ALT': None,
#    'FRENCH_NAME_ALT': None,
#    'ADDRESS_LINE_1': '1-493-495 Dundas Street',
#    'ADDRESS_LINE_2': None,
#    'ADDRESS_DESCRIPTOR': None,
#    'COMMUNITY': 'London',
#    'POSTAL_CODE': 'N6B1W4',
#    'GEOMETRY_UPDATE_DATETIME': 1744234355000,
#    'EFFECTIVE_DATETIME': 1744210207000,
#    'SYSTEM_DATETIME': 1744221299000,
#    'OBJECTID': 2272897}},
#  {'type': 'Feature',
#   'id': 2272913,
#   'geometry': {'type': 'Point',
#    'coordinates': [-79.40219158941336, 43.646487183011686]},
#   'properties': {'OGF_ID': 321006208,
#    'MOH_SERVICE_PROVIDER_IDENT': '101034',
#    'SERVICE_TYPE': 'HIV AIDS and Hep C Program',
#    'SERVICE_TYPE_DETAIL': 'CBAESP, HCV Service',
#    'ENGLISH_NAME': 'Canadian AIDS Treatment Information Exchange',
#    'FRENCH_NAME': None,
#    'ENGLISH_NAME_ALT': None,
#    'FRENCH_NAME_ALT': None,
#    'ADDRESS_LINE_1': '555 Richmond Street West',
#    'ADDRESS_LINE_2': 'Suite 505, P.O. Box 1104',
#    'ADDRESS_DESCRIPTOR': 'Practice Location',
#    'COMMUNITY': 'Toronto',
#    'POSTAL_CODE': 'M5V3B1',
#    'GEOMETRY_UPDATE_DATETIME': 1744234443000,
#    'EFFECTIVE_DATETIME': 1744209015000,
#    'SYSTEM_DATETIME': 1744221299000,
#    'OBJECTID': 2272913}},
#  {'type': 'Feature',
#   'id': 2272929,
#   'geometry': {'type': 'Point',
#    'coordinates': [-79.43782791002327, 43.75116679971216]},
#   'properties': {'OGF_ID': 321015728,
#    'MOH_SERVICE_PROVIDER_IDENT': '83901',
#    'SERVICE_TYPE': 'Pharmacy',
#    'SERVICE_TYPE_DETAIL': 'Retail Pharmacy',
#    'ENGLISH_NAME': 'Sunshine Drugs Bathurst',
#    'FRENCH_NAME': None,
#    'ENGLISH_NAME_ALT': None,
#    'FRENCH_NAME_ALT': None,
#    'ADDRESS_LINE_1': '108-4256 Bathurst Street',
#    'ADDRESS_LINE_2': None,
#    'ADDRESS_DESCRIPTOR': None,
#    'COMMUNITY': 'North York',
#    'POSTAL_CODE': 'M3H5Y8',
#    'GEOMETRY_UPDATE_DATETIME': 1744234641000,
#    'EFFECTIVE_DATETIME': 1744210078000,
#    'SYSTEM_DATETIME': 1744221299000,
#    'OBJECTID': 2272929}},
#  {'type': 'Feature',
#   'id': 2272945,
#   'geometry': {'type': 'Point',
#    'coordinates': [-79.383091884996, 43.66552788724098]},
#   'properties': {'OGF_ID': 321016521,
#    'MOH_SERVICE_PROVIDER_IDENT': '9246032',
#    'SERVICE_TYPE': 'Pharmacy',
#    'SERVICE_TYPE_DETAIL': 'Retail Pharmacy',
#    'ENGLISH_NAME': 'Srx Pharmacy',
#    'FRENCH_NAME': None,
#    'ENGLISH_NAME_ALT': None,
#    'FRENCH_NAME_ALT': None,
#    'ADDRESS_LINE_1': '34 Wellesley Street East',
#    'ADDRESS_LINE_2': None,
#    'ADDRESS_DESCRIPTOR': None,
#    'COMMUNITY': 'Toronto',
#    'POSTAL_CODE': 'M4Y1G7',
#    'GEOMETRY_UPDATE_DATETIME': 1744234405000,
#    'EFFECTIVE_DATETIME': 1744210168000,
#    'SYSTEM_DATETIME': 1744221299000,
#    'OBJECTID': 2272945}},
#  {'type': 'Feature',
#   'id': 2272961,
#   'geometry': {'type': 'Point',
#    'coordinates': [-82.71996060904969, 42.2936024845567]},
#   'properties': {'OGF_ID': 321011013,
#    'MOH_SERVICE_PROVIDER_IDENT': 'S0157',
#    'SERVICE_TYPE': 'Licensed Retirement Home',
#    'SERVICE_TYPE_DETAIL': None,
#    'ENGLISH_NAME': 'Seasons Belle River',
#    'FRENCH_NAME': None,
#    'ENGLISH_NAME_ALT': None,
#    'FRENCH_NAME_ALT': None,
#    'ADDRESS_LINE_1': '1700 County Road #22',
#    'ADDRESS_LINE_2': None,
#    'ADDRESS_DESCRIPTOR': None,
#    'COMMUNITY': 'Belle River',
#    'POSTAL_CODE': 'N0R1A0',
#    'GEOMETRY_UPDATE_DATETIME': 1744234200000,
#    'EFFECTIVE_DATETIME': 1744209550000,
#    'SYSTEM_DATETIME': 1744221299000,
#    'OBJECTID': 2272961}},
#  {'type': 'Feature',
#   'id': 2272977,
#   'geometry': {'type': 'Point',
#    'coordinates': [-79.85053659703405, 43.24786669187867]},
#   'properties': {'OGF_ID': 321013745,
#    'MOH_SERVICE_PROVIDER_IDENT': '5694858',
#    'SERVICE_TYPE': 'Pharmacy',
#    'SERVICE_TYPE_DETAIL': 'Long Term Care Facility',
#    'ENGLISH_NAME': 'Hamilton Continuing Care',
#    'FRENCH_NAME': None,
#    'ENGLISH_NAME_ALT': None,
#    'FRENCH_NAME_ALT': None,
#    'ADDRESS_LINE_1': '125 Wentworth Street South',
#    'ADDRESS_LINE_2': None,
#    'ADDRESS_DESCRIPTOR': None,
#    'COMMUNITY': 'Hamilton',
#    'POSTAL_CODE': 'L8N2Z1',
#    'GEOMETRY_UPDATE_DATETIME': 1744234541000,
#    'EFFECTIVE_DATETIME': 1744209857000,
#    'SYSTEM_DATETIME': 1744221299000,
#    'OBJECTID': 2272977}},
#  {'type': 'Feature',
#   'id': 2272993,
#   'geometry': {'type': 'Point',
#    'coordinates': [-79.78945157644723, 43.23373149221625]},
#   'properties': {'OGF_ID': 321012792,
#    'MOH_SERVICE_PROVIDER_IDENT': '4074192',
#    'SERVICE_TYPE': 'Pharmacy',
#    'SERVICE_TYPE_DETAIL': 'Retail Pharmacy',
#    'ENGLISH_NAME': 'The Hamilton Pharmacy',
#    'FRENCH_NAME': None,
#    'ENGLISH_NAME_ALT': None,
#    'FRENCH_NAME_ALT': None,
#    'ADDRESS_LINE_1': '335 Queenston Road',
#    'ADDRESS_LINE_2': None,
#    'ADDRESS_DESCRIPTOR': None,
#    'COMMUNITY': 'Hamilton',
#    'POSTAL_CODE': 'L8K1H7',
#    'GEOMETRY_UPDATE_DATETIME': 1744234700000,
#    'EFFECTIVE_DATETIME': 1744209751000,
#    'SYSTEM_DATETIME': 1744221299000,
#    'OBJECTID': 2272993}},
#  {'type': 'Feature',
#   'id': 2273009,
#   'geometry': {'type': 'Point',
#    'coordinates': [-80.51566012599716, 43.45629609717748]},
#   'properties': {'OGF_ID': 321015971,
#    'MOH_SERVICE_PROVIDER_IDENT': '8677513',
#    'SERVICE_TYPE': 'Pharmacy',
#    'SERVICE_TYPE_DETAIL': 'Retail Pharmacy',
#    'ENGLISH_NAME': 'Spark Pharmacy',
#    'FRENCH_NAME': None,
#    'ENGLISH_NAME_ALT': None,
#    'FRENCH_NAME_ALT': None,
#    'ADDRESS_LINE_1': '535 Park Street',
#    'ADDRESS_LINE_2': None,
#    'ADDRESS_DESCRIPTOR': None,
#    'COMMUNITY': 'Kitchener',
#    'POSTAL_CODE': 'N2G1N8',
#    'GEOMETRY_UPDATE_DATETIME': 1744234403000,
#    'EFFECTIVE_DATETIME': 1744210106000,
#    'SYSTEM_DATETIME': 1744221299000,
#    'OBJECTID': 2273009}},
#  {'type': 'Feature',
#   'id': 2273025,
#   'geometry': {'type': 'Point',
#    'coordinates': [-81.18343525337902, 46.57570858420468]},
#   'properties': {'OGF_ID': 321017942,
#    'MOH_SERVICE_PROVIDER_IDENT': '4725',
#    'SERVICE_TYPE': 'Long-Term Care Home',
#    'SERVICE_TYPE_DETAIL': 'NH non-profit',
#    'ENGLISH_NAME': "St. Gabriel's Villa of Sudbury",
#    'FRENCH_NAME': None,
#    'ENGLISH_NAME_ALT': None,
#    'FRENCH_NAME_ALT': None,
#    'ADDRESS_LINE_1': '4690 Municipal Road 15',
#    'ADDRESS_LINE_2': None,
#    'ADDRESS_DESCRIPTOR': None,
#    'COMMUNITY': 'Chelmsford',
#    'POSTAL_CODE': 'P0M1L0',
#    'GEOMETRY_UPDATE_DATETIME': 1744234239000,
#    'EFFECTIVE_DATETIME': 1744216944000,
#    'SYSTEM_DATETIME': 1744221299000,
#    'OBJECTID': 2273025}},
#  {'type': 'Feature',
#   'id': 2273041,
#   'geometry': {'type': 'Point',
#    'coordinates': [-83.0219864022949, 42.29724247018098]},
#   'properties': {'OGF_ID': 321009549,
#    'MOH_SERVICE_PROVIDER_IDENT': '604290',
#    'SERVICE_TYPE': 'Integrated Community Health Services Centre',
#    'SERVICE_TYPE_DETAIL': 'Radiography, General Ultrasound',
#    'ENGLISH_NAME': 'Clear Medical Imaging',
#    'FRENCH_NAME': None,
#    'ENGLISH_NAME_ALT': '2324317 Ontario Ltd.',
#    'FRENCH_NAME_ALT': None,
#    'ADDRESS_LINE_1': '250 Tecumseh Road East',
#    'ADDRESS_LINE_2': 'Building 100, Unit 120',
#    'ADDRESS_DESCRIPTOR': None,
#    'COMMUNITY': 'Windsor',
#    'POSTAL_CODE': 'N8X2R3',
#    'GEOMETRY_UPDATE_DATETIME': 1744234330000,
#    'EFFECTIVE_DATETIME': 1744209390000,
#    'SYSTEM_DATETIME': 1744221299000,
#    'OBJECTID': 2273041}},
#  {'type': 'Feature',
#   'id': 2273057,
#   'geometry': {'type': 'Point',
#    'coordinates': [-79.45446184295467, 44.05984995273585]},
#   'properties': {'OGF_ID': 321007106,
#    'MOH_SERVICE_PROVIDER_IDENT': '240507',
#    'SERVICE_TYPE': 'HIV AIDS and Hep C Program',
#    'SERVICE_TYPE_DETAIL': 'At Site, HIV POC Testing',
#    'ENGLISH_NAME': 'York Region Public Health Services, Sexual Health Clinic',
#    'FRENCH_NAME': None,
#    'ENGLISH_NAME_ALT': None,
#    'FRENCH_NAME_ALT': None,
#    'ADDRESS_LINE_1': '22 Prospect Street',
#    'ADDRESS_LINE_2': None,
#    'ADDRESS_DESCRIPTOR': 'Practice Location',
#    'COMMUNITY': 'Newmarket',
#    'POSTAL_CODE': 'L3Y3S9',
#    'GEOMETRY_UPDATE_DATETIME': 1744234639000,
#    'EFFECTIVE_DATETIME': 1744209124000,
#    'SYSTEM_DATETIME': 1744221299000,
#    'OBJECTID': 2273057}},
#  {'type': 'Feature',
#   'id': 2273073,
#   'geometry': {'type': 'Point',
#    'coordinates': [-79.59846854903863, 43.61332116805954]},
#   'properties': {'OGF_ID': 321011554,
#    'MOH_SERVICE_PROVIDER_IDENT': '1209793',
#    'SERVICE_TYPE': 'Pharmacy',
#    'SERVICE_TYPE_DETAIL': 'Retail Pharmacy',
#    'ENGLISH_NAME': 'Apple-Hills Medical Pharmacy',
#    'FRENCH_NAME': None,
#    'ENGLISH_NAME_ALT': None,
#    'FRENCH_NAME_ALT': None,
#    'ADDRESS_LINE_1': '1221 Bloor Street East',
#    'ADDRESS_LINE_2': None,
#    'ADDRESS_DESCRIPTOR': None,
#    'COMMUNITY': 'Mississauga',
#    'POSTAL_CODE': 'L4Y2N8',
#    'GEOMETRY_UPDATE_DATETIME': 1744234204000,
#    'EFFECTIVE_DATETIME': 1744209612000,
#    'SYSTEM_DATETIME': 1744221299000,
#    'OBJECTID': 2273073}},
#  {'type': 'Feature',
#   'id': 2273089,
#   'geometry': {'type': 'Point',
#    'coordinates': [-79.30593097599301, 43.84256792183537]},
#   'properties': {'OGF_ID': 321014253,
#    'MOH_SERVICE_PROVIDER_IDENT': '6436751',
#    'SERVICE_TYPE': 'Pharmacy',
#    'SERVICE_TYPE_DETAIL': 'Retail Pharmacy',
#    'ENGLISH_NAME': 'Janedal Pharmacy',
#    'FRENCH_NAME': None,
#    'ENGLISH_NAME_ALT': None,
#    'FRENCH_NAME_ALT': None,
#    'ADDRESS_LINE_1': '7A-7750 Kennedy Road',
#    'ADDRESS_LINE_2': None,
#    'ADDRESS_DESCRIPTOR': None,
#    'COMMUNITY': 'Markham',
#    'POSTAL_CODE': 'L3R0A7',
#    'GEOMETRY_UPDATE_DATETIME': 1744234532000,
#    'EFFECTIVE_DATETIME': 1744209914000,
#    'SYSTEM_DATETIME': 1744221299000,
#    'OBJECTID': 2273089}},
#  {'type': 'Feature',
#   'id': 2273105,
#   'geometry': {'type': 'Point',
#    'coordinates': [-81.36219794823211, 42.968273170591424]},
#   'properties': {'OGF_ID': 321010980,
#    'MOH_SERVICE_PROVIDER_IDENT': 'S01218',
#    'SERVICE_TYPE': 'Licensed Retirement Home',
#    'SERVICE_TYPE_DETAIL': None,
#    'ENGLISH_NAME': 'Riverstone Retirement Residence',
#    'FRENCH_NAME': None,
#    'ENGLISH_NAME_ALT': None,
#    'FRENCH_NAME_ALT': None,
#    'ADDRESS_LINE_1': '1951 Shore Road',
#    'ADDRESS_LINE_2': None,
#    'ADDRESS_DESCRIPTOR': None,
#    'COMMUNITY': 'London',
#    'POSTAL_CODE': 'N6K0K4',
#    'GEOMETRY_UPDATE_DATETIME': 1744234682000,
#    'EFFECTIVE_DATETIME': 1744209546000,
#    'SYSTEM_DATETIME': 1744221299000,
#    'OBJECTID': 2273105}},
#  {'type': 'Feature',
#   'id': 2273121,
#   'geometry': {'type': 'Point',
#    'coordinates': [-79.80565247687393, 43.179500781847466]},
#   'properties': {'OGF_ID': 321013344,
#    'MOH_SERVICE_PROVIDER_IDENT': '5049556',
#    'SERVICE_TYPE': 'Pharmacy',
#    'SERVICE_TYPE_DETAIL': 'Retail Pharmacy',
#    'ENGLISH_NAME': 'Fletcher Pharmacy',
#    'FRENCH_NAME': None,
#    'ENGLISH_NAME_ALT': None,
#    'FRENCH_NAME_ALT': None,
#    'ADDRESS_LINE_1': '2-1962 Rymal Road East',
#    'ADDRESS_LINE_2': None,
#    'ADDRESS_DESCRIPTOR': None,
#    'COMMUNITY': 'Hamilton',
#    'POSTAL_CODE': 'L0R1P0',
#    'GEOMETRY_UPDATE_DATETIME': 1744234420000,
#    'EFFECTIVE_DATETIME': 1744209813000,
#    'SYSTEM_DATETIME': 1744221299000,
#    'OBJECTID': 2273121}},
#  ...]

# %%
len(response['features'])
# Out:
# 2000

# %%
response['exceededTransferLimit']
# Out:
# True

# %%
params = {
    'outFields': '*',
    'where': '1=1',
    'f': 'geojson',
    "resultOffset": 0
}

features = []

while True:
    response = requests.get(url, params=params).json()

    if not response.get('features'):
        break

    features.extend(response['features'])
    params['resultOffset'] += len(response['features'])

# %%
len(features)
# Out:
# 11974

# %%
features
# Out:
# [{'type': 'Feature',
#   'id': 2258241,
#   'geometry': {'type': 'Point',
#    'coordinates': [-83.02664460387791, 42.298914270244566]},
#   'properties': {'OGF_ID': 321006337,
#    'MOH_SERVICE_PROVIDER_IDENT': '1154419',
#    'SERVICE_TYPE': 'Integrated Community Health Services Centre',
#    'SERVICE_TYPE_DETAIL': 'Bone Mineral Dxa, Fluoroscopy, Radiography, General Ultrasound, Vascular Ultrasound, Mammography',
#    'ENGLISH_NAME': 'Clear Medical Imaging',
#    'FRENCH_NAME': None,
#    'ENGLISH_NAME_ALT': '2324317 Ontario Ltd.',
#    'FRENCH_NAME_ALT': None,
#    'ADDRESS_LINE_1': '1568 Ouellette Avenue',
#    'ADDRESS_LINE_2': None,
#    'ADDRESS_DESCRIPTOR': None,
#    'COMMUNITY': 'Windsor',
#    'POSTAL_CODE': 'N8X1K7',
#    'GEOMETRY_UPDATE_DATETIME': 1744234662000,
#    'EFFECTIVE_DATETIME': 1744209030000,
#    'SYSTEM_DATETIME': 1744221299000,
#    'OBJECTID': 2258241}},
#  {'type': 'Feature',
#   'id': 2258257,
#   'geometry': {'type': 'Point',
#    'coordinates': [-77.56906163975705, 44.10448104625137]},
#   'properties': {'OGF_ID': 321013957,
#    'MOH_SERVICE_PROVIDER_IDENT': '6027596',
#    'SERVICE_TYPE': 'Pharmacy',
#    'SERVICE_TYPE_DETAIL': 'Retail Pharmacy',
#    'ENGLISH_NAME': 'Rexall #1008',
#    'FRENCH_NAME': None,
#    'ENGLISH_NAME_ALT': None,
#    'FRENCH_NAME_ALT': None,
#    'ADDRESS_LINE_1': '109 Dundas Street East',
#    'ADDRESS_LINE_2': None,
#    'ADDRESS_DESCRIPTOR': None,
#    'COMMUNITY': 'Trenton',
#    'POSTAL_CODE': 'K8V1L1',
#    'GEOMETRY_UPDATE_DATETIME': 1744234399000,
#    'EFFECTIVE_DATETIME': 1744209880000,
#    'SYSTEM_DATETIME': 1744221299000,
#    'OBJECTID': 2258257}},
#  {'type': 'Feature',
#   'id': 2258273,
#   'geometry': {'type': 'Point',
#    'coordinates': [-79.7926824881633, 43.356301213748104]},
#   'properties': {'OGF_ID': 321013142,
#    'MOH_SERVICE_PROVIDER_IDENT': '468871',
#    'SERVICE_TYPE': 'Pharmacy',
#    'SERVICE_TYPE_DETAIL': 'Retail Pharmacy',
#    'ENGLISH_NAME': 'Innomar Specialty Pharmacy Inc',
#    'FRENCH_NAME': None,
#    'ENGLISH_NAME_ALT': None,
#    'FRENCH_NAME_ALT': None,
#    'ADDRESS_LINE_1': '4-3250 Harvester Road',
#    'ADDRESS_LINE_2': None,
#    'ADDRESS_DESCRIPTOR': None,
#    'COMMUNITY': 'Burlington',
#    'POSTAL_CODE': 'L7N3W9',
#    'GEOMETRY_UPDATE_DATETIME': 1744234582000,
#    'EFFECTIVE_DATETIME': 1744209791000,
#    'SYSTEM_DATETIME': 1744221299000,
#    'OBJECTID': 2258273}},
#  {'type': 'Feature',
#   'id': 2258289,
#   'geometry': {'type': 'Point',
#    'coordinates': [-79.93719877352608, 43.79963948471444]},
#   'properties': {'OGF_ID': 321010297,
#    'MOH_SERVICE_PROVIDER_IDENT': '999054',
#    'SERVICE_TYPE': 'Seniors Active Living Centre',
#    'SERVICE_TYPE_DETAIL': None,
#    'ENGLISH_NAME': 'Caledon Seniors Centre Satellite Location Inglewood Community Centre',
#    'FRENCH_NAME': 'Caledon Seniors Centre Satellite Location Inglewood Community Centre',
#    'ENGLISH_NAME_ALT': None,
#    'FRENCH_NAME_ALT': None,
#    'ADDRESS_LINE_1': '158/25 Mclaughlin Road',
#    'ADDRESS_LINE_2': None,
#    'ADDRESS_DESCRIPTOR': None,
#    'COMMUNITY': 'Inglewood',
#    'POSTAL_CODE': 'L7C1H4',
#    'GEOMETRY_UPDATE_DATETIME': 1744234306000,
#    'EFFECTIVE_DATETIME': 1744209472000,
#    'SYSTEM_DATETIME': 1744221299000,
#    'OBJECTID': 2258289}},
#  {'type': 'Feature',
#   'id': 2258305,
#   'geometry': {'type': 'Point',
#    'coordinates': [-82.2187663668793, 42.433938734192125]},
#   'properties': {'OGF_ID': 321016232,
#    'MOH_SERVICE_PROVIDER_IDENT': '89790',
#    'SERVICE_TYPE': 'Pharmacy',
#    'SERVICE_TYPE_DETAIL': 'Retail Pharmacy',
#    'ENGLISH_NAME': 'Wal-Mart Pharmacy',
#    'FRENCH_NAME': None,
#    'ENGLISH_NAME_ALT': None,
#    'FRENCH_NAME_ALT': None,
#    'ADDRESS_LINE_1': '881 St Clair Street',
#    'ADDRESS_LINE_2': None,
#    'ADDRESS_DESCRIPTOR': None,
#    'COMMUNITY': 'Chatham',
#    'POSTAL_CODE': 'N7M5T7',
#    'GEOMETRY_UPDATE_DATETIME': 1744234500000,
#    'EFFECTIVE_DATETIME': 1744210135000,
#    'SYSTEM_DATETIME': 1744221299000,
#    'OBJECTID': 2258305}},
#  {'type': 'Feature',
#   'id': 2258321,
#   'geometry': {'type': 'Point',
#    'coordinates': [-80.0972071353582, 43.9194937979268]},
#   'properties': {'OGF_ID': 321015855,
#    'MOH_SERVICE_PROVIDER_IDENT': '8539478',
#    'SERVICE_TYPE': 'Pharmacy',
#    'SERVICE_TYPE_DETAIL': 'Retail Pharmacy',
#    'ENGLISH_NAME': 'Medione Chafford Pharmacy',
#    'FRENCH_NAME': None,
#    'ENGLISH_NAME_ALT': None,
#    'FRENCH_NAME_ALT': None,
#    'ADDRESS_LINE_1': '195 Broadway',
#    'ADDRESS_LINE_2': None,
#    'ADDRESS_DESCRIPTOR': None,
#    'COMMUNITY': 'Orangeville',
#    'POSTAL_CODE': 'L9W1K2',
#    'GEOMETRY_UPDATE_DATETIME': 1744234644000,
#    'EFFECTIVE_DATETIME': 1744210093000,
#    'SYSTEM_DATETIME': 1744221299000,
#    'OBJECTID': 2258321}},
#  {'type': 'Feature',
#   'id': 2258337,
#   'geometry': {'type': 'Point',
#    'coordinates': [-80.96800597356068, 44.56310196552293]},
#   'properties': {'OGF_ID': 321015538,
#    'MOH_SERVICE_PROVIDER_IDENT': '8167011',
#    'SERVICE_TYPE': 'Pharmacy',
#    'SERVICE_TYPE_DETAIL': 'Retail Pharmacy',
#    'ENGLISH_NAME': 'Drugstore Pharmacy 4277',
#    'FRENCH_NAME': None,
#    'ENGLISH_NAME_ALT': None,
#    'FRENCH_NAME_ALT': None,
#    'ADDRESS_LINE_1': '1020 10th Street West',
#    'ADDRESS_LINE_2': None,
#    'ADDRESS_DESCRIPTOR': None,
#    'COMMUNITY': 'Owen Sound',
#    'POSTAL_CODE': 'N4K5S1',
#    'GEOMETRY_UPDATE_DATETIME': 1744234588000,
#    'EFFECTIVE_DATETIME': 1744210057000,
#    'SYSTEM_DATETIME': 1744221299000,
#    'OBJECTID': 2258337}},
#  {'type': 'Feature',
#   'id': 2258353,
#   'geometry': {'type': 'Point',
#    'coordinates': [-84.31172055505402, 46.55152080596695]},
#   'properties': {'OGF_ID': 321009113,
#    'MOH_SERVICE_PROVIDER_IDENT': '4572',
#    'SERVICE_TYPE': 'Community Support Service',
#    'SERVICE_TYPE_DETAIL': None,
#    'ENGLISH_NAME': 'F.J. Davey Home',
#    'FRENCH_NAME': None,
#    'ENGLISH_NAME_ALT': None,
#    'FRENCH_NAME_ALT': None,
#    'ADDRESS_LINE_1': '733 Third Line East',
#    'ADDRESS_LINE_2': None,
#    'ADDRESS_DESCRIPTOR': None,
#    'COMMUNITY': 'Sault Ste. Marie',
#    'POSTAL_CODE': 'P6A7C1',
#    'GEOMETRY_UPDATE_DATETIME': 1744234555000,
#    'EFFECTIVE_DATETIME': 1744209343000,
#    'SYSTEM_DATETIME': 1744221299000,
#    'OBJECTID': 2258353}},
#  {'type': 'Feature',
#   'id': 2258369,
#   'geometry': {'type': 'Point',
#    'coordinates': [-79.78935765118077, 47.06512143435005]},
#   'properties': {'OGF_ID': 321012216,
#    'MOH_SERVICE_PROVIDER_IDENT': '27660',
#    'SERVICE_TYPE': 'Pharmacy',
#    'SERVICE_TYPE_DETAIL': 'Retail Pharmacy',
#    'ENGLISH_NAME': 'Temagami Pharmasave',
#    'FRENCH_NAME': None,
#    'ENGLISH_NAME_ALT': None,
#    'FRENCH_NAME_ALT': None,
#    'ADDRESS_LINE_1': '6729 11 Highway North Gd',
#    'ADDRESS_LINE_2': None,
#    'ADDRESS_DESCRIPTOR': None,
#    'COMMUNITY': 'Temagami',
#    'POSTAL_CODE': 'P0H2H0',
#    'GEOMETRY_UPDATE_DATETIME': 1744234620000,
#    'EFFECTIVE_DATETIME': 1744209686000,
#    'SYSTEM_DATETIME': 1744221299000,
#    'OBJECTID': 2258369}},
#  {'type': 'Feature',
#   'id': 2258385,
#   'geometry': {'type': 'Point',
#    'coordinates': [-79.69416314940602, 44.38376529727595]},
#   'properties': {'OGF_ID': 321007828,
#    'MOH_SERVICE_PROVIDER_IDENT': '3310',
#    'SERVICE_TYPE': 'Mental Health and Addiction Organization',
#    'SERVICE_TYPE_DETAIL': 'Mental Health Services',
#    'ENGLISH_NAME': 'Huronia Transition Homes',
#    'FRENCH_NAME': None,
#    'ENGLISH_NAME_ALT': None,
#    'FRENCH_NAME_ALT': None,
#    'ADDRESS_LINE_1': '80 Bradford Street',
#    'ADDRESS_LINE_2': 'Suite: 143',
#    'ADDRESS_DESCRIPTOR': 'Practice Location',
#    'COMMUNITY': 'Barrie',
#    'POSTAL_CODE': 'L4N6S7',
#    'GEOMETRY_UPDATE_DATETIME': 1744234444000,
#    'EFFECTIVE_DATETIME': 1744209204000,
#    'SYSTEM_DATETIME': 1744221299000,
#    'OBJECTID': 2258385}},
#  {'type': 'Feature',
#   'id': 2258401,
#   'geometry': {'type': 'Point',
#    'coordinates': [-79.44784242364037, 43.86832261972109]},
#   'properties': {'OGF_ID': 321007949,
#    'MOH_SERVICE_PROVIDER_IDENT': '3520',
#    'SERVICE_TYPE': 'Licensed Lab and Specimen Collection Centre',
#    'SERVICE_TYPE_DETAIL': 'Licensed Specimen Collection Centre Location',
#    'ENGLISH_NAME': 'Lifelabs',
#    'FRENCH_NAME': None,
#    'ENGLISH_NAME_ALT': None,
#    'FRENCH_NAME_ALT': None,
#    'ADDRESS_LINE_1': '250 Harding Boulevard West',
#    'ADDRESS_LINE_2': None,
#    'ADDRESS_DESCRIPTOR': 'Practice Address',
#    'COMMUNITY': 'Richmond Hill',
#    'POSTAL_CODE': 'L4C9M7',
#    'GEOMETRY_UPDATE_DATETIME': 1744234224000,
#    'EFFECTIVE_DATETIME': 1744209217000,
#    'SYSTEM_DATETIME': 1744221299000,
#    'OBJECTID': 2258401}},
#  {'type': 'Feature',
#   'id': 2258417,
#   'geometry': {'type': 'Point',
#    'coordinates': [-77.38479998728045, 44.19026996937756]},
#   'properties': {'OGF_ID': 321009428,
#    'MOH_SERVICE_PROVIDER_IDENT': '5651',
#    'SERVICE_TYPE': 'Licensed Lab and Specimen Collection Centre',
#    'SERVICE_TYPE_DETAIL': 'Community (Private) Lab Location',
#    'ENGLISH_NAME': 'Lifelabs',
#    'FRENCH_NAME': None,
#    'ENGLISH_NAME_ALT': None,
#    'FRENCH_NAME_ALT': None,
#    'ADDRESS_LINE_1': '51 Adam Street',
#    'ADDRESS_LINE_2': None,
#    'ADDRESS_DESCRIPTOR': 'Billing, Administration, & Practice Address',
#    'COMMUNITY': 'Belleville',
#    'POSTAL_CODE': 'K8N5K3',
#    'GEOMETRY_UPDATE_DATETIME': 1744234553000,
#    'EFFECTIVE_DATETIME': 1744209377000,
#    'SYSTEM_DATETIME': 1744221299000,
#    'OBJECTID': 2258417}},
#  {'type': 'Feature',
#   'id': 2258433,
#   'geometry': {'type': 'Point',
#    'coordinates': [-80.49352261858773, 43.45172379743586]},
#   'properties': {'OGF_ID': 321016989,
#    'MOH_SERVICE_PROVIDER_IDENT': '9630036',
#    'SERVICE_TYPE': 'Pharmacy',
#    'SERVICE_TYPE_DETAIL': 'Retail Pharmacy',
#    'ENGLISH_NAME': 'Shoppers Drug Mart #1087',
#    'FRENCH_NAME': None,
#    'ENGLISH_NAME_ALT': None,
#    'FRENCH_NAME_ALT': None,
#    'ADDRESS_LINE_1': '250 King Street West',
#    'ADDRESS_LINE_2': None,
#    'ADDRESS_DESCRIPTOR': None,
#    'COMMUNITY': 'Kitchener',
#    'POSTAL_CODE': 'N2G1B6',
#    'GEOMETRY_UPDATE_DATETIME': 1744234691000,
#    'EFFECTIVE_DATETIME': 1744210221000,
#    'SYSTEM_DATETIME': 1744221299000,
#    'OBJECTID': 2258433}},
#  {'type': 'Feature',
#   'id': 2258449,
#   'geometry': {'type': 'Point',
#    'coordinates': [-79.78514278571183, 43.35562411397995]},
#   'properties': {'OGF_ID': 321015168,
#    'MOH_SERVICE_PROVIDER_IDENT': '7657733',
#    'SERVICE_TYPE': 'Pharmacy',
#    'SERVICE_TYPE_DETAIL': 'Retail Pharmacy',
#    'ENGLISH_NAME': 'Food Basics Pharmacy #581',
#    'FRENCH_NAME': None,
#    'ENGLISH_NAME_ALT': None,
#    'FRENCH_NAME_ALT': None,
#    'ADDRESS_LINE_1': '3365 Fairview Street',
#    'ADDRESS_LINE_2': None,
#    'ADDRESS_DESCRIPTOR': None,
#    'COMMUNITY': 'Burlington',
#    'POSTAL_CODE': 'L7N3N9',
#    'GEOMETRY_UPDATE_DATETIME': 1744234617000,
#    'EFFECTIVE_DATETIME': 1744210016000,
#    'SYSTEM_DATETIME': 1744221299000,
#    'OBJECTID': 2258449}},
#  {'type': 'Feature',
#   'id': 2258465,
#   'geometry': {'type': 'Point',
#    'coordinates': [-79.71623439952593, 43.75925128810083]},
#   'properties': {'OGF_ID': 321007444,
#    'MOH_SERVICE_PROVIDER_IDENT': '3043514',
#    'SERVICE_TYPE': 'Integrated Community Health Services Centre',
#    'SERVICE_TYPE_DETAIL': 'Bone Mineral Dxa, Mammography, Radiography, General Ultrasound, Vascular Ultrasound',
#    'ENGLISH_NAME': 'Cottrelle Diagnostic Imaging',
#    'FRENCH_NAME': None,
#    'ENGLISH_NAME_ALT': '2566773 Ontario Inc.',
#    'FRENCH_NAME_ALT': None,
#    'ADDRESS_LINE_1': '10 Cottrelle Boulevard',
#    'ADDRESS_LINE_2': 'Unit 202',
#    'ADDRESS_DESCRIPTOR': None,
#    'COMMUNITY': 'Brampton',
#    'POSTAL_CODE': 'L6S0E2',
#    'GEOMETRY_UPDATE_DATETIME': 1744234278000,
#    'EFFECTIVE_DATETIME': 1744209161000,
#    'SYSTEM_DATETIME': 1744221299000,
#    'OBJECTID': 2258465}},
#  {'type': 'Feature',
#   'id': 2258481,
#   'geometry': {'type': 'Point',
#    'coordinates': [-79.6266993734175, 43.78644119705446]},
#   'properties': {'OGF_ID': 321011741,
#    'MOH_SERVICE_PROVIDER_IDENT': '1495956',
#    'SERVICE_TYPE': 'Pharmacy',
#    'SERVICE_TYPE_DETAIL': 'Retail Pharmacy',
#    'ENGLISH_NAME': 'Wal-Mart Pharmacy',
#    'FRENCH_NAME': None,
#    'ENGLISH_NAME_ALT': None,
#    'FRENCH_NAME_ALT': None,
#    'ADDRESS_LINE_1': '8300 Highway 27',
#    'ADDRESS_LINE_2': None,
#    'ADDRESS_DESCRIPTOR': None,
#    'COMMUNITY': 'Woodbridge',
#    'POSTAL_CODE': 'L4H0R9',
#    'GEOMETRY_UPDATE_DATETIME': 1744234363000,
#    'EFFECTIVE_DATETIME': 1744209632000,
#    'SYSTEM_DATETIME': 1744221299000,
#    'OBJECTID': 2258481}},
#  {'type': 'Feature',
#   'id': 2258497,
#   'geometry': {'type': 'Point',
#    'coordinates': [-81.15326808970072, 44.12260888137909]},
#   'properties': {'OGF_ID': 321017463,
#    'MOH_SERVICE_PROVIDER_IDENT': '9463',
#    'SERVICE_TYPE': 'Hospital',
#    'SERVICE_TYPE_DETAIL': 'Site',
#    'ENGLISH_NAME': 'South Bruce Grey Health Centre - Walkerton',
#    'FRENCH_NAME': None,
#    'ENGLISH_NAME_ALT': 'South Bruce Grey Health Centre',
#    'FRENCH_NAME_ALT': None,
#    'ADDRESS_LINE_1': '21 McGivern St. W.',
#    'ADDRESS_LINE_2': None,
#    'ADDRESS_DESCRIPTOR': None,
#    'COMMUNITY': 'Walkerton',
#    'POSTAL_CODE': 'N0G2V0',
#    'GEOMETRY_UPDATE_DATETIME': 1744234434000,
#    'EFFECTIVE_DATETIME': 1744210274000,
#    'SYSTEM_DATETIME': 1744221299000,
#    'OBJECTID': 2258497}},
#  {'type': 'Feature',
#   'id': 2258513,
#   'geometry': {'type': 'Point',
#    'coordinates': [-79.44747514009501, 44.05294525186573]},
#   'properties': {'OGF_ID': 321011599,
#    'MOH_SERVICE_PROVIDER_IDENT': '1267471',
#    'SERVICE_TYPE': 'Pharmacy',
#    'SERVICE_TYPE_DETAIL': 'Home For Special Care',
#    'ENGLISH_NAME': 'Parkview Manor',
#    'FRENCH_NAME': None,
#    'ENGLISH_NAME_ALT': None,
#    'FRENCH_NAME_ALT': None,
#    'ADDRESS_LINE_1': '683 Gorham Street',
#    'ADDRESS_LINE_2': None,
#    'ADDRESS_DESCRIPTOR': None,
#    'COMMUNITY': 'Newmarket',
#    'POSTAL_CODE': 'L3Y1L5',
#    'GEOMETRY_UPDATE_DATETIME': 1744234587000,
#    'EFFECTIVE_DATETIME': 1744209616000,
#    'SYSTEM_DATETIME': 1744221299000,
#    'OBJECTID': 2258513}},
#  {'type': 'Feature',
#   'id': 2258529,
#   'geometry': {'type': 'Point',
#    'coordinates': [-83.11147391224563, 42.10305313122091]},
#   'properties': {'OGF_ID': 321015603,
#    'MOH_SERVICE_PROVIDER_IDENT': '8251278',
#    'SERVICE_TYPE': 'Pharmacy',
#    'SERVICE_TYPE_DETAIL': 'Retail Pharmacy',
#    'ENGLISH_NAME': 'Old Town Pharmacy',
#    'FRENCH_NAME': None,
#    'ENGLISH_NAME_ALT': None,
#    'FRENCH_NAME_ALT': None,
#    'ADDRESS_LINE_1': '80 Richmond Street',
#    'ADDRESS_LINE_2': None,
#    'ADDRESS_DESCRIPTOR': None,
#    'COMMUNITY': 'Amherstburg',
#    'POSTAL_CODE': 'N9V1E9',
#    'GEOMETRY_UPDATE_DATETIME': 1744234543000,
#    'EFFECTIVE_DATETIME': 1744210064000,
#    'SYSTEM_DATETIME': 1744221299000,
#    'OBJECTID': 2258529}},
#  {'type': 'Feature',
#   'id': 2258545,
#   'geometry': {'type': 'Point',
#    'coordinates': [-79.39947758967219, 43.65926898538221]},
#   'properties': {'OGF_ID': 321008165,
#    'MOH_SERVICE_PROVIDER_IDENT': '3803',
#    'SERVICE_TYPE': 'Mental Health and Addiction Organization',
#    'SERVICE_TYPE_DETAIL': 'Mental Health Services',
#    'ENGLISH_NAME': 'Centre For Addiction And Mental Health (CAMH)',
#    'FRENCH_NAME': None,
#    'ENGLISH_NAME_ALT': None,
#    'FRENCH_NAME_ALT': None,
#    'ADDRESS_LINE_1': '250 College Street',
#    'ADDRESS_LINE_2': None,
#    'ADDRESS_DESCRIPTOR': 'Practice Location',
#    'COMMUNITY': 'Toronto',
#    'POSTAL_CODE': 'M5T1R8',
#    'GEOMETRY_UPDATE_DATETIME': 1744234696000,
#    'EFFECTIVE_DATETIME': 1744209240000,
#    'SYSTEM_DATETIME': 1744221299000,
#    'OBJECTID': 2258545}},
#  {'type': 'Feature',
#   'id': 2258561,
#   'geometry': {'type': 'Point',
#    'coordinates': [-79.11291635048997, 43.10270649992076]},
#   'properties': {'OGF_ID': 321011956,
#    'MOH_SERVICE_PROVIDER_IDENT': '2078058',
#    'SERVICE_TYPE': 'Pharmacy',
#    'SERVICE_TYPE_DETAIL': 'Retail Pharmacy',
#    'ENGLISH_NAME': 'Loblaw Pharmacy #537',
#    'FRENCH_NAME': None,
#    'ENGLISH_NAME_ALT': None,
#    'FRENCH_NAME_ALT': None,
#    'ADDRESS_LINE_1': '6940 Morrison Street',
#    'ADDRESS_LINE_2': None,
#    'ADDRESS_DESCRIPTOR': None,
#    'COMMUNITY': 'Niagara Falls',
#    'POSTAL_CODE': 'L2E7K5',
#    'GEOMETRY_UPDATE_DATETIME': 1744234283000,
#    'EFFECTIVE_DATETIME': 1744209657000,
#    'SYSTEM_DATETIME': 1744221299000,
#    'OBJECTID': 2258561}},
#  {'type': 'Feature',
#   'id': 2258577,
#   'geometry': {'type': 'Point',
#    'coordinates': [-75.72345724414265, 45.39003224843084]},
#   'properties': {'OGF_ID': 321012428,
#    'MOH_SERVICE_PROVIDER_IDENT': '3285714',
#    'SERVICE_TYPE': 'Pharmacy',
#    'SERVICE_TYPE_DETAIL': 'Retail Pharmacy',
#    'ENGLISH_NAME': 'Mcneil Parkdale Pharmacy',
#    'FRENCH_NAME': None,
#    'ENGLISH_NAME_ALT': None,
#    'FRENCH_NAME_ALT': None,
#    'ADDRESS_LINE_1': '1077 Carling Avenue',
#    'ADDRESS_LINE_2': None,
#    'ADDRESS_DESCRIPTOR': None,
#    'COMMUNITY': 'Ottawa',
#    'POSTAL_CODE': 'K1Y4K4',
#    'GEOMETRY_UPDATE_DATETIME': 1744234333000,
#    'EFFECTIVE_DATETIME': 1744209710000,
#    'SYSTEM_DATETIME': 1744221299000,
#    'OBJECTID': 2258577}},
#  {'type': 'Feature',
#   'id': 2258593,
#   'geometry': {'type': 'Point',
#    'coordinates': [-79.58591355184325, 43.6901710821233]},
#   'properties': {'OGF_ID': 321007528,
#    'MOH_SERVICE_PROVIDER_IDENT': '30740',
#    'SERVICE_TYPE': 'Mental Health and Addiction Organization',
#    'SERVICE_TYPE_DETAIL': 'Addiction Services And Mental Health Services',
#    'ENGLISH_NAME': 'Canadian Mental Health Association (Cmha) Peel Dufferin Branch',
#    'FRENCH_NAME': None,
#    'ENGLISH_NAME_ALT': None,
#    'FRENCH_NAME_ALT': None,
#    'ADDRESS_LINE_1': '10 Carlson Court',
#    'ADDRESS_LINE_2': 'Suite: 201',
#    'ADDRESS_DESCRIPTOR': 'Practice Location',
#    'COMMUNITY': 'Etobicoke',
#    'POSTAL_CODE': 'M9W6L2',
#    'GEOMETRY_UPDATE_DATETIME': 1744234472000,
#    'EFFECTIVE_DATETIME': 1744209170000,
#    'SYSTEM_DATETIME': 1744221299000,
#    'OBJECTID': 2258593}},
#  {'type': 'Feature',
#   'id': 2258609,
#   'geometry': {'type': 'Point',
#    'coordinates': [-79.24042329732262, 43.17713730741412]},
#   'properties': {'OGF_ID': 321016011,
#    'MOH_SERVICE_PROVIDER_IDENT': '8723811',
#    'SERVICE_TYPE': 'Pharmacy',
#    'SERVICE_TYPE_DETAIL': 'Retail Pharmacy',
#    'ENGLISH_NAME': "Sam's Geneva Street Pharmacy",
#    'FRENCH_NAME': None,
#    'ENGLISH_NAME_ALT': None,
#    'FRENCH_NAME_ALT': None,
#    'ADDRESS_LINE_1': '284 Geneva Street Unit 5',
#    'ADDRESS_LINE_2': None,
#    'ADDRESS_DESCRIPTOR': None,
#    'COMMUNITY': 'St Catharines',
#    'POSTAL_CODE': 'L2N2E8',
#    'GEOMETRY_UPDATE_DATETIME': 1744234636000,
#    'EFFECTIVE_DATETIME': 1744210110000,
#    'SYSTEM_DATETIME': 1744221299000,
#    'OBJECTID': 2258609}},
#  {'type': 'Feature',
#   'id': 2258625,
#   'geometry': {'type': 'Point',
#    'coordinates': [-80.99826588106275, 46.46605147654795]},
#   'properties': {'OGF_ID': 321007008,
#    'MOH_SERVICE_PROVIDER_IDENT': '2261',
#    'SERVICE_TYPE': 'Public Health Unit Office',
#    'SERVICE_TYPE_DETAIL': None,
#    'ENGLISH_NAME': 'Sudbury And District Health Unit',
#    'FRENCH_NAME': 'Service De Santé Publique De Sudbury Et Du District',
#    'ENGLISH_NAME_ALT': None,
#    'FRENCH_NAME_ALT': None,
#    'ADDRESS_LINE_1': '1300 Paris Street',
#    'ADDRESS_LINE_2': None,
#    'ADDRESS_DESCRIPTOR': 'Administrative Office',
#    'COMMUNITY': 'Sudbury',
#    'POSTAL_CODE': 'P3E3A3',
#    'GEOMETRY_UPDATE_DATETIME': 1744234196000,
#    'EFFECTIVE_DATETIME': 1744209113000,
#    'SYSTEM_DATETIME': 1744221299000,
#    'OBJECTID': 2258625}},
#  {'type': 'Feature',
#   'id': 2258641,
#   'geometry': {'type': 'Point',
#    'coordinates': [-79.44946732827071, 43.914313427664176]},
#   'properties': {'OGF_ID': 321011734,
#    'MOH_SERVICE_PROVIDER_IDENT': '1477510',
#    'SERVICE_TYPE': 'Pharmacy',
#    'SERVICE_TYPE_DETAIL': 'Retail Pharmacy',
#    'ENGLISH_NAME': 'Shoppers Drug Mart #1148',
#    'FRENCH_NAME': None,
#    'ENGLISH_NAME_ALT': None,
#    'FRENCH_NAME_ALT': None,
#    'ADDRESS_LINE_1': '118 Tower Hill Road',
#    'ADDRESS_LINE_2': None,
#    'ADDRESS_DESCRIPTOR': None,
#    'COMMUNITY': 'Richmond Hill',
#    'POSTAL_CODE': 'L4E0K6',
#    'GEOMETRY_UPDATE_DATETIME': 1744234522000,
#    'EFFECTIVE_DATETIME': 1744209632000,
#    'SYSTEM_DATETIME': 1744221299000,
#    'OBJECTID': 2258641}},
#  {'type': 'Feature',
#   'id': 2258657,
#   'geometry': {'type': 'Point',
#    'coordinates': [-79.3789663824967, 43.652072985069466]},
#   'properties': {'OGF_ID': 321014165,
#    'MOH_SERVICE_PROVIDER_IDENT': '6294672',
#    'SERVICE_TYPE': 'Pharmacy',
#    'SERVICE_TYPE_DETAIL': 'Retail Pharmacy',
#    'ENGLISH_NAME': 'Rexall #8161',
#    'FRENCH_NAME': None,
#    'ENGLISH_NAME_ALT': None,
#    'FRENCH_NAME_ALT': None,
#    'ADDRESS_LINE_1': '159 Yonge Street',
#    'ADDRESS_LINE_2': None,
#    'ADDRESS_DESCRIPTOR': None,
#    'COMMUNITY': 'Toronto',
#    'POSTAL_CODE': 'M5C1X7',
#    'GEOMETRY_UPDATE_DATETIME': 1744234672000,
#    'EFFECTIVE_DATETIME': 1744209904000,
#    'SYSTEM_DATETIME': 1744221299000,
#    'OBJECTID': 2258657}},
#  {'type': 'Feature',
#   'id': 2258673,
#   'geometry': {'type': 'Point',
#    'coordinates': [-79.7646915875341, 43.45037203164587]},
#   'properties': {'OGF_ID': 321013514,
#    'MOH_SERVICE_PROVIDER_IDENT': '5324758',
#    'SERVICE_TYPE': 'Pharmacy',
#    'SERVICE_TYPE_DETAIL': 'Retail Pharmacy',
#    'ENGLISH_NAME': 'Origins Phmcy & Home Hlth Care',
#    'FRENCH_NAME': None,
#    'ENGLISH_NAME_ALT': None,
#    'FRENCH_NAME_ALT': None,
#    'ADDRESS_LINE_1': '7-3001 Hospital Gate',
#    'ADDRESS_LINE_2': None,
#    'ADDRESS_DESCRIPTOR': None,
#    'COMMUNITY': 'Oakville',
#    'POSTAL_CODE': 'L6M0L8',
#    'GEOMETRY_UPDATE_DATETIME': 1744234378000,
#    'EFFECTIVE_DATETIME': 1744209831000,
#    'SYSTEM_DATETIME': 1744221299000,
#    'OBJECTID': 2258673}},
#  {'type': 'Feature',
#   'id': 2258689,
#   'geometry': {'type': 'Point',
#    'coordinates': [-79.26810239103038, 42.99886507431701]},
#   'properties': {'OGF_ID': 321010234,
#    'MOH_SERVICE_PROVIDER_IDENT': '99490',
#    'SERVICE_TYPE': 'Integrated Community Health Services Centre',
#    'SERVICE_TYPE_DETAIL': 'Fluoroscopy, Radiography, General Ultrasound, Bone Mineral Dxa, Nuclear Medicine - In Vivo - Spect, Nuclear Medicine - In Vivo - General',
#    'ENGLISH_NAME': 'Greater Niagara Medical Imaging',
#    'FRENCH_NAME': None,
#    'ENGLISH_NAME_ALT': 'Greater Niagara Medical Imaging Inc.',
#    'FRENCH_NAME_ALT': None,
#    'ADDRESS_LINE_1': '555 Prince Charles Drive North',
#    'ADDRESS_LINE_2': 'Suite 114',
#    'ADDRESS_DESCRIPTOR': None,
#    'COMMUNITY': 'Welland',
#    'POSTAL_CODE': 'L3C6B5',
#    'GEOMETRY_UPDATE_DATETIME': 1744234263000,
#    'EFFECTIVE_DATETIME': 1744209465000,
#    'SYSTEM_DATETIME': 1744221299000,
#    'OBJECTID': 2258689}},
#  {'type': 'Feature',
#   'id': 2258705,
#   'geometry': {'type': 'Point',
#    'coordinates': [-79.60324514896233, 43.595235864660985]},
#   'properties': {'OGF_ID': 321013069,
#    'MOH_SERVICE_PROVIDER_IDENT': '4564554',
#    'SERVICE_TYPE': 'Pharmacy',
#    'SERVICE_TYPE_DETAIL': 'Retail Pharmacy',
#    'ENGLISH_NAME': 'Cawthra Drug Store',
#    'FRENCH_NAME': None,
#    'ENGLISH_NAME_ALT': None,
#    'FRENCH_NAME_ALT': None,
#    'ADDRESS_LINE_1': '7&8-680 Silver Creek Boulevard',
#    'ADDRESS_LINE_2': None,
#    'ADDRESS_DESCRIPTOR': None,
#    'COMMUNITY': 'Mississauga',
#    'POSTAL_CODE': 'L5A3Z1',
#    'GEOMETRY_UPDATE_DATETIME': 1744234336000,
#    'EFFECTIVE_DATETIME': 1744209782000,
#    'SYSTEM_DATETIME': 1744221299000,
#    'OBJECTID': 2258705}},
#  {'type': 'Feature',
#   'id': 2258721,
#   'geometry': {'type': 'Point',
#    'coordinates': [-79.95957603325462, 43.26711669019614]},
#   'properties': {'OGF_ID': 321016461,
#    'MOH_SERVICE_PROVIDER_IDENT': '9192394',
#    'SERVICE_TYPE': 'Pharmacy',
#    'SERVICE_TYPE_DETAIL': 'Retail Pharmacy',
#    'ENGLISH_NAME': 'Shoppers Drug Mart #1056',
#    'FRENCH_NAME': None,
#    'ENGLISH_NAME_ALT': None,
#    'FRENCH_NAME_ALT': None,
#    'ADDRESS_LINE_1': '133 King Street West',
#    'ADDRESS_LINE_2': None,
#    'ADDRESS_DESCRIPTOR': None,
#    'COMMUNITY': 'Dundas',
#    'POSTAL_CODE': 'L9H1V3',
#    'GEOMETRY_UPDATE_DATETIME': 1744234178000,
#    'EFFECTIVE_DATETIME': 1744210161000,
#    'SYSTEM_DATETIME': 1744221299000,
#    'OBJECTID': 2258721}},
#  {'type': 'Feature',
#   'id': 2258737,
#   'geometry': {'type': 'Point',
#    'coordinates': [-79.24908305624471, 43.824819421369924]},
#   'properties': {'OGF_ID': 321015568,
#    'MOH_SERVICE_PROVIDER_IDENT': '8203473',
#    'SERVICE_TYPE': 'Pharmacy',
#    'SERVICE_TYPE_DETAIL': 'Retail Pharmacy',
#    'ENGLISH_NAME': 'Majestic City Pharmacy',
#    'FRENCH_NAME': None,
#    'ENGLISH_NAME_ALT': None,
#    'FRENCH_NAME_ALT': None,
#    'ADDRESS_LINE_1': 'A1-2900 Markham Road',
#    'ADDRESS_LINE_2': None,
#    'ADDRESS_DESCRIPTOR': None,
#    'COMMUNITY': 'Scarborough',
#    'POSTAL_CODE': 'M1X1E6',
#    'GEOMETRY_UPDATE_DATETIME': 1744234320000,
#    'EFFECTIVE_DATETIME': 1744210061000,
#    'SYSTEM_DATETIME': 1744221299000,
#    'OBJECTID': 2258737}},
#  {'type': 'Feature',
#   'id': 2258753,
#   'geometry': {'type': 'Point',
#    'coordinates': [-78.71514541788449, 46.31057506676532]},
#   'properties': {'OGF_ID': 321017907,
#    'MOH_SERVICE_PROVIDER_IDENT': '5514',
#    'SERVICE_TYPE': 'Long-Term Care Home',
#    'SERVICE_TYPE_DETAIL': 'NH non-profit',
#    'ENGLISH_NAME': 'Algonquin Nursing Home',
#    'FRENCH_NAME': None,
#    'ENGLISH_NAME_ALT': None,
#    'FRENCH_NAME_ALT': None,
#    'ADDRESS_LINE_1': '207 Turcotte Park Road',
#    'ADDRESS_LINE_2': None,
#    'ADDRESS_DESCRIPTOR': None,
#    'COMMUNITY': 'Mattawa',
#    'POSTAL_CODE': 'P0H1V0',
#    'GEOMETRY_UPDATE_DATETIME': 1744234662000,
#    'EFFECTIVE_DATETIME': 1744214631000,
#    'SYSTEM_DATETIME': 1744221299000,
#    'OBJECTID': 2258753}},
#  {'type': 'Feature',
#   'id': 2258769,
#   'geometry': {'type': 'Point',
#    'coordinates': [-79.62205995322128, 43.57562986033927]},
#   'properties': {'OGF_ID': 321014441,
#    'MOH_SERVICE_PROVIDER_IDENT': '6709831',
#    'SERVICE_TYPE': 'Pharmacy',
#    'SERVICE_TYPE_DETAIL': 'Retail Pharmacy',
#    'ENGLISH_NAME': 'Swiderski Pharmacy',
#    'FRENCH_NAME': None,
#    'ENGLISH_NAME_ALT': None,
#    'FRENCH_NAME_ALT': None,
#    'ADDRESS_LINE_1': '1-3015 Parkerhill Road',
#    'ADDRESS_LINE_2': None,
#    'ADDRESS_DESCRIPTOR': None,
#    'COMMUNITY': 'Mississagua',
#    'POSTAL_CODE': 'L5B4B2',
#    'GEOMETRY_UPDATE_DATETIME': 1744234358000,
#    'EFFECTIVE_DATETIME': 1744209935000,
#    'SYSTEM_DATETIME': 1744221299000,
#    'OBJECTID': 2258769}},
#  {'type': 'Feature',
#   'id': 2258785,
#   'geometry': {'type': 'Point',
#    'coordinates': [-81.21962160048622, 42.93339957132932]},
#   'properties': {'OGF_ID': 321014764,
#    'MOH_SERVICE_PROVIDER_IDENT': '7129038',
#    'SERVICE_TYPE': 'Pharmacy',
#    'SERVICE_TYPE_DETAIL': 'Retail Pharmacy',
#    'ENGLISH_NAME': 'Medisystem Pharmacy 6030',
#    'FRENCH_NAME': None,
#    'ENGLISH_NAME_ALT': None,
#    'FRENCH_NAME_ALT': None,
#    'ADDRESS_LINE_1': '24-30-1100 Dearness Drive',
#    'ADDRESS_LINE_2': None,
#    'ADDRESS_DESCRIPTOR': None,
#    'COMMUNITY': 'London',
#    'POSTAL_CODE': 'N6E1N9',
#    'GEOMETRY_UPDATE_DATETIME': 1744234575000,
#    'EFFECTIVE_DATETIME': 1744209970000,
#    'SYSTEM_DATETIME': 1744221299000,
#    'OBJECTID': 2258785}},
#  {'type': 'Feature',
#   'id': 2258801,
#   'geometry': {'type': 'Point',
#    'coordinates': [-79.46719064138968, 43.99732664128052]},
#   'properties': {'OGF_ID': 321007784,
#    'MOH_SERVICE_PROVIDER_IDENT': '3231',
#    'SERVICE_TYPE': 'Mental Health and Addiction Organization',
#    'SERVICE_TYPE_DETAIL': 'Addiction Services And Mental Health Services',
#    'ENGLISH_NAME': 'Canadian Mental Health Association (Cmha) York Region Branch',
#    'FRENCH_NAME': None,
#    'ENGLISH_NAME_ALT': None,
#    'FRENCH_NAME_ALT': None,
#    'ADDRESS_LINE_1': '15150 Yonge Street',
#    'ADDRESS_LINE_2': 'Suite: 201',
#    'ADDRESS_DESCRIPTOR': 'Practice Location',
#    'COMMUNITY': 'Aurora',
#    'POSTAL_CODE': 'L4G1M2',
#    'GEOMETRY_UPDATE_DATETIME': 1744234299000,
#    'EFFECTIVE_DATETIME': 1744209199000,
#    'SYSTEM_DATETIME': 1744221299000,
#    'OBJECTID': 2258801}},
#  {'type': 'Feature',
#   'id': 2258817,
#   'geometry': {'type': 'Point',
#    'coordinates': [-76.16376010080515, 44.326981945654225]},
#   'properties': {'OGF_ID': 321006694,
#    'MOH_SERVICE_PROVIDER_IDENT': '18098',
#    'SERVICE_TYPE': 'Mental Health and Addiction Organization',
#    'SERVICE_TYPE_DETAIL': 'Addiction Services And Mental Health Services',
#    'ENGLISH_NAME': 'Lanark, Leeds And Grenville Addictions And Mental Health',
#    'FRENCH_NAME': None,
#    'ENGLISH_NAME_ALT': None,
#    'FRENCH_NAME_ALT': None,
#    'ADDRESS_LINE_1': '21 Mill Street',
#    'ADDRESS_LINE_2': None,
#    'ADDRESS_DESCRIPTOR': 'Practice Location',
#    'COMMUNITY': 'Gananoque',
#    'POSTAL_CODE': 'K7G2L5',
#    'GEOMETRY_UPDATE_DATETIME': 1744234502000,
#    'EFFECTIVE_DATETIME': 1744209078000,
#    'SYSTEM_DATETIME': 1744221299000,
#    'OBJECTID': 2258817}},
#  {'type': 'Feature',
#   'id': 2258833,
#   'geometry': {'type': 'Point',
#    'coordinates': [-74.7352569867865, 45.029766027015214]},
#   'properties': {'OGF_ID': 321011706,
#    'MOH_SERVICE_PROVIDER_IDENT': '1397394',
#    'SERVICE_TYPE': 'Pharmacy',
#    'SERVICE_TYPE_DETAIL': 'Retail Pharmacy',
#    'ENGLISH_NAME': 'Jean Coutu Pharmacy #64',
#    'FRENCH_NAME': None,
#    'ENGLISH_NAME_ALT': None,
#    'FRENCH_NAME_ALT': None,
#    'ADDRESS_LINE_1': '5 9th Street East',
#    'ADDRESS_LINE_2': None,
#    'ADDRESS_DESCRIPTOR': None,
#    'COMMUNITY': 'Cornwall',
#    'POSTAL_CODE': 'K6H6R3',
#    'GEOMETRY_UPDATE_DATETIME': 1744234475000,
#    'EFFECTIVE_DATETIME': 1744209629000,
#    'SYSTEM_DATETIME': 1744221299000,
#    'OBJECTID': 2258833}},
#  {'type': 'Feature',
#   'id': 2258849,
#   'geometry': {'type': 'Point',
#    'coordinates': [-79.37187028167527, 43.66847578827874]},
#   'properties': {'OGF_ID': 321012194,
#    'MOH_SERVICE_PROVIDER_IDENT': '2726679',
#    'SERVICE_TYPE': 'Pharmacy',
#    'SERVICE_TYPE_DETAIL': 'Retail Pharmacy',
#    'ENGLISH_NAME': 'St James Drug Mart',
#    'FRENCH_NAME': None,
#    'ENGLISH_NAME_ALT': None,
#    'FRENCH_NAME_ALT': None,
#    'ADDRESS_LINE_1': '118-240 Wellesley Street East',
#    'ADDRESS_LINE_2': None,
#    'ADDRESS_DESCRIPTOR': None,
#    'COMMUNITY': 'Toronto',
#    'POSTAL_CODE': 'M4X1G5',
#    'GEOMETRY_UPDATE_DATETIME': 1744234603000,
#    'EFFECTIVE_DATETIME': 1744209684000,
#    'SYSTEM_DATETIME': 1744221299000,
#    'OBJECTID': 2258849}},
#  {'type': 'Feature',
#   'id': 2258865,
#   'geometry': {'type': 'Point',
#    'coordinates': [-84.77061958872379, 47.99774929600373]},
#   'properties': {'OGF_ID': 321006273,
#    'MOH_SERVICE_PROVIDER_IDENT': '10513',
#    'SERVICE_TYPE': 'Mental Health and Addiction Organization',
#    'SERVICE_TYPE_DETAIL': 'Mental Health Services',
#    'ENGLISH_NAME': 'Canadian Mental Health Association (Cmha) Algoma',
#    'FRENCH_NAME': None,
#    'ENGLISH_NAME_ALT': None,
#    'FRENCH_NAME_ALT': None,
#    'ADDRESS_LINE_1': '22 Broadway Avenue',
#    'ADDRESS_LINE_2': None,
#    'ADDRESS_DESCRIPTOR': 'Practice Location',
#    'COMMUNITY': 'Wawa',
#    'POSTAL_CODE': 'P0S1K0',
#    'GEOMETRY_UPDATE_DATETIME': 1744234196000,
#    'EFFECTIVE_DATETIME': 1744209023000,
#    'SYSTEM_DATETIME': 1744221299000,
#    'OBJECTID': 2258865}},
#  {'type': 'Feature',
#   'id': 2258881,
#   'geometry': {'type': 'Point',
#    'coordinates': [-79.41209870267379, 43.760913302616004]},
#   'properties': {'OGF_ID': 321010142,
#    'MOH_SERVICE_PROVIDER_IDENT': '9213446',
#    'SERVICE_TYPE': 'Integrated Community Health Services Centre',
#    'SERVICE_TYPE_DETAIL': 'General Ultrasound',
#    'ENGLISH_NAME': 'Anova Fertility & Reproductive Health',
#    'FRENCH_NAME': None,
#    'ENGLISH_NAME_ALT': '9421467 Canada Inc.',
#    'FRENCH_NAME_ALT': None,
#    'ADDRESS_LINE_1': '25 Sheppard Avenue West',
#    'ADDRESS_LINE_2': 'Suite 650',
#    'ADDRESS_DESCRIPTOR': None,
#    'COMMUNITY': 'North York',
#    'POSTAL_CODE': 'M2N6S6',
#    'GEOMETRY_UPDATE_DATETIME': 1744234307000,
#    'EFFECTIVE_DATETIME': 1744209456000,
#    'SYSTEM_DATETIME': 1744221299000,
#    'OBJECTID': 2258881}},
#  {'type': 'Feature',
#   'id': 2258897,
#   'geometry': {'type': 'Point',
#    'coordinates': [-80.43982659999718, 43.433767196853694]},
#   'properties': {'OGF_ID': 321013593,
#    'MOH_SERVICE_PROVIDER_IDENT': '5437397',
#    'SERVICE_TYPE': 'Pharmacy',
#    'SERVICE_TYPE_DETAIL': 'Retail Pharmacy',
#    'ENGLISH_NAME': 'Weber Community Pharmacy',
#    'FRENCH_NAME': None,
#    'ENGLISH_NAME_ALT': None,
#    'FRENCH_NAME_ALT': None,
#    'ADDRESS_LINE_1': '1360 Weber Street East',
#    'ADDRESS_LINE_2': None,
#    'ADDRESS_DESCRIPTOR': None,
#    'COMMUNITY': 'Kitchener',
#    'POSTAL_CODE': 'N2A1C4',
#    'GEOMETRY_UPDATE_DATETIME': 1744234505000,
#    'EFFECTIVE_DATETIME': 1744209840000,
#    'SYSTEM_DATETIME': 1744221299000,
#    'OBJECTID': 2258897}},
#  {'type': 'Feature',
#   'id': 2258913,
#   'geometry': {'type': 'Point',
#    'coordinates': [-79.44000612221127, 43.8803610221874]},
#   'properties': {'OGF_ID': 321013110,
#    'MOH_SERVICE_PROVIDER_IDENT': '4628558',
#    'SERVICE_TYPE': 'Pharmacy',
#    'SERVICE_TYPE_DETAIL': 'Retail Pharmacy',
#    'ENGLISH_NAME': 'Dara Pharmacy',
#    'FRENCH_NAME': None,
#    'ENGLISH_NAME_ALT': None,
#    'FRENCH_NAME_ALT': None,
#    'ADDRESS_LINE_1': '107-10376 Yonge Street',
#    'ADDRESS_LINE_2': None,
#    'ADDRESS_DESCRIPTOR': None,
#    'COMMUNITY': 'Richmond Hill',
#    'POSTAL_CODE': 'L4C3B8',
#    'GEOMETRY_UPDATE_DATETIME': 1744234459000,
#    'EFFECTIVE_DATETIME': 1744209787000,
#    'SYSTEM_DATETIME': 1744221299000,
#    'OBJECTID': 2258913}},
#  {'type': 'Feature',
#   'id': 2258929,
#   'geometry': {'type': 'Point',
#    'coordinates': [-79.90710511262515, 43.22117378451588]},
#   'properties': {'OGF_ID': 321012472,
#    'MOH_SERVICE_PROVIDER_IDENT': '3368279',
#    'SERVICE_TYPE': 'Pharmacy',
#    'SERVICE_TYPE_DETAIL': 'Retail Pharmacy',
#    'ENGLISH_NAME': 'Shoppers Drug Mart 1045',
#    'FRENCH_NAME': None,
#    'ENGLISH_NAME_ALT': None,
#    'FRENCH_NAME_ALT': None,
#    'ADDRESS_LINE_1': '1300 Garth Street',
#    'ADDRESS_LINE_2': None,
#    'ADDRESS_DESCRIPTOR': None,
#    'COMMUNITY': 'Hamilton',
#    'POSTAL_CODE': 'L9C4L7',
#    'GEOMETRY_UPDATE_DATETIME': 1744234243000,
#    'EFFECTIVE_DATETIME': 1744209715000,
#    'SYSTEM_DATETIME': 1744221299000,
#    'OBJECTID': 2258929}},
#  {'type': 'Feature',
#   'id': 2258945,
#   'geometry': {'type': 'Point',
#    'coordinates': [-81.00645338550461, 46.4822145786934]},
#   'properties': {'OGF_ID': 321016252,
#    'MOH_SERVICE_PROVIDER_IDENT': '9006470',
#    'SERVICE_TYPE': 'Pharmacy',
#    'SERVICE_TYPE_DETAIL': 'Retail Pharmacy',
#    'ENGLISH_NAME': 'Shoppers Drug Mart #1540',
#    'FRENCH_NAME': None,
#    'ENGLISH_NAME_ALT': None,
#    'FRENCH_NAME_ALT': None,
#    'ADDRESS_LINE_1': '112-359 Riverside Drive',
#    'ADDRESS_LINE_2': None,
#    'ADDRESS_DESCRIPTOR': None,
#    'COMMUNITY': 'Sudbury',
#    'POSTAL_CODE': 'P3E1H5',
#    'GEOMETRY_UPDATE_DATETIME': 1744234572000,
#    'EFFECTIVE_DATETIME': 1744210138000,
#    'SYSTEM_DATETIME': 1744221299000,
#    'OBJECTID': 2258945}},
#  {'type': 'Feature',
#   'id': 2258961,
#   'geometry': {'type': 'Point',
#    'coordinates': [-80.25121181392552, 43.1354554532194]},
#   'properties': {'OGF_ID': 321007647,
#    'MOH_SERVICE_PROVIDER_IDENT': '31226',
#    'SERVICE_TYPE': 'Mental Health and Addiction Organization',
#    'SERVICE_TYPE_DETAIL': 'Addiction Services',
#    'ENGLISH_NAME': 'Soar Community Services',
#    'FRENCH_NAME': None,
#    'ENGLISH_NAME_ALT': None,
#    'FRENCH_NAME_ALT': None,
#    'ADDRESS_LINE_1': '73 Murray Street',
#    'ADDRESS_LINE_2': None,
#    'ADDRESS_DESCRIPTOR': 'Practice Location',
#    'COMMUNITY': 'Brantford',
#    'POSTAL_CODE': 'N3S5N8',
#    'GEOMETRY_UPDATE_DATETIME': 1744234281000,
#    'EFFECTIVE_DATETIME': 1744209183000,
#    'SYSTEM_DATETIME': 1744221299000,
#    'OBJECTID': 2258961}},
#  {'type': 'Feature',
#   'id': 2258977,
#   'geometry': {'type': 'Point',
#    'coordinates': [-89.26108816696059, 48.40527765886378]},
#   'properties': {'OGF_ID': 321007088,
#    'MOH_SERVICE_PROVIDER_IDENT': '2379',
#    'SERVICE_TYPE': 'Mental Health and Addiction Organization',
#    'SERVICE_TYPE_DETAIL': 'Addiction Services',
#    'ENGLISH_NAME': "St. Joseph's Care Group",
#    'FRENCH_NAME': None,
#    'ENGLISH_NAME_ALT': None,
#    'FRENCH_NAME_ALT': None,
#    'ADDRESS_LINE_1': '667 Sibley Drive',
#    'ADDRESS_LINE_2': 'Balmoral Centre',
#    'ADDRESS_DESCRIPTOR': 'Practice Location',
#    'COMMUNITY': 'Thunder Bay',
#    'POSTAL_CODE': 'P7B5G7',
#    'GEOMETRY_UPDATE_DATETIME': 1744234480000,
#    'EFFECTIVE_DATETIME': 1744209122000,
#    'SYSTEM_DATETIME': 1744221299000,
#    'OBJECTID': 2258977}},
#  {'type': 'Feature',
#   'id': 2258993,
#   'geometry': {'type': 'Point',
#    'coordinates': [-75.63841272052159, 45.44399166122417]},
#   'properties': {'OGF_ID': 321017315,
#    'MOH_SERVICE_PROVIDER_IDENT': '7530',
#    'SERVICE_TYPE': 'Hospital',
#    'SERVICE_TYPE_DETAIL': 'Corporation',
#    'ENGLISH_NAME': 'Hopital Montfort',
#    'FRENCH_NAME': None,
#    'ENGLISH_NAME_ALT': 'Hopital Montfort',
#    'FRENCH_NAME_ALT': None,
#    'ADDRESS_LINE_1': '713 chemin Montreal',
#    'ADDRESS_LINE_2': None,
#    'ADDRESS_DESCRIPTOR': None,
#    'COMMUNITY': 'Ottawa',
#    'POSTAL_CODE': 'K1K0T2',
#    'GEOMETRY_UPDATE_DATETIME': 1744234468000,
#    'EFFECTIVE_DATETIME': 1744210257000,
#    'SYSTEM_DATETIME': 1744221299000,
#    'OBJECTID': 2258993}},
#  {'type': 'Feature',
#   'id': 2259009,
#   'geometry': {'type': 'Point',
#    'coordinates': [-79.22640634643706, 43.795867817352864]},
#   'properties': {'OGF_ID': 321015344,
#    'MOH_SERVICE_PROVIDER_IDENT': '7918159',
#    'SERVICE_TYPE': 'Pharmacy',
#    'SERVICE_TYPE_DETAIL': 'Retail Pharmacy',
#    'ENGLISH_NAME': 'Lapsley IDA Pharmacy',
#    'FRENCH_NAME': None,
#    'ENGLISH_NAME_ALT': None,
#    'FRENCH_NAME_ALT': None,
#    'ADDRESS_LINE_1': '27 Lapsley Road',
#    'ADDRESS_LINE_2': None,
#    'ADDRESS_DESCRIPTOR': None,
#    'COMMUNITY': 'Scarborough',
#    'POSTAL_CODE': 'M1B1K1',
#    'GEOMETRY_UPDATE_DATETIME': 1744234650000,
#    'EFFECTIVE_DATETIME': 1744210036000,
#    'SYSTEM_DATETIME': 1744221299000,
#    'OBJECTID': 2259009}},
#  {'type': 'Feature',
#   'id': 2259025,
#   'geometry': {'type': 'Point',
#    'coordinates': [-79.38720369540428, 43.768581405116315]},
#   'properties': {'OGF_ID': 321015477,
#    'MOH_SERVICE_PROVIDER_IDENT': '8089793',
#    'SERVICE_TYPE': 'Pharmacy',
#    'SERVICE_TYPE_DETAIL': 'Retail Pharmacy',
#    'ENGLISH_NAME': 'Loblaw Pharmacy #1019',
#    'FRENCH_NAME': None,
#    'ENGLISH_NAME_ALT': None,
#    'FRENCH_NAME_ALT': None,
#    'ADDRESS_LINE_1': '2877 Bayview Avenue',
#    'ADDRESS_LINE_2': None,
#    'ADDRESS_DESCRIPTOR': None,
#    'COMMUNITY': 'Toronto',
#    'POSTAL_CODE': 'M2K2S3',
#    'GEOMETRY_UPDATE_DATETIME': 1744234281000,
#    'EFFECTIVE_DATETIME': 1744210050000,
#    'SYSTEM_DATETIME': 1744221299000,
#    'OBJECTID': 2259025}},
#  {'type': 'Feature',
#   'id': 2259041,
#   'geometry': {'type': 'Point',
#    'coordinates': [-81.23755529147847, 42.76900614134068]},
#   'properties': {'OGF_ID': 321017599,
#    'MOH_SERVICE_PROVIDER_IDENT': '1056',
#    'SERVICE_TYPE': 'Long-Term Care Home',
#    'SERVICE_TYPE_DETAIL': 'MHFA',
#    'ENGLISH_NAME': 'Elgin Manor',
#    'FRENCH_NAME': None,
#    'ENGLISH_NAME_ALT': None,
#    'FRENCH_NAME_ALT': None,
#    'ADDRESS_LINE_1': '39262 Fingal Line',
#    'ADDRESS_LINE_2': None,
#    'ADDRESS_DESCRIPTOR': None,
#    'COMMUNITY': 'St Thomas',
#    'POSTAL_CODE': 'N5P3S5',
#    'GEOMETRY_UPDATE_DATETIME': 1744234353000,
#    'EFFECTIVE_DATETIME': 1744214630000,
#    'SYSTEM_DATETIME': 1744221299000,
#    'OBJECTID': 2259041}},
#  {'type': 'Feature',
#   'id': 2259057,
#   'geometry': {'type': 'Point',
#    'coordinates': [-74.65142849840458, 45.51930601477195]},
#   'properties': {'OGF_ID': 321011938,
#    'MOH_SERVICE_PROVIDER_IDENT': '2021519',
#    'SERVICE_TYPE': 'Pharmacy',
#    'SERVICE_TYPE_DETAIL': 'Retail Pharmacy',
#    'ENGLISH_NAME': 'Vankleekhill Pharmacy',
#    'FRENCH_NAME': None,
#    'ENGLISH_NAME_ALT': None,
#    'FRENCH_NAME_ALT': None,
#    'ADDRESS_LINE_1': '28 Main Street',
#    'ADDRESS_LINE_2': None,
#    'ADDRESS_DESCRIPTOR': None,
#    'COMMUNITY': 'Vankleekhill',
#    'POSTAL_CODE': 'K0B1R0',
#    'GEOMETRY_UPDATE_DATETIME': 1744234223000,
#    'EFFECTIVE_DATETIME': 1744209655000,
#    'SYSTEM_DATETIME': 1744221299000,
#    'OBJECTID': 2259057}},
#  {'type': 'Feature',
#   'id': 2259073,
#   'geometry': {'type': 'Point',
#    'coordinates': [-76.48581469853323, 44.235340215978255]},
#   'properties': {'OGF_ID': 321017280,
#    'MOH_SERVICE_PROVIDER_IDENT': '9836056',
#    'SERVICE_TYPE': 'Pharmacy',
#    'SERVICE_TYPE_DETAIL': 'Long Term Care Facility',
#    'ENGLISH_NAME': 'Providence Manor',
#    'FRENCH_NAME': None,
#    'ENGLISH_NAME_ALT': None,
#    'FRENCH_NAME_ALT': None,
#    'ADDRESS_LINE_1': '275 Sydenham Street',
#    'ADDRESS_LINE_2': None,
#    'ADDRESS_DESCRIPTOR': None,
#    'COMMUNITY': 'Kingston',
#    'POSTAL_CODE': 'K7K1G7',
#    'GEOMETRY_UPDATE_DATETIME': 1744234641000,
#    'EFFECTIVE_DATETIME': 1744210253000,
#    'SYSTEM_DATETIME': 1744221299000,
#    'OBJECTID': 2259073}},
#  {'type': 'Feature',
#   'id': 2259089,
#   'geometry': {'type': 'Point',
#    'coordinates': [-81.48970102394443, 43.360462733133524]},
#   'properties': {'OGF_ID': 321006616,
#    'MOH_SERVICE_PROVIDER_IDENT': '16894',
#    'SERVICE_TYPE': 'Mental Health and Addiction Organization',
#    'SERVICE_TYPE_DETAIL': 'Mental Health Services',
#    'ENGLISH_NAME': 'Canadian Mental Health Association (Cmha) Thames Valley Addiction And Mental Health Services',
#    'FRENCH_NAME': None,
#    'ENGLISH_NAME_ALT': None,
#    'FRENCH_NAME_ALT': None,
#    'ADDRESS_LINE_1': '149 Thames Road West',
#    'ADDRESS_LINE_2': 'Suite: B',
#    'ADDRESS_DESCRIPTOR': 'Practice Location',
#    'COMMUNITY': 'Exeter',
#    'POSTAL_CODE': 'N0M1S3',
#    'GEOMETRY_UPDATE_DATETIME': 1744234421000,
#    'EFFECTIVE_DATETIME': 1744209069000,
#    'SYSTEM_DATETIME': 1744221299000,
#    'OBJECTID': 2259089}},
#  {'type': 'Feature',
#   'id': 2259105,
#   'geometry': {'type': 'Point',
#    'coordinates': [-94.16228599512777, 48.67827343056857]},
#   'properties': {'OGF_ID': 321010611,
#    'MOH_SERVICE_PROVIDER_IDENT': '999369',
#    'SERVICE_TYPE': 'Seniors Active Living Centre',
#    'SERVICE_TYPE_DETAIL': None,
#    'ENGLISH_NAME': 'Township Of Morley - Stratton Seniors Friendship Centre',
#    'FRENCH_NAME': 'Township Of Morley - Stratton Seniors Friendship Centre',
#    'ENGLISH_NAME_ALT': None,
#    'FRENCH_NAME_ALT': None,
#    'ADDRESS_LINE_1': '11605 Highway 11',
#    'ADDRESS_LINE_2': None,
#    'ADDRESS_DESCRIPTOR': None,
#    'COMMUNITY': 'Stratton',
#    'POSTAL_CODE': 'P0W1N0',
#    'GEOMETRY_UPDATE_DATETIME': 1744234221000,
#    'EFFECTIVE_DATETIME': 1744209505000,
#    'SYSTEM_DATETIME': 1744221299000,
#    'OBJECTID': 2259105}},
#  {'type': 'Feature',
#   'id': 2259121,
#   'geometry': {'type': 'Point',
#    'coordinates': [-79.87515202861321, 43.51828193842029]},
#   'properties': {'OGF_ID': 321007214,
#    'MOH_SERVICE_PROVIDER_IDENT': '2657',
#    'SERVICE_TYPE': 'Mental Health and Addiction Organization',
#    'SERVICE_TYPE_DETAIL': 'Mental Health Services',
#    'ENGLISH_NAME': 'Supported Training And Rehabilitation In Diverse Environments (Stride)',
#    'FRENCH_NAME': None,
#    'ENGLISH_NAME_ALT': None,
#    'FRENCH_NAME_ALT': None,
#    'ADDRESS_LINE_1': '55 Ontario Street South',
#    'ADDRESS_LINE_2': 'Suite: 26',
#    'ADDRESS_DESCRIPTOR': 'Administration And Practice Location',
#    'COMMUNITY': 'Milton',
#    'POSTAL_CODE': 'L9T2M3',
#    'GEOMETRY_UPDATE_DATETIME': 1744234525000,
#    'EFFECTIVE_DATETIME': 1744209136000,
#    'SYSTEM_DATETIME': 1744221299000,
#    'OBJECTID': 2259121}},
#  {'type': 'Feature',
#   'id': 2259137,
#   'geometry': {'type': 'Point',
#    'coordinates': [-75.68348916535884, 44.598876913318854]},
#   'properties': {'OGF_ID': 321014657,
#    'MOH_SERVICE_PROVIDER_IDENT': '7006152',
#    'SERVICE_TYPE': 'Pharmacy',
#    'SERVICE_TYPE_DETAIL': 'Retail Pharmacy',
#    'ENGLISH_NAME': 'Leeds Pharmacy',
#    'FRENCH_NAME': None,
#    'ENGLISH_NAME_ALT': None,
#    'FRENCH_NAME_ALT': None,
#    'ADDRESS_LINE_1': 'C-163 Ormond Street',
#    'ADDRESS_LINE_2': None,
#    'ADDRESS_DESCRIPTOR': None,
#    'COMMUNITY': 'Brockville',
#    'POSTAL_CODE': 'K6V7E6',
#    'GEOMETRY_UPDATE_DATETIME': 1744234676000,
#    'EFFECTIVE_DATETIME': 1744209958000,
#    'SYSTEM_DATETIME': 1744221299000,
#    'OBJECTID': 2259137}},
#  {'type': 'Feature',
#   'id': 2259153,
#   'geometry': {'type': 'Point',
#    'coordinates': [-81.39509149545212, 44.42234282023144]},
#   'properties': {'OGF_ID': 321011745,
#    'MOH_SERVICE_PROVIDER_IDENT': '1497990',
#    'SERVICE_TYPE': 'Pharmacy',
#    'SERVICE_TYPE_DETAIL': 'Retail Pharmacy',
#    'ENGLISH_NAME': 'Wal-Mart Pharmacy',
#    'FRENCH_NAME': None,
#    'ENGLISH_NAME_ALT': None,
#    'FRENCH_NAME_ALT': None,
#    'ADDRESS_LINE_1': '5122 Highway 21',
#    'ADDRESS_LINE_2': None,
#    'ADDRESS_DESCRIPTOR': None,
#    'COMMUNITY': 'Port Elgin',
#    'POSTAL_CODE': 'N0H2C0',
#    'GEOMETRY_UPDATE_DATETIME': 1744234379000,
#    'EFFECTIVE_DATETIME': 1744209633000,
#    'SYSTEM_DATETIME': 1744221299000,
#    'OBJECTID': 2259153}},
#  {'type': 'Feature',
#   'id': 2259169,
#   'geometry': {'type': 'Point',
#    'coordinates': [-79.18904433513734, 43.80321502036759]},
#   'properties': {'OGF_ID': 321013883,
#    'MOH_SERVICE_PROVIDER_IDENT': '5924510',
#    'SERVICE_TYPE': 'Pharmacy',
#    'SERVICE_TYPE_DETAIL': 'Long Term Care Facility',
#    'ENGLISH_NAME': 'Extendicare/Rouge Valley',
#    'FRENCH_NAME': None,
#    'ENGLISH_NAME_ALT': None,
#    'FRENCH_NAME_ALT': None,
#    'ADDRESS_LINE_1': '551 Conlins Avenue',
#    'ADDRESS_LINE_2': None,
#    'ADDRESS_DESCRIPTOR': None,
#    'COMMUNITY': 'Toronto',
#    'POSTAL_CODE': 'M1B5S1',
#    'GEOMETRY_UPDATE_DATETIME': 1744234262000,
#    'EFFECTIVE_DATETIME': 1744209872000,
#    'SYSTEM_DATETIME': 1744221299000,
#    'OBJECTID': 2259169}},
#  {'type': 'Feature',
#   'id': 2259185,
#   'geometry': {'type': 'Point',
#    'coordinates': [-75.70939194093228, 45.407132451944385]},
#   'properties': {'OGF_ID': 321017034,
#    'MOH_SERVICE_PROVIDER_IDENT': '9661715',
#    'SERVICE_TYPE': 'Pharmacy',
#    'SERVICE_TYPE_DETAIL': 'Retail Pharmacy',
#    'ENGLISH_NAME': 'Pharma Can Drug Mart',
#    'FRENCH_NAME': None,
#    'ENGLISH_NAME_ALT': None,
#    'FRENCH_NAME_ALT': None,
#    'ADDRESS_LINE_1': '71 Willow Street',
#    'ADDRESS_LINE_2': None,
#    'ADDRESS_DESCRIPTOR': None,
#    'COMMUNITY': 'Ottawa',
#    'POSTAL_CODE': 'K1R6V9',
#    'GEOMETRY_UPDATE_DATETIME': 1744234339000,
#    'EFFECTIVE_DATETIME': 1744210226000,
#    'SYSTEM_DATETIME': 1744221299000,
#    'OBJECTID': 2259185}},
#  {'type': 'Feature',
#   'id': 2259201,
#   'geometry': {'type': 'Point',
#    'coordinates': [-80.32017911013345, 42.84208329783255]},
#   'properties': {'OGF_ID': 321011143,
#    'MOH_SERVICE_PROVIDER_IDENT': 'S0544',
#    'SERVICE_TYPE': 'Licensed Retirement Home',
#    'SERVICE_TYPE_DETAIL': None,
#    'ENGLISH_NAME': 'Aspira Cedar Crossing Retirement Living',
#    'FRENCH_NAME': None,
#    'ENGLISH_NAME_ALT': None,
#    'FRENCH_NAME_ALT': None,
#    'ADDRESS_LINE_1': '395 Cedar Street',
#    'ADDRESS_LINE_2': None,
#    'ADDRESS_DESCRIPTOR': None,
#    'COMMUNITY': 'Simcoe',
#    'POSTAL_CODE': 'N3Y2J2',
#    'GEOMETRY_UPDATE_DATETIME': 1744234631000,
#    'EFFECTIVE_DATETIME': 1744209564000,
#    'SYSTEM_DATETIME': 1744221299000,
#    'OBJECTID': 2259201}},
#  {'type': 'Feature',
#   'id': 2259217,
#   'geometry': {'type': 'Point',
#    'coordinates': [-80.92639006043164, 44.564387367822086]},
#   'properties': {'OGF_ID': 321007418,
#    'MOH_SERVICE_PROVIDER_IDENT': '30294',
#    'SERVICE_TYPE': 'Mental Health and Addiction Organization',
#    'SERVICE_TYPE_DETAIL': 'Addiction Services And Mental Health Services',
#    'ENGLISH_NAME': 'Southwest Ontario Aboriginal Health Access Centre',
#    'FRENCH_NAME': None,
#    'ENGLISH_NAME_ALT': None,
#    'FRENCH_NAME_ALT': None,
#    'ADDRESS_LINE_1': '733 9th Avenue East',
#    'ADDRESS_LINE_2': 'Suite: Unit #3',
#    'ADDRESS_DESCRIPTOR': 'Practice Location',
#    'COMMUNITY': 'Owen Sound',
#    'POSTAL_CODE': 'N4K3E6',
#    'GEOMETRY_UPDATE_DATETIME': 1744234216000,
#    'EFFECTIVE_DATETIME': 1744209159000,
#    'SYSTEM_DATETIME': 1744221299000,
#    'OBJECTID': 2259217}},
#  {'type': 'Feature',
#   'id': 2259233,
#   'geometry': {'type': 'Point',
#    'coordinates': [-79.24863898319765, 42.97916297167104]},
#   'properties': {'OGF_ID': 321008394,
#    'MOH_SERVICE_PROVIDER_IDENT': '4027',
#    'SERVICE_TYPE': 'Licensed Lab and Specimen Collection Centre',
#    'SERVICE_TYPE_DETAIL': 'Licensed Hospital Lab Location',
#    'ENGLISH_NAME': 'Niagara Health System - Welland County General Hospital Site',
#    'FRENCH_NAME': None,
#    'ENGLISH_NAME_ALT': None,
#    'FRENCH_NAME_ALT': None,
#    'ADDRESS_LINE_1': '65 Third Street',
#    'ADDRESS_LINE_2': None,
#    'ADDRESS_DESCRIPTOR': 'Billing, Administration, & Practice Address',
#    'COMMUNITY': 'Welland',
#    'POSTAL_CODE': 'L3B4W6',
#    'GEOMETRY_UPDATE_DATETIME': 1744234537000,
#    'EFFECTIVE_DATETIME': 1744209265000,
#    'SYSTEM_DATETIME': 1744221299000,
#    'OBJECTID': 2259233}},
#  {'type': 'Feature',
#   'id': 2259249,
#   'geometry': {'type': 'Point',
#    'coordinates': [-88.27436745530996, 49.01489971073494]},
#   'properties': {'OGF_ID': 321017523,
#    'MOH_SERVICE_PROVIDER_IDENT': '7390',
#    'SERVICE_TYPE': 'Hospital',
#    'SERVICE_TYPE_DETAIL': 'Corporation',
#    'ENGLISH_NAME': 'Nipigon District Memorial Hospital',
# ...
#   'id': 2273905,
#   'geometry': {'type': 'Point',
#    'coordinates': [-82.38247073089858, 42.58239975245624]},
#   'properties': {'OGF_ID': 321011078,
#    'MOH_SERVICE_PROVIDER_IDENT': 'S0433',
#    'SERVICE_TYPE': 'Licensed Retirement Home',
#    'SERVICE_TYPE_DETAIL': None,
#    'ENGLISH_NAME': 'Oaks Retirement Village',
#    'FRENCH_NAME': None,
#    'ENGLISH_NAME_ALT': None,
#    'FRENCH_NAME_ALT': None,
#    'ADDRESS_LINE_1': '80 Mcnaughton Avenue',
#    'ADDRESS_LINE_2': None,
#    'ADDRESS_DESCRIPTOR': None,
#    'COMMUNITY': 'Wallaceburg',
#    'POSTAL_CODE': 'N8A1R9',
#    'GEOMETRY_UPDATE_DATETIME': 1744234240000,
#    'EFFECTIVE_DATETIME': 1744209557000,
#    'SYSTEM_DATETIME': 1744221299000,
#    'OBJECTID': 2273905}},
#  {'type': 'Feature',
#   'id': 2273921,
#   'geometry': {'type': 'Point',
#    'coordinates': [-81.32938802705344, 48.47748286855024]},
#   'properties': {'OGF_ID': 321009631,
#    'MOH_SERVICE_PROVIDER_IDENT': '64F',
#    'SERVICE_TYPE': 'Family Health Team',
#    'SERVICE_TYPE_DETAIL': 'Satellite',
#    'ENGLISH_NAME': 'Timmins Academic Family Health Team-Fifth Avenue Site',
#    'FRENCH_NAME': None,
#    'ENGLISH_NAME_ALT': None,
#    'FRENCH_NAME_ALT': None,
#    'ADDRESS_LINE_1': '206 Fifth Avenue',
#    'ADDRESS_LINE_2': None,
#    'ADDRESS_DESCRIPTOR': '64',
#    'COMMUNITY': 'Timmins',
#    'POSTAL_CODE': 'P4N5L3',
#    'GEOMETRY_UPDATE_DATETIME': 1744234333000,
#    'EFFECTIVE_DATETIME': 1744209399000,
#    'SYSTEM_DATETIME': 1744221299000,
#    'OBJECTID': 2273921}},
#  {'type': 'Feature',
#   'id': 2273937,
#   'geometry': {'type': 'Point',
#    'coordinates': [-79.87094240381056, 43.25143829156033]},
#   'properties': {'OGF_ID': 321009290,
#    'MOH_SERVICE_PROVIDER_IDENT': '5056225',
#    'SERVICE_TYPE': 'Integrated Community Health Services Centre',
#    'SERVICE_TYPE_DETAIL': 'Fluoroscopy, General Ultrasound, Radiography, Vascular Ultrasound',
#    'ENGLISH_NAME': 'Wentworth-Halton X-Ray And Ultrasound Inc.',
#    'FRENCH_NAME': None,
#    'ENGLISH_NAME_ALT': 'Wentworth-Halton X-Ray And Ultrasound Inc.',
#    'FRENCH_NAME_ALT': None,
#    'ADDRESS_LINE_1': '1 Young Street',
#    'ADDRESS_LINE_2': 'Suite 105',
#    'ADDRESS_DESCRIPTOR': None,
#    'COMMUNITY': 'Hamilton',
#    'POSTAL_CODE': 'L8N1T8',
#    'GEOMETRY_UPDATE_DATETIME': 1744234625000,
#    'EFFECTIVE_DATETIME': 1744209362000,
#    'SYSTEM_DATETIME': 1744221299000,
#    'OBJECTID': 2273937}},
#  {'type': 'Feature',
#   'id': 2273953,
#   'geometry': {'type': 'Point',
#    'coordinates': [-79.46501076428818, 46.311775330179]},
#   'properties': {'OGF_ID': 321007408,
#    'MOH_SERVICE_PROVIDER_IDENT': '3026',
#    'SERVICE_TYPE': 'Mental Health and Addiction Organization',
#    'SERVICE_TYPE_DETAIL': 'Mental Health Services',
#    'ENGLISH_NAME': 'Canadian Mental Health Association North Bay And District',
#    'FRENCH_NAME': None,
#    'ENGLISH_NAME_ALT': None,
#    'FRENCH_NAME_ALT': None,
#    'ADDRESS_LINE_1': '176 Main Street West',
#    'ADDRESS_LINE_2': 'Suite: A',
#    'ADDRESS_DESCRIPTOR': 'Administration And Practice Location',
#    'COMMUNITY': 'North Bay',
#    'POSTAL_CODE': 'P1B2T5',
#    'GEOMETRY_UPDATE_DATETIME': 1744234204000,
#    'EFFECTIVE_DATETIME': 1744209157000,
#    'SYSTEM_DATETIME': 1744221299000,
#    'OBJECTID': 2273953}},
#  {'type': 'Feature',
#   'id': 2273969,
#   'geometry': {'type': 'Point',
#    'coordinates': [-74.71360157869029, 45.018330425897304]},
#   'properties': {'OGF_ID': 321015328,
#    'MOH_SERVICE_PROVIDER_IDENT': '7893719',
#    'SERVICE_TYPE': 'Pharmacy',
#    'SERVICE_TYPE_DETAIL': 'Retail Pharmacy',
#    'ENGLISH_NAME': 'Medical Arts Pharmacy',
#    'FRENCH_NAME': None,
#    'ENGLISH_NAME_ALT': None,
#    'FRENCH_NAME_ALT': None,
#    'ADDRESS_LINE_1': '165 Montreal Road',
#    'ADDRESS_LINE_2': None,
#    'ADDRESS_DESCRIPTOR': None,
#    'COMMUNITY': 'Cornwall',
#    'POSTAL_CODE': 'K6H1B2',
#    'GEOMETRY_UPDATE_DATETIME': 1744234576000,
#    'EFFECTIVE_DATETIME': 1744210034000,
#    'SYSTEM_DATETIME': 1744221299000,
#    'OBJECTID': 2273969}},
#  {'type': 'Feature',
#   'id': 2273985,
#   'geometry': {'type': 'Point',
#    'coordinates': [-79.92048821979073, 46.373261417277284]},
#   'properties': {'OGF_ID': 321007839,
#    'MOH_SERVICE_PROVIDER_IDENT': '3326631',
#    'SERVICE_TYPE': 'Community Health Centre',
#    'SERVICE_TYPE_DETAIL': 'Main',
#    'ENGLISH_NAME': 'Centre De Santé Communautaire Du Nipissing Ouest',
#    'FRENCH_NAME': 'Centre De Santé Communautaire Du Nipissing Ouest',
#    'ENGLISH_NAME_ALT': None,
#    'FRENCH_NAME_ALT': None,
#    'ADDRESS_LINE_1': '68 Michaud Street',
#    'ADDRESS_LINE_2': None,
#    'ADDRESS_DESCRIPTOR': None,
#    'COMMUNITY': 'Sturgeon Falls',
#    'POSTAL_CODE': 'P2B1B8',
#    'GEOMETRY_UPDATE_DATETIME': 1744234683000,
#    'EFFECTIVE_DATETIME': 1744209205000,
#    'SYSTEM_DATETIME': 1744221299000,
#    'OBJECTID': 2273985}},
#  {'type': 'Feature',
#   'id': 2274001,
#   'geometry': {'type': 'Point',
#    'coordinates': [-79.24956724609048, 43.70782530084648]},
#   'properties': {'OGF_ID': 321012319,
#    'MOH_SERVICE_PROVIDER_IDENT': '30228',
#    'SERVICE_TYPE': 'Pharmacy',
#    'SERVICE_TYPE_DETAIL': 'Retail Pharmacy',
#    'ENGLISH_NAME': 'Kingston Pharmacy',
#    'FRENCH_NAME': None,
#    'ENGLISH_NAME_ALT': None,
#    'FRENCH_NAME_ALT': None,
#    'ADDRESS_LINE_1': '2377 Kingston Road',
#    'ADDRESS_LINE_2': None,
#    'ADDRESS_DESCRIPTOR': None,
#    'COMMUNITY': 'Scarborough',
#    'POSTAL_CODE': 'M1N4E7',
#    'GEOMETRY_UPDATE_DATETIME': 1744234322000,
#    'EFFECTIVE_DATETIME': 1744209698000,
#    'SYSTEM_DATETIME': 1744221299000,
#    'OBJECTID': 2274001}},
#  {'type': 'Feature',
#   'id': 2274017,
#   'geometry': {'type': 'Point',
#    'coordinates': [-79.43178450597676, 43.72724519580385]},
#   'properties': {'OGF_ID': 321010110,
#    'MOH_SERVICE_PROVIDER_IDENT': '9000000094',
#    'SERVICE_TYPE': 'Midwifery Clinic',
#    'SERVICE_TYPE_DETAIL': 'Main',
#    'ENGLISH_NAME': 'Uptown Midwives And Family Wellness',
#    'FRENCH_NAME': None,
#    'ENGLISH_NAME_ALT': None,
#    'FRENCH_NAME_ALT': None,
#    'ADDRESS_LINE_1': '3426 Bathurst Street',
#    'ADDRESS_LINE_2': None,
#    'ADDRESS_DESCRIPTOR': 'Practice Location',
#    'COMMUNITY': 'Toronto',
#    'POSTAL_CODE': 'M6A2C2',
#    'GEOMETRY_UPDATE_DATETIME': 1744234666000,
#    'EFFECTIVE_DATETIME': 1744209452000,
#    'SYSTEM_DATETIME': 1744221299000,
#    'OBJECTID': 2274017}},
#  {'type': 'Feature',
#   'id': 2274033,
#   'geometry': {'type': 'Point',
#    'coordinates': [-74.60693319007603, 45.59907743020609]},
#   'properties': {'OGF_ID': 321008700,
#    'MOH_SERVICE_PROVIDER_IDENT': '4206',
#    'SERVICE_TYPE': 'Licensed Lab and Specimen Collection Centre',
#    'SERVICE_TYPE_DETAIL': 'Licensed Hospital Lab Location',
#    'ENGLISH_NAME': 'Hopital General De Hawkesbury And District General Hospital Inc.',
#    'FRENCH_NAME': None,
#    'ENGLISH_NAME_ALT': None,
#    'FRENCH_NAME_ALT': None,
#    'ADDRESS_LINE_1': '1111 Ghislain Street',
#    'ADDRESS_LINE_2': None,
#    'ADDRESS_DESCRIPTOR': 'Billing, Administration, & Practice Address',
#    'COMMUNITY': 'Hawkesbury',
#    'POSTAL_CODE': 'K6A3G5',
#    'GEOMETRY_UPDATE_DATETIME': 1744234335000,
#    'EFFECTIVE_DATETIME': 1744209298000,
#    'SYSTEM_DATETIME': 1744221299000,
#    'OBJECTID': 2274033}},
#  {'type': 'Feature',
#   'id': 2274049,
#   'geometry': {'type': 'Point',
#    'coordinates': [-79.39820220346033, 43.81980261356382]},
#   'properties': {'OGF_ID': 321015343,
#    'MOH_SERVICE_PROVIDER_IDENT': '7917873',
#    'SERVICE_TYPE': 'Pharmacy',
#    'SERVICE_TYPE_DETAIL': 'Retail Pharmacy',
#    'ENGLISH_NAME': 'Shoppers Drug Mart #658',
#    'FRENCH_NAME': None,
#    'ENGLISH_NAME_ALT': None,
#    'FRENCH_NAME_ALT': None,
#    'ADDRESS_LINE_1': '298 John Street',
#    'ADDRESS_LINE_2': None,
#    'ADDRESS_DESCRIPTOR': None,
#    'COMMUNITY': 'Thornhill',
#    'POSTAL_CODE': 'L3T5W4',
#    'GEOMETRY_UPDATE_DATETIME': 1744234187000,
#    'EFFECTIVE_DATETIME': 1744210035000,
#    'SYSTEM_DATETIME': 1744221299000,
#    'OBJECTID': 2274049}},
#  {'type': 'Feature',
#   'id': 2274065,
#   'geometry': {'type': 'Point',
#    'coordinates': [-75.66427232311601, 45.37339984807911]},
#   'properties': {'OGF_ID': 321014307,
#    'MOH_SERVICE_PROVIDER_IDENT': '6510359',
#    'SERVICE_TYPE': 'Pharmacy',
#    'SERVICE_TYPE_DETAIL': 'Retail Pharmacy',
#    'ENGLISH_NAME': 'Promed Pharmacy',
#    'FRENCH_NAME': None,
#    'ENGLISH_NAME_ALT': None,
#    'FRENCH_NAME_ALT': None,
#    'ADDRESS_LINE_1': '2706 Alta Vista Drive',
#    'ADDRESS_LINE_2': None,
#    'ADDRESS_DESCRIPTOR': None,
#    'COMMUNITY': 'Ottawa',
#    'POSTAL_CODE': 'K1V7T4',
#    'GEOMETRY_UPDATE_DATETIME': 1744234323000,
#    'EFFECTIVE_DATETIME': 1744209920000,
#    'SYSTEM_DATETIME': 1744221299000,
#    'OBJECTID': 2274065}},
#  {'type': 'Feature',
#   'id': 2274081,
#   'geometry': {'type': 'Point',
#    'coordinates': [-79.29522876553735, 43.76304170841601]},
#   'properties': {'OGF_ID': 321009328,
#    'MOH_SERVICE_PROVIDER_IDENT': '5225596',
#    'SERVICE_TYPE': 'Integrated Community Health Services Centre',
#    'SERVICE_TYPE_DETAIL': 'Pulmonary Function B - Lung Volumes & Diffusion',
#    'ENGLISH_NAME': 'Toronto Lung Care Clinic',
#    'FRENCH_NAME': None,
#    'ENGLISH_NAME_ALT': 'Mr. Udaya Shankar Padmakaran',
#    'FRENCH_NAME_ALT': None,
#    'ADDRESS_LINE_1': '520 Ellesmere Road',
#    'ADDRESS_LINE_2': '301',
#    'ADDRESS_DESCRIPTOR': None,
#    'COMMUNITY': 'Scarborough',
#    'POSTAL_CODE': 'M1R0B1',
#    'GEOMETRY_UPDATE_DATETIME': 1744234668000,
#    'EFFECTIVE_DATETIME': 1744209366000,
#    'SYSTEM_DATETIME': 1744221299000,
#    'OBJECTID': 2274081}},
#  {'type': 'Feature',
#   'id': 2274097,
#   'geometry': {'type': 'Point',
#    'coordinates': [-82.86764145567935, 42.306574279530366]},
#   'properties': {'OGF_ID': 321013150,
#    'MOH_SERVICE_PROVIDER_IDENT': '4701790',
#    'SERVICE_TYPE': 'Pharmacy',
#    'SERVICE_TYPE_DETAIL': 'Retail Pharmacy',
#    'ENGLISH_NAME': 'Sobeys Pharmacy #7216',
#    'FRENCH_NAME': None,
#    'ENGLISH_NAME_ALT': None,
#    'FRENCH_NAME_ALT': None,
#    'ADDRESS_LINE_1': '19 Amy Croft Drive',
#    'ADDRESS_LINE_2': None,
#    'ADDRESS_DESCRIPTOR': None,
#    'COMMUNITY': 'Windsor',
#    'POSTAL_CODE': 'N9K1C7',
#    'GEOMETRY_UPDATE_DATETIME': 1744234389000,
#    'EFFECTIVE_DATETIME': 1744209791000,
#    'SYSTEM_DATETIME': 1744221299000,
#    'OBJECTID': 2274097}},
#  {'type': 'Feature',
#   'id': 2274113,
#   'geometry': {'type': 'Point',
#    'coordinates': [-79.56465118321105, 44.11490515708848]},
#   'properties': {'OGF_ID': 321013971,
#    'MOH_SERVICE_PROVIDER_IDENT': '6044755',
#    'SERVICE_TYPE': 'Pharmacy',
#    'SERVICE_TYPE_DETAIL': 'Retail Pharmacy',
#    'ENGLISH_NAME': 'Bradford Centre Pharmacy',
#    'FRENCH_NAME': None,
#    'ENGLISH_NAME_ALT': None,
#    'FRENCH_NAME_ALT': None,
#    'ADDRESS_LINE_1': '21 Barrie Street',
#    'ADDRESS_LINE_2': None,
#    'ADDRESS_DESCRIPTOR': None,
#    'COMMUNITY': 'Bradford',
#    'POSTAL_CODE': 'L3Z2B3',
#    'GEOMETRY_UPDATE_DATETIME': 1744234584000,
#    'EFFECTIVE_DATETIME': 1744209882000,
#    'SYSTEM_DATETIME': 1744221299000,
#    'OBJECTID': 2274113}},
#  {'type': 'Feature',
#   'id': 2274129,
#   'geometry': {'type': 'Point',
#    'coordinates': [-79.87943818712736, 44.150531948296376]},
#   'properties': {'OGF_ID': 321012826,
#    'MOH_SERVICE_PROVIDER_IDENT': '4136036',
#    'SERVICE_TYPE': 'Pharmacy',
#    'SERVICE_TYPE_DETAIL': 'Retail Pharmacy',
#    'ENGLISH_NAME': 'Drugstore Pharmacy #509',
#    'FRENCH_NAME': None,
#    'ENGLISH_NAME_ALT': None,
#    'FRENCH_NAME_ALT': None,
#    'ADDRESS_LINE_1': '30 King Street South',
#    'ADDRESS_LINE_2': None,
#    'ADDRESS_DESCRIPTOR': None,
#    'COMMUNITY': 'Alliston',
#    'POSTAL_CODE': 'L9R1H6',
#    'GEOMETRY_UPDATE_DATETIME': 1744234512000,
#    'EFFECTIVE_DATETIME': 1744209755000,
#    'SYSTEM_DATETIME': 1744221299000,
#    'OBJECTID': 2274129}},
#  {'type': 'Feature',
#   'id': 2274145,
#   'geometry': {'type': 'Point',
#    'coordinates': [-78.31911159984044, 44.30654424800691]},
#   'properties': {'OGF_ID': 321009337,
#    'MOH_SERVICE_PROVIDER_IDENT': '5267',
#    'SERVICE_TYPE': 'Mental Health and Addiction Organization',
#    'SERVICE_TYPE_DETAIL': 'Mental Health Services',
#    'ENGLISH_NAME': 'Ontario Shores Centre For Mental Health Sciences',
#    'FRENCH_NAME': None,
#    'ENGLISH_NAME_ALT': None,
#    'FRENCH_NAME_ALT': None,
#    'ADDRESS_LINE_1': '421 Water Street',
#    'ADDRESS_LINE_2': 'Suite: 4',
#    'ADDRESS_DESCRIPTOR': 'Practice Location',
#    'COMMUNITY': 'Peterborough',
#    'POSTAL_CODE': 'K9H3P9',
#    'GEOMETRY_UPDATE_DATETIME': 1744234660000,
#    'EFFECTIVE_DATETIME': 1744209367000,
#    'SYSTEM_DATETIME': 1744221299000,
#    'OBJECTID': 2274145}},
#  {'type': 'Feature',
#   'id': 2274161,
#   'geometry': {'type': 'Point',
#    'coordinates': [-81.43482366985072, 42.95610476491926]},
#   'properties': {'OGF_ID': 321010447,
#    'MOH_SERVICE_PROVIDER_IDENT': '999202',
#    'SERVICE_TYPE': 'Seniors Active Living Centre',
#    'SERVICE_TYPE_DETAIL': None,
#    'ENGLISH_NAME': 'Middlesex Centre SALC - Komoka Community Centre',
#    'FRENCH_NAME': 'Middlesex Centre SALC - Komoka Community Centre',
#    'ENGLISH_NAME_ALT': None,
#    'FRENCH_NAME_ALT': None,
#    'ADDRESS_LINE_1': '133 Queen Street',
#    'ADDRESS_LINE_2': None,
#    'ADDRESS_DESCRIPTOR': None,
#    'COMMUNITY': 'Komoka',
#    'POSTAL_CODE': 'N0L1R0',
#    'GEOMETRY_UPDATE_DATETIME': 1744234567000,
#    'EFFECTIVE_DATETIME': 1744209488000,
#    'SYSTEM_DATETIME': 1744221299000,
#    'OBJECTID': 2274161}},
#  {'type': 'Feature',
#   'id': 2274177,
#   'geometry': {'type': 'Point',
#    'coordinates': [-79.83687221556308, 43.50820833844607]},
#   'properties': {'OGF_ID': 321012335,
#    'MOH_SERVICE_PROVIDER_IDENT': '307590',
#    'SERVICE_TYPE': 'Pharmacy',
#    'SERVICE_TYPE_DETAIL': 'Retail Pharmacy',
#    'ENGLISH_NAME': 'Metro Pharmacy #571',
#    'FRENCH_NAME': None,
#    'ENGLISH_NAME_ALT': None,
#    'FRENCH_NAME_ALT': None,
#    'ADDRESS_LINE_1': '1050 Kennedy Circle',
#    'ADDRESS_LINE_2': None,
#    'ADDRESS_DESCRIPTOR': None,
#    'COMMUNITY': 'Milton',
#    'POSTAL_CODE': 'L9T0J9',
#    'GEOMETRY_UPDATE_DATETIME': 1744234301000,
#    'EFFECTIVE_DATETIME': 1744209700000,
#    'SYSTEM_DATETIME': 1744221299000,
#    'OBJECTID': 2274177}},
#  {'type': 'Feature',
#   'id': 2274193,
#   'geometry': {'type': 'Point',
#    'coordinates': [-82.59016834681718, 42.04316774626296]},
#   'properties': {'OGF_ID': 321017648,
#    'MOH_SERVICE_PROVIDER_IDENT': '4590',
#    'SERVICE_TYPE': 'Long-Term Care Home',
#    'SERVICE_TYPE_DETAIL': 'NH non-profit',
#    'ENGLISH_NAME': 'Leamington Mennonite Home Long Term Care Residence',
#    'FRENCH_NAME': None,
#    'ENGLISH_NAME_ALT': None,
#    'FRENCH_NAME_ALT': None,
#    'ADDRESS_LINE_1': '35 Pickwick Drive',
#    'ADDRESS_LINE_2': None,
#    'ADDRESS_DESCRIPTOR': None,
#    'COMMUNITY': 'Leamington',
#    'POSTAL_CODE': 'N8H4T5',
#    'GEOMETRY_UPDATE_DATETIME': 1744234460000,
#    'EFFECTIVE_DATETIME': 1744214631000,
#    'SYSTEM_DATETIME': 1744221299000,
#    'OBJECTID': 2274193}},
#  {'type': 'Feature',
#   'id': 2274209,
#   'geometry': {'type': 'Point',
#    'coordinates': [-79.37224198143736, 43.664422587549865]},
#   'properties': {'OGF_ID': 321010378,
#    'MOH_SERVICE_PROVIDER_IDENT': '999135',
#    'SERVICE_TYPE': 'Seniors Active Living Centre',
#    'SERVICE_TYPE_DETAIL': None,
#    'ENGLISH_NAME': 'Dixon Hall - The Adult Enrichment Program',
#    'FRENCH_NAME': 'Dixon Hall - The Adult Enrichment Program',
#    'ENGLISH_NAME_ALT': None,
#    'FRENCH_NAME_ALT': None,
#    'ADDRESS_LINE_1': '55 Bleecker Street',
#    'ADDRESS_LINE_2': None,
#    'ADDRESS_DESCRIPTOR': None,
#    'COMMUNITY': 'Toronto',
#    'POSTAL_CODE': 'M4X1W9',
#    'GEOMETRY_UPDATE_DATETIME': 1744234229000,
#    'EFFECTIVE_DATETIME': 1744209480000,
#    'SYSTEM_DATETIME': 1744221299000,
#    'OBJECTID': 2274209}},
#  {'type': 'Feature',
#   'id': 2274225,
#   'geometry': {'type': 'Point',
#    'coordinates': [-79.51488942647283, 43.659285680021284]},
#   'properties': {'OGF_ID': 321016704,
#    'MOH_SERVICE_PROVIDER_IDENT': '9397075',
#    'SERVICE_TYPE': 'Pharmacy',
#    'SERVICE_TYPE_DETAIL': 'Retail Pharmacy',
#    'ENGLISH_NAME': 'Kingsway Pharmacy',
#    'FRENCH_NAME': None,
#    'ENGLISH_NAME_ALT': None,
#    'FRENCH_NAME_ALT': None,
#    'ADDRESS_LINE_1': '4242 Dundas Street West',
#    'ADDRESS_LINE_2': None,
#    'ADDRESS_DESCRIPTOR': None,
#    'COMMUNITY': 'Etobicoke',
#    'POSTAL_CODE': 'M8X1Y6',
#    'GEOMETRY_UPDATE_DATETIME': 1744234414000,
#    'EFFECTIVE_DATETIME': 1744210189000,
#    'SYSTEM_DATETIME': 1744221299000,
#    'OBJECTID': 2274225}},
#  ...]

# %%
geojson = {
    "type": "FeatureCollection",
    "features": features,
}

# %% [markdown]
# ### Save to geojson

# %%
with open(HEALTH_SERVICES_PATH, "w") as f:
    json.dump(geojson, f)

# %%
hospital_geodata = gpd.read_file(HEALTH_SERVICES_PATH)

# %%
hospital_geodata.head()
# Out:
#       OGF_ID MOH_SERVICE_PROVIDER_IDENT  ... OBJECTID                    geometry
# 0  321006337                    1154419  ...  2258241  POINT (-83.02664 42.29891)
# 1  321013957                    6027596  ...  2258257  POINT (-77.56906 44.10448)
# 2  321013142                     468871  ...  2258273   POINT (-79.79268 43.3563)
# 3  321010297                     999054  ...  2258289   POINT (-79.9372 43.79964)
# 4  321016232                      89790  ...  2258305  POINT (-82.21877 42.43394)
#
# [5 rows x 18 columns]

# %%
hospital_geodata.shape
# Out:
# (11974, 18)

# %%
hospital_geodata['geometry']
# Out:
# 0        POINT (-83.02664 42.29891)
# 1        POINT (-77.56906 44.10448)
# 2         POINT (-79.79268 43.3563)
# 3         POINT (-79.9372 43.79964)
# 4        POINT (-82.21877 42.43394)
#                     ...
# 11969    POINT (-89.25012 48.44686)
# 11970     POINT (-83.56357 46.2634)
# 11971    POINT (-79.52206 43.83456)
# 11972    POINT (-79.87923 47.82267)
# 11973    POINT (-79.88686 44.32194)
# Name: geometry, Length: 11974, dtype: geometry
