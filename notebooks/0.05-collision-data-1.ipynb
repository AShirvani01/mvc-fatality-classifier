# %%
# %load_ext autoreload
# %autoreload 2

# %%
from data import get_collision_data

# %%
df = get_collision_data()

# %%
df.head()
# Out:
#    _id    ACCNUM  ... DIVISION                                           geometry
# 0    1  893184.0  ...      D55  {"type": "Point", "coordinates": [-79.31879700...
# 1    2  893184.0  ...      D55  {"type": "Point", "coordinates": [-79.31879700...
# 2    3  893184.0  ...      D55  {"type": "Point", "coordinates": [-79.31879700...
# 3    4  893184.0  ...      D55  {"type": "Point", "coordinates": [-79.31879700...
# 4    5  893184.0  ...      D55  {"type": "Point", "coordinates": [-79.31879700...
#
# [5 rows x 50 columns]

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 18957 entries, 0 to 18956
# Data columns (total 50 columns):
#  #   Column             Non-Null Count  Dtype
# ---  ------             --------------  -----
#  0   _id                18957 non-null  int64
#  1   ACCNUM             14027 non-null  float64
#  2   DATE               18957 non-null  object
#  3   TIME               18957 non-null  int64
#  4   STREET1            18957 non-null  object
#  5   STREET2            17251 non-null  object
#  6   OFFSET             3820 non-null   object
#  7   ROAD_CLASS         18471 non-null  object
#  8   DISTRICT           18728 non-null  object
#  9   ACCLOC             13501 non-null  object
#  10  TRAFFCTL           18882 non-null  object
#  11  VISIBILITY         18933 non-null  object
#  12  LIGHT              18953 non-null  object
#  13  RDSFCOND           18928 non-null  object
#  14  ACCLASS            18956 non-null  object
#  15  IMPACTYPE          18930 non-null  object
#  16  INVTYPE            18941 non-null  object
#  17  INVAGE             18957 non-null  object
#  18  INJURY             10060 non-null  object
#  19  FATAL_NO           870 non-null    float64
#  20  INITDIR            13680 non-null  object
#  21  VEHTYPE            15470 non-null  object
#  22  MANOEUVER          11004 non-null  object
#  23  DRIVACT            9668 non-null   object
#  24  DRIVCOND           9666 non-null   object
#  25  PEDTYPE            3229 non-null   object
#  26  PEDACT             3227 non-null   object
#  27  PEDCOND            3246 non-null   object
#  28  CYCLISTYPE         805 non-null    object
#  29  CYCACT             802 non-null    object
#  30  CYCCOND            800 non-null    object
#  31  PEDESTRIAN         7688 non-null   object
#  32  CYCLIST            1986 non-null   object
#  33  AUTOMOBILE         17230 non-null  object
#  34  MOTORCYCLE         1684 non-null   object
#  35  TRUCK              1169 non-null   object
#  36  TRSN_CITY_VEH      1148 non-null   object
#  37  EMERG_VEH          49 non-null     object
#  38  PASSENGER          7183 non-null   object
#  39  SPEEDING           2694 non-null   object
#  40  AG_DRIV            9836 non-null   object
#  41  REDLIGHT           1577 non-null   object
#  42  ALCOHOL            808 non-null    object
#  43  DISABILITY         493 non-null    object
#  44  HOOD_158           18957 non-null  object
#  45  NEIGHBOURHOOD_158  18957 non-null  object
#  46  HOOD_140           18957 non-null  object
#  47  NEIGHBOURHOOD_140  18957 non-null  object
#  48  DIVISION           18957 non-null  object
#  49  geometry           18957 non-null  object
# dtypes: float64(2), int64(2), object(46)
# memory usage: 7.2+ MB

# %% [markdown]
# ### Number of missing data points by column

# %%
df.isna().sum()
# Out:
# _id                      0
# ACCNUM                4930
# DATE                     0
# TIME                     0
# STREET1                  0
# STREET2               1706
# OFFSET               15137
# ROAD_CLASS             486
# DISTRICT               229
# ACCLOC                5456
# TRAFFCTL                75
# VISIBILITY              24
# LIGHT                    4
# RDSFCOND                29
# ACCLASS                  1
# IMPACTYPE               27
# INVTYPE                 16
# INVAGE                   0
# INJURY                8897
# FATAL_NO             18087
# INITDIR               5277
# VEHTYPE               3487
# MANOEUVER             7953
# DRIVACT               9289
# DRIVCOND              9291
# PEDTYPE              15728
# PEDACT               15730
# PEDCOND              15711
# CYCLISTYPE           18152
# CYCACT               18155
# CYCCOND              18157
# PEDESTRIAN           11269
# CYCLIST              16971
# AUTOMOBILE            1727
# MOTORCYCLE           17273
# TRUCK                17788
# TRSN_CITY_VEH        17809
# EMERG_VEH            18908
# PASSENGER            11774
# SPEEDING             16263
# AG_DRIV               9121
# REDLIGHT             17380
# ALCOHOL              18149
# DISABILITY           18464
# HOOD_158                 0
# NEIGHBOURHOOD_158        0
# HOOD_140                 0
# NEIGHBOURHOOD_140        0
# DIVISION                 0
# geometry                 0
# dtype: int64

# %%
print(f"No. of duplicated rows: {df.duplicated().sum()}")
# Out:
# No. of duplicated rows: 0

# %% [markdown]
# ### Looking at classes of some features

# %%
df['INJURY'].value_counts()
# Out:
# INJURY
# Major      6445
# Minor      1479
# Minimal    1160
# Fatal       976
# Name: count, dtype: int64

# %%
df['ROAD_CLASS'].value_counts()
# Out:
# ROAD_CLASS
# Major Arterial     13376
# Minor Arterial      2958
# Collector           1032
# Local                865
# Expressway           164
# Other                 25
# Expressway Ramp       14
# Major Arterial        13
# Laneway               11
# Pending                7
# Major Shoreline        6
# Name: count, dtype: int64

# %%
df['NEIGHBOURHOOD_158'].value_counts()
# Out:
# NEIGHBOURHOOD_158
# West Humber-Clairville      597
# Yonge-Bay Corridor          376
# Wexford/Maryvale            361
# South Riverdale             353
# South Parkdale              304
#                            ...
# Guildwood                    25
# North Toronto                25
# Maple Leaf                   20
# Playter Estates-Danforth     20
# Lambton Baby Point           18
# Name: count, Length: 159, dtype: int64

# %%
df.query('NEIGHBOURHOOD_158 == "NSA"')
# Out:
#          _id  ...                                           geometry
# 237      238  ...  {"type": "Point", "coordinates": [-79.32438999...
# 238      239  ...  {"type": "Point", "coordinates": [-79.32438999...
# 239      240  ...  {"type": "Point", "coordinates": [-79.32438999...
# 240      241  ...  {"type": "Point", "coordinates": [-79.32438999...
# 241      242  ...  {"type": "Point", "coordinates": [-79.32438999...
# ...      ...  ...                                                ...
# 18617  18618  ...  {"type": "Point", "coordinates": [-79.27633999...
# 18618  18619  ...  {"type": "Point", "coordinates": [-79.27633999...
# 18619  18620  ...  {"type": "Point", "coordinates": [-79.27633999...
# 18673  18674  ...  {"type": "Point", "coordinates": [-79.42923299...
# 18674  18675  ...  {"type": "Point", "coordinates": [-79.42923299...
#
# [128 rows x 50 columns]

# %%
df.query('ROAD_CLASS.isna() | ROAD_CLASS == "Pending"')
# Out:
#          _id  ...                                           geometry
# 90        91  ...  {"type": "Point", "coordinates": [-79.52439000...
# 91        92  ...  {"type": "Point", "coordinates": [-79.52439000...
# 188      189  ...  {"type": "Point", "coordinates": [-79.48149000...
# 189      190  ...  {"type": "Point", "coordinates": [-79.48149000...
# 190      191  ...  {"type": "Point", "coordinates": [-79.48149000...
# ...      ...  ...                                                ...
# 18930  18931  ...  {"type": "Point", "coordinates": [-79.23516399...
# 18934  18935  ...  {"type": "Point", "coordinates": [-79.37143299...
# 18935  18936  ...  {"type": "Point", "coordinates": [-79.37143299...
# 18942  18943  ...  {"type": "Point", "coordinates": [-79.46403900...
# 18943  18944  ...  {"type": "Point", "coordinates": [-79.46403900...
#
# [493 rows x 50 columns]
